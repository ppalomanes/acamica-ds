# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
# Out:
# C:\Users\franc\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
df = pd.read_csv ('movie_metadata.csv')
df.columns
df.shape
# Out:
# (5043, 28)

# %%
print(df.shape)
df.head(3).T
# Out:
# (5043, 28)
#                                                                            0  \
# color                                                                  Color
# director_name                                                  James Cameron
# num_critic_for_reviews                                                   723
# duration                                                                 178
# director_facebook_likes                                                    0
# actor_3_facebook_likes                                                   855
# actor_2_name                                                Joel David Moore
# actor_1_facebook_likes                                                  1000
# gross                                                            7.60506e+08
# genres                                       Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                     CCH Pounder
# ...

# %%
#Hay relación existe entre Gross y actor3 likes?
#Hay relación entre color y rating?
#Hay relación entre budget y gross?
#Hay relación entre movie likes y actor likes?
#Hay relación entre content user 
#Qué influye más en el score? La influencia en redes del director, o la del del actor
#Evolución del budget a lo largo de los años
#Influye el rol del actor en el éxito económico de la película

#Existe una predominancia de un aspect ratio a lo largo de los años?
#Qué influye más en el numero de user reviews? Los likes del director, los del actor o de la película
#Relación entre aspect ratio y año
#Relación entre calificaciçon y score
#

# %%
#Películas que fracasaron en cuanto a lo $ (Budget - gross

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
df2=(df.gross <= df.budget)

# %%
df['perdida']=df['gross']-df['budget']

# %%
sorted(df)
# Out:
# ['actor_1_facebook_likes',
#  'actor_1_name',
#  'actor_2_facebook_likes',
#  'actor_2_name',
#  'actor_3_facebook_likes',
#  'actor_3_name',
#  'aspect_ratio',
#  'budget',
#  'cast_total_facebook_likes',
#  'color',
#  'content_rating',
#  'country',
#  'director_facebook_likes',
#  'director_name',
#  'duration',
#  'facenumber_in_poster',
#  'genres',
#  'gross',
#  'imdb_score',
#  'language',
#  'movie_facebook_likes',
#  'movie_imdb_link',
#  'movie_title',
#  'num_critic_for_reviews',
#  'num_user_for_reviews',
#  'num_voted_users',
#  'perdida',
#  'plot_keywords',
#  'title_year']

# %%
df3 = df[df2][['movie_title','gross','budget','perdida','imdb_score']]

# %%
df3
# Out:
#                                        movie_title        gross       budget  \
# 2                                         Spectre   200074175.0  245000000.0
# 5                                     John Carter    73058679.0  263700000.0
# 7                                         Tangled   200807262.0  260000000.0
# 11                               Superman Returns   200069408.0  209000000.0
# 12                              Quantum of Solace   168368427.0  200000000.0
# 14                                The Lone Ranger    89289910.0  215000000.0
# 16       The Chronicles of Narnia: Prince Caspian   141614023.0  225000000.0
# 18    Pirates of the Caribbean: On Stranger Tides   241063875.0  250000000.0
# 19                                 Men in Black 3   179020854.0  225000000.0
# 22                                     Robin Hood   105219735.0  200000000.0
# 24                             The Golden Compass    70083519.0  180000000.0
# ...

# %%
df3.sort_values('perdida',ascending=True)
# Out:
#                                    movie_title       gross        budget  \
# 2988                                 The Host    2201412.0  1.221550e+10
# 3859                           Lady Vengeance     211667.0  4.200000e+09
# 3005                                 Fateless     195888.0  2.500000e+09
# 2323                        Princess Mononoke    2298191.0  2.400000e+09
# 2334                                 Steamboy     410388.0  2.127520e+09
# 3423                                    Akira     439162.0  1.100000e+09
# 4542                            Godzilla 2000   10037390.0  1.000000e+09
# 3851                                    Tango    1687311.0  7.000000e+08
# 3075                   Kabhi Alvida Naa Kehna    3275443.0  7.000000e+08
# 3273                                    Kites    1602466.0  6.000000e+08
# 1338                                Red Cliff     626809.0  5.536320e+08
# 3311                 The Legend of Suriyothai     454255.0  4.000000e+08
# ...

# %%
df3.sort_values('imdb_score',ascending=False)
# Out:
#                                            movie_title       gross  \
# 683                                        Fight Club   37023395.0
# 4747                                    Seven Samurai     269061.0
# 2373                                    Spirited Away   10049886.0
# 4427                                     Modern Times     163245.0
# 3175                               American History X    6712241.0
# 1448                                      The Pianist   32519322.0
# 3931                                          Samsara    2601847.0
# 1714                      Once Upon a Time in America    5300000.0
# 1298                                           Amélie   33201661.0
# 4105                                           Oldboy    2181290.0
# 3849                              Requiem for a Dream    3609278.0
# 1329                         Baahubali: The Beginning    6498000.0
# 2970                                         Das Boot   11433134.0
# ...
