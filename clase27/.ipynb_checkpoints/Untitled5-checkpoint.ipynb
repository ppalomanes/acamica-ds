# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv", index_col=0)

# %%
df.sample(5)
# Out:
#        label                                              tweet
# id
# 28296      1  @user #allahsoil why build walls when there ar...
# 760        0  just bought: 'launch: using design thinking......
# 13748      0  my first day at college wearing #formals  went...
# 5067       0  best gig ever tonight in @user @user @user @us...
# 28615      0   @user priority tou choro koi 2nd option tk ni...

# %%
df["label"].unique()
# Out:
# array([0, 1])

# %%
df["tweet"].nunique()
# Out:
# 29530

# %%
df.size
# Out:
# 63924

# %%
df["tweet"].value_counts()
# Out:
# #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦                                                                          319
# i finally found a way how to delete old tweets! you might find it useful as well:    #deletetweets                                                             82
# aww yeah it's all good bing bong bing bong                                                                                                                     75
# i'm so   and #grateful now that - #affirmations                                                                                                                56
# @user you might be a libtard if... #libtard  #sjw #liberal #politics                                                                                           40
# you might be a libtard if... #libtard  #sjw #liberal #politics                                                                                                 32
# ð #love #instagood #photooftheday top.tags #tbt #cute #me #beautiful #followme   #followâ¦                                                                 29
# have my lover stop being angry at me visit us..&gt;&gt;&gt;  #lover   #friend #astrologer #love                                                                26
# #flagday2016   #flag #day #2016 #(30 #photos) buy things about "flag day 2016": â¦                                                                            22
# get #up get   get  #enjoy #music #today #free #apps #free #music                                                                                               21
# @user #feminismiscancer #feminismisterrorism #feminismmuktbharat why  #malevote is ignored  @user                                                              20
# #sikh #temple vandalised in in #calgary, #wso condemns  act                                                                                                    20
# save $$ no logins x brokers   #me #change #memes #love   #education #university                                                                                17
# can #lighttherapy help with   or #depression?    #altwaystoheal  #healthy is #happy !!                                                                         16
# can #lighttherapy help with   or #depression?   #altwaystoheal #healthy is #happy !!                                                                           14
# #music as #therapy as a tool for #healing!   #altwaystoheal #healthy is  !!                                                                                    14
# best essential oils for #healing!!    #altwaystoheal #healthy  !!                                                                                              14
# best #essentialoils for #anxiety !!     #healthy   #peace !!  #altwaystoheal !!                                                                                14
# safe ways to heal your #acne!!    #altwaystoheal #healthy   #healing!!                                                                                         14
# what is a #detoxdiet?  #altwaystoheal! #healthy  !                                                                                                             14
# does #magnettherapy really work?   #altwaystoheal #healing #healthy   !!                                                                                       14
# looking to feel more #joy? join me and 20 speakers on the free summit #unleashyourjoy                                                                          13
# best #lawofattraction #resources for #healing!    #altwaystoheal #healthy is  ! #idwp !                                                                        13
# herbal sleep remedies that work!!  #altwaystoheal #healthy #healing   !!                                                                                       13
# #lawofattraction for #healing!!    #altwaystoheal #healthy is  !!                                                                                              12
# can #lighttherapy help with #sad or #depression?    #altwaystoheal  #healthy is   !!                                                                           12
# #raw food diet benefits! -    #altwaystoheal #healthy   #healing #peace #joy #love !!                                                                          12
# can #atherapy and #musictherapy heal your life?   #altwaystoheal #healthy   #healing!                                                                          11
# #saysomething   bull up: you will dominate your bull and you will direct it whatever you want it to do. when                                                   11
# stuck in the rat race? find your freedom.   #masterkeyexperience                                                                                               11
#                                                                                                                                                              ...
#  @user cannot wait to see  @user working #lcmss17 w/ @user later this morning! #lcm                                                                             1
#  @user @user @user we need more #mentorsinpharmacy to ensure you feel  !and #suppoed @user @user @user                                                          1
#  @user a week till ibiza!!! ðð»ð¾ð¸ðð­ð­ð»ððððâï¸ð·ð¹ðºðð
# ð x #girlsholiday #fun #beach #sun #sand #sea   x      1
# my whole life..   ððð                                                                                                                                  1
# #mlearning   gorilla simulator: you need to do to adapt to the environment. the need to tear the city. mater                                                    1
#  â #mxn de-correlated with latam currencies, intervention risks rising - tds   #blog #silver #gold #forex                                                     1
#  @user if you think #york is an enlightened city read the horrible, homophobic comments in today's @user   #pride                                               1
# knowing i've passed my disseation and be able to sta my dream job in september! i can't sleep!!   #wideawake ð³ððð·âºï¸âºï¸                       1
#   bihday to this super talented actress @user #more grace                                                                                                       1
# today notice sounds #health    @user @user @user @user                                                                                                          1
# working at @user as sales executive                                                                                                                             1
# wahhhh!!!!!  white ppl arent allowed to do this!!!  ððð.   fuck you rich. we don't care ð                                                           1
# making elderflower cordial ó¾ #mylife #homemade #natural #plantbased #drink #flower #elderflower   #brewing...                                                1
# a walk in the parkâï¸ð³ #friends   #photooftheday #smile #sun #goodtimes #love #life #walkingâ¦                                                           1
# got engaged this morning and he's delighted!  #engagement #engaged   #happiness #inloveâ¦                                                                      1
#  @user #guess whos   for #summer                                                                                                                                1
# now playing  :  dustin o'halloran - " opus 30" on     music song                                                                                                1
# whoever invented this is brilliant. what a   #dog #fetch                                                                                                        1
#  @user @user @user  love it ðð                                                                                                                            1
# poisonous/hateful ideology + mental weakness/instability + easy access to guns/explosives = tragedy     needs #leadership #action                               1
# it's true... Ãverything in life &amp; love changes when you got little elfs hoppin' around. especially mÃ©   #love                                             1
# finding out you have pcos is just... it's disheaening... #pcos   #notsurewhattodo #feelingoverwhelmed                                                           1
# my main girl rosieeannx has hit her first #promotion ðððâ¤ï¸ðððð¼ yayyy! so   for you! i knowâ¦                                          1
# @user fine be pedantic, all your interest have been from the strict 'never' list i gave you. ella, savannah, and now ivy.                                       1
# happy national coffee cake day everyone!    #coffee #cake @user                                                                                                 1
# another upload!! go check it out!ð   #youtuber   #lifestyle #advice #vlog #vlogger #blog                                                                     1
# @user we are   to be sponsors   #proud @user @user sat july 2nd                                                                                                 1
# have a very good sweet dreams everyone and tomorrow ð´ððâ #tuesday #bynight   #smileâ¦                                                               1
# thank you so much ma'am @user  got reply from #urvashirautela  #feeling #cool #greatgrandmasti                                                                  1
# chatted with @user and @user about their new restaurant @user opens this month!                                                                                 1
# Name: tweet, Length: 29530, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df["tweet"]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /home/rcrespillo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vectorizer = TfidfVectorizer(analyzer='word', 
                             tokenizer=nltk.word_tokenize, 
                             stop_words=stops, 
                             ngram_range=(1,3))

X_train_v = vectorizer.fit_transform(X_train)
X_test_v = vectorizer.transform(X_test)

# %%
X_train_v.shape
# Out:
# (25569, 395790)

# %%
vectorizer.vocabulary_
# Out:
# {'ok': 268168,
#  'social': 317055,
#  'media': 245727,
#  'detox': 152594,
#  '.': 66241,
#  'drink': 157448,
#  'take': 330690,
#  '?': 87292,
#  'fb': 172054,
#  ',': 58804,
#  'twitter': 347759,
#  'tumblr': 346825,
#  'patch': 274832,
#  'checking': 132032,
#  '#': 6059,
#  'tired': 340095,
#  'ok social': 268219,
#  'social media': 317088,
#  'media detox': 245781,
#  'detox .': 152598,
#  '. drink': 69311,
#  'drink take': 157499,
#  'take ?': 330730,
#  '? fb': 88077,
#  'fb ,': 172057,
#  ', twitter': 64247,
#  'twitter ,': 347779,
#  ', tumblr': 64233,
#  'tumblr patch': 346836,
#  'patch ?': 274833,
#  '? checking': 87985,
#  'checking #': 132033,
#  '# tired': 44776,
#  'ok social media': 268220,
#  'social media detox': 317096,
#  'media detox .': 245782,
#  'detox . drink': 152599,
#  '. drink take': 69312,
#  'drink take ?': 157500,
#  'take ? fb': 330731,
#  '? fb ,': 88078,
#  'fb , twitter': 172059,
#  ', twitter ,': 64248,
#  'twitter , tumblr': 347783,
#  ', tumblr patch': 64234,
#  'tumblr patch ?': 346837,
#  'patch ? checking': 274834,
#  '? checking #': 87986,
#  'checking # tired': 132035,
#  'smile': 315765,
#  'cover': 142187,
#  'really': 293440,
#  'ask': 106002,
#  'self': 307737,
#  '# smile': 41066,
#  'smile #': 315771,
#  '# cover': 14906,
#  'cover .': 142203,
#  '. really': 71465,
#  'really ?': 293486,
#  '? ask': 87914,
#  'ask #': 106005,
#  '# self': 39894,
#  '# smile #': 41068,
#  'smile # cover': 315807,
#  '# cover .': 14908,
#  'cover . really': 142206,
#  '. really ?': 71467,
#  'really ? ask': 293492,
#  '? ask #': 87915,
#  'ask # self': 106006,
#  'observed': 266991,
#  'true': 345322,
#  'think': 336710,
#  'psychology': 288145,
#  'mentalhealth': 246815,
#  'science': 305327,
#  'day': 147350,
#  'happâ\x80¦': 201301,
#  'observed true': 266994,
#  'true .': 345365,
#  '. think': 72161,
#  'think ?': 336806,
#  '? #': 87342,
#  '# psychology': 37125,
#  'psychology #': 288146,
#  '# mentalhealth': 30717,
#  'mentalhealth #': 246816,
#  '# science': 39628,
#  'science day': 305352,
#  'day #': 147421,
#  '# happâ\x80¦': 23412,
#  'observed true .': 266995,
#  'true . think': 345377,
#  '. think ?': 72164,
#  'think ? #': 336807,
#  '? # psychology': 87567,
#  '# psychology #': 37126,
#  'psychology # mentalhealth': 288147,
#  '# mentalhealth #': 30718,
#  'mentalhealth # science': 246820,
#  '# science day': 39633,
#  'science day #': 305353,
#  'day # happâ\x80¦': 147513,
#  "'m": 51965,
#  'lazy': 226415,
#  'christian': 133615,
#  'cause': 129874,
#  "n't": 255793,
#  'kids': 221584,
#  'taken': 330997,
#  'thought': 337595,
#  'crime': 143360,
#  'posts': 283842,
#  'lmao': 233711,
#  "'m lazy": 52512,
#  'lazy christian': 226423,
#  'christian cause': 133625,
#  "cause n't": 129933,
#  "n't think": 257333,
#  'think kids': 336951,
#  'kids taken': 221774,
#  'taken thought': 331042,
#  'thought crime': 337639,
#  'crime twitter': 143391,
#  'twitter posts': 347876,
#  'posts ,': 283848,
#  ', lmao': 62153,
#  'lmao .': 233718,
#  "'m lazy christian": 52514,
#  'lazy christian cause': 226424,
#  "christian cause n't": 133626,
#  "cause n't think": 129937,
#  "n't think kids": 257347,
#  'think kids taken': 336952,
#  'kids taken thought': 221775,
#  'taken thought crime': 331043,
#  'thought crime twitter': 337640,
#  'crime twitter posts': 143392,
#  'twitter posts ,': 347877,
#  'posts , lmao': 283850,
#  ', lmao .': 62154,
#  '@': 88839,
#  'user': 352185,
#  "'s": 53742,
#  'got': 193561,
#  'australian': 107463,
#  'shitty': 310989,
#  'things': 336428,
#  '@ user': 89549,
#  'user @': 354222,
#  "user 's": 353571,
#  "'s got": 55101,
#  'got .': 193594,
#  '. australian': 68642,
#  'australian shitty': 107469,
#  'shitty things': 311002,
#  'things .': 336455,
#  '@ user @': 89690,
#  'user @ user': 354227,
#  "@ user 's": 89564,
#  "user 's got": 353615,
#  "'s got .": 55102,
#  'got . australian': 193597,
#  '. australian shitty': 68643,
#  'australian shitty things': 107470,
#  'shitty things .': 311003,
#  'lead': 226532,
#  'investigators': 215616,
#  'kathy': 220428,
#  'robb': 299723,
#  'team': 332421,
#  'member': 246332,
#  'penny': 276139,
#  'setting': 309272,
#  'equipment': 163442,
#  'ptitn5': 288204,
#  'user lead': 357936,
#  'lead investigators': 226554,
#  'investigators kathy': 215619,
#  'kathy robb': 220431,
#  'robb ,': 299724,
#  ', team': 64020,
#  'team member': 332541,
#  'member penny': 246356,
#  'penny ,': 276144,
#  ', setting': 63578,
#  'setting equipment': 309286,
#  'equipment .': 163443,
#  '. #': 66246,
#  '# ptitn5': 37141,
#  '@ user lead': 90959,
#  'user lead investigators': 357939,
#  'lead investigators kathy': 226555,
#  'investigators kathy robb': 215620,
#  'kathy robb ,': 220432,
#  'robb , team': 299725,
#  ', team member': 64022,
#  'team member penny': 332542,
#  'member penny ,': 246357,
#  'penny , setting': 276145,
#  ', setting equipment': 63579,
#  'setting equipment .': 309287,
#  'equipment . #': 163444,
#  '. # ptitn5': 67375,
#  'rss|xactaccounts|': 300921,
#  'tinyplanet': 340013,
#  'love': 236544,
#  'picoftheday': 279070,
#  'beautiful': 112602,
#  'cute': 144776,
#  'tinyplanetbufâ\x80¦': 340016,
#  'rss|xactaccounts| #': 300922,
#  '# tinyplanet': 44763,
#  'tinyplanet #': 340014,
#  '# love': 29219,
#  'love #': 236563,
#  '# picoftheday': 35769,
#  'picoftheday #': 279071,
#  '# beautiful': 10028,
#  'beautiful #': 112609,
#  '# cute': 15379,
#  'cute #': 144781,
#  '# tinyplanetbufâ\x80¦': 44765,
#  'rss|xactaccounts| # tinyplanet': 300923,
#  '# tinyplanet #': 44764,
#  'tinyplanet # love': 340015,
#  '# love #': 29221,
#  'love # picoftheday': 236915,
#  '# picoftheday #': 35770,
#  'picoftheday # beautiful': 279074,
#  '# beautiful #': 10030,
#  'beautiful # cute': 112629,
#  '# cute #': 15380,
#  'cute # tinyplanetbufâ\x80¦': 144873,
#  'mine': 248511,
#  '!': 0,
#  "'ll": 51637,
#  'studying': 325670,
#  'weekend': 371357,
#  '&': 50136,
#  'amp': 101130,
#  ';': 85039,
#  'bring': 123835,
#  'tuesday': 346688,
#  'compare': 138361,
#  'notes': 265381,
#  'choo': 133388,
#  ')': 57863,
#  'user mine': 358571,
#  'mine !': 248512,
#  "! 'll": 2226,
#  "'ll studying": 51899,
#  'studying weekend': 325681,
#  'weekend &': 371497,
#  '& amp': 50137,
#  'amp ;': 101131,
#  '; bring': 85594,
#  'bring tuesday': 123917,
#  'tuesday compare': 346736,
#  'compare notes': 138366,
#  'notes choo': 265387,
#  'choo ;': 133389,
#  '; )': 85293,
#  '@ user mine': 91139,
#  'user mine !': 358572,
#  "mine ! 'll": 248515,
#  "! 'll studying": 2232,
#  "'ll studying weekend": 51900,
#  'studying weekend &': 325682,
#  'weekend & amp': 371498,
#  '& amp ;': 50138,
#  'amp ; bring': 101243,
#  '; bring tuesday': 85595,
#  'bring tuesday compare': 123918,
#  'tuesday compare notes': 346737,
#  'compare notes choo': 138367,
#  'notes choo ;': 265388,
#  'choo ; )': 133390,
#  'excited': 166689,
#  'newcastle': 262081,
#  'saturday': 303561,
#  'hendo': 204763,
#  'girlsweekend': 188750,
#  'ð\x9f\x91': 389910,
#  'ð\x9f\x92\x84ð\x9f\x91\xadð\x9f\x8d¹ð\x9f\x8e\x89ð\x9f\x91\x90': 390704,
#  'excited newcastle': 166845,
#  'newcastle saturday': 262092,
#  'saturday #': 303573,
#  '# hendo': 23939,
#  'hendo #': 204764,
#  '# girlsweekend': 21855,
#  'girlsweekend ð\x9f\x91': 188751,
#  'ð\x9f\x91 ð\x9f\x92\x84ð\x9f\x91\xadð\x9f\x8d¹ð\x9f\x8e\x89ð\x9f\x91\x90': 389940,
#  'excited newcastle saturday': 166846,
#  'newcastle saturday #': 262093,
#  'saturday # hendo': 303593,
#  '# hendo #': 23940,
#  'hendo # girlsweekend': 204765,
#  '# girlsweekend ð\x9f\x91': 21856,
#  'girlsweekend ð\x9f\x91 ð\x9f\x92\x84ð\x9f\x91\xadð\x9f\x8d¹ð\x9f\x8e\x89ð\x9f\x91\x90': 188752,
#  'thankful': 334564,
#  'stars': 322178,
#  'positive': 283273,
#  'thankful stars': 334891,
#  'stars .': 322187,
#  '# thankful': 43988,
#  'thankful #': 334565,
#  '# positive': 36432,
#  'thankful stars .': 334892,
#  'stars . #': 322188,
#  '. # thankful': 67635,
#  '# thankful #': 43989,
#  'thankful # positive': 334579,
#  'details': 152513,
#  'website': 370426,
#  'x': 380239,
#  'online': 270017,
#  'shopping': 311636,
#  'buy': 126211,
#  'gottohaveit': 194339,
#  'newâ\x80¦': 262726,
#  'details website': 152537,
#  'website x': 370473,
#  'x #': 380240,
#  '# online': 34322,
#  'online #': 270020,
#  '# shopping': 40449,
#  'shopping #': 311640,
#  '# buy': 12452,
#  'buy #': 126212,
#  '# gottohaveit': 22498,
#  'gottohaveit #': 194340,
#  '# newâ\x80¦': 33114,
#  'details website x': 152538,
#  'website x #': 370474,
#  'x # online': 380250,
#  '# online #': 34323,
#  'online # shopping': 270024,
#  '# shopping #': 40450,
#  'shopping # buy': 311642,
#  '# buy #': 12453,
#  'buy # gottohaveit': 126213,
#  '# gottohaveit #': 22499,
#  'gottohaveit # newâ\x80¦': 194341,
#  'ca': 126571,
#  'ð\x9f\x98\x81': 392038,
#  'happiness': 199620,
#  'lovelife': 238395,
#  'weightlossjourney': 372168,
#  "ca n't": 126584,
#  "n't bring": 256112,
#  'bring ð\x9f\x98\x81': 123927,
#  'ð\x9f\x98\x81 #': 392041,
#  '# happiness': 23315,
#  'happiness #': 199625,
#  '# lovelife': 29427,
#  'lovelife #': 238396,
#  '# weightlossjourney': 47588,
#  "ca n't bring": 126607,
#  "n't bring ð\x9f\x98\x81": 256114,
#  'bring ð\x9f\x98\x81 #': 123928,
#  'ð\x9f\x98\x81 # happiness': 392057,
#  '# happiness #': 23317,
#  'happiness # lovelife': 199676,
#  '# lovelife #': 29428,
#  'lovelife # weightlossjourney': 238413,
#  'use': 351923,
#  'power': 284124,
#  'mind': 248310,
#  'heal': 203158,
#  'body': 120703,
#  'altwaystoheal': 99640,
#  'healthy': 203350,
#  'use power': 352017,
#  'power mind': 284183,
#  'mind #': 248315,
#  '# heal': 23680,
#  'heal body': 203166,
#  'body !': 120704,
#  '! #': 504,
#  '# altwaystoheal': 8123,
#  'altwaystoheal #': 99644,
#  '# healthy': 23720,
#  'healthy !': 203351,
#  '! !': 1,
#  'use power mind': 352018,
#  'power mind #': 284184,
#  'mind # heal': 248318,
#  '# heal body': 23682,
#  'heal body !': 203167,
#  'body ! #': 120706,
#  '! # altwaystoheal': 573,
#  '# altwaystoheal #': 8125,
#  'altwaystoheal # healthy': 99646,
#  '# healthy !': 23721,
#  'healthy ! !': 203352,
#  'classic': 134551,
#  'hummus': 209983,
#  'topped': 342785,
#  'chicken': 132516,
#  'shawarma': 310421,
#  'thighs': 336222,
#  'ð\x9f\x8d´ð\x9f\x8d½ð\x9f\x98\x89': 388987,
#  'tummy': 346858,
#  'dinner': 153612,
#  'classic hummus': 134566,
#  'hummus topped': 209987,
#  'topped chicken': 342786,
#  'chicken shawarma': 132536,
#  'shawarma thighs': 310424,
#  'thighs ð\x9f\x8d´ð\x9f\x8d½ð\x9f\x98\x89': 336223,
#  'ð\x9f\x8d´ð\x9f\x8d½ð\x9f\x98\x89 tummy': 388988,
#  'tummy #': 346859,
#  '# #': 6065,
#  '# dinner': 16507,
#  'dinner #': 153613,
#  '# shawarma': 40275,
#  'shawarma @': 310422,
#  'classic hummus topped': 134567,
#  'hummus topped chicken': 209988,
#  'topped chicken shawarma': 342787,
#  'chicken shawarma thighs': 132537,
#  'shawarma thighs ð\x9f\x8d´ð\x9f\x8d½ð\x9f\x98\x89': 310425,
#  'thighs ð\x9f\x8d´ð\x9f\x8d½ð\x9f\x98\x89 tummy': 336224,
#  'ð\x9f\x8d´ð\x9f\x8d½ð\x9f\x98\x89 tummy #': 388989,
#  'tummy # #': 346860,
#  '# # dinner': 6156,
#  '# dinner #': 16508,
#  'dinner # shawarma': 153623,
#  '# shawarma @': 40276,
#  'shawarma @ user': 310423,
#  'today': 340458,
#  'wearing': 370243,
#  'overalls': 272399,
#  'like': 230495,
#  '12': 76920,
#  'year': 381134,
#  'old': 268333,
#  'kid': 221487,
#  'offered': 267367,
#  'extra': 167848,
#  'coupon': 142004,
#  'woman': 376273,
#  'grocery': 196398,
#  'store': 324277,
#  'ran': 291651,
#  'away': 107946,
#  'hatefear': 202173,
#  'today wearing': 341135,
#  'wearing overalls': 370260,
#  'overalls ,': 272400,
#  ', like': 62084,
#  'like 12': 230668,
#  '12 year': 76979,
#  'year old': 381353,
#  'old kid': 268443,
#  'kid .': 221504,
#  '. offered': 71075,
#  'offered extra': 267368,
#  'extra coupon': 167856,
#  'coupon woman': 142014,
#  'woman grocery': 376363,
#  'grocery store': 196401,
#  'store .': 324287,
#  '. ran': 71437,
#  'ran away': 291659,
#  'away .': 107973,
#  '# hatefear': 23526,
#  'today wearing overalls': 341136,
#  'wearing overalls ,': 370261,
#  'overalls , like': 272401,
#  ', like 12': 62087,
#  'like 12 year': 230670,
#  '12 year old': 76980,
#  'year old kid': 381368,
#  'old kid .': 268444,
#  'kid . offered': 221508,
#  '. offered extra': 71076,
#  'offered extra coupon': 267369,
#  'extra coupon woman': 167857,
#  'coupon woman grocery': 142015,
#  'woman grocery store': 376364,
#  'grocery store .': 196402,
#  'store . ran': 324290,
#  '. ran away': 71438,
#  'ran away .': 291660,
#  'away . #': 107974,
#  '. # hatefear': 66878,
#  'augusta': 107323,
#  'buffalo': 125191,
#  'simulation': 313423,
#  ':': 83365,
#  'vicinity': 364106,
#  'homes': 207343,
#  'way': 369525,
#  'yo': 382377,
#  '# augusta': 9151,
#  'augusta buffalo': 107326,
#  'buffalo simulation': 125211,
#  'simulation :': 313426,
#  ': buffalo': 83949,
#  'buffalo take': 125213,
#  'take vicinity': 330964,
#  'vicinity homes': 364107,
#  'homes .': 207348,
#  '. way': 72477,
#  'way ,': 369561,
#  ', yo': 64694,
#  '# augusta buffalo': 9153,
#  'augusta buffalo simulation': 107327,
#  'buffalo simulation :': 125212,
#  'simulation : buffalo': 313427,
#  ': buffalo take': 83950,
#  'buffalo take vicinity': 125214,
#  'take vicinity homes': 330965,
#  'vicinity homes .': 364108,
#  'homes . way': 207351,
#  '. way ,': 72478,
#  'way , yo': 369573,
#  '7': 82478,
#  'steps': 323106,
#  'aging': 96965,
#  '7 steps': 82545,
#  'steps #': 323107,
#  'healthy #': 203357,
#  '# aging': 7627,
#  '7 steps #': 82546,
#  'steps # healthy': 323109,
#  '# healthy #': 23722,
#  'healthy # aging': 203359,
#  'watch': 368801,
#  'prince': 286207,
#  'cherry': 132362,
#  'moon': 251634,
#  'watch #': 368807,
#  '# prince': 36841,
#  'prince cherry': 286219,
#  'cherry moon': 132368,
#  'moon .': 251640,
#  'watch # prince': 368824,
#  '# prince cherry': 36844,
#  'prince cherry moon': 286220,
#  'cherry moon .': 132369,
#  'celebrating': 130425,
#  'â': 385167,
#  '\x98': 384359,
#  'besties': 115468,
#  'nationalbestfriendsday': 258623,
#  'celebrating â': 130477,
#  'â \x98': 385192,
#  '\x98 besties': 384360,
#  'besties #': 115469,
#  '# nationalbestfriendsday': 32466,
#  'celebrating â \x98': 130478,
#  'â \x98 besties': 385193,
#  '\x98 besties #': 384361,
#  'besties # nationalbestfriendsday': 115474,
#  'couple': 141869,
#  'shoppers': 311628,
#  'parking': 274377,
#  'lot': 236221,
#  'sale': 302829,
#  'couple #': 141872,
#  '# shoppers': 40445,
#  'shoppers #': 311629,
#  '# parking': 35087,
#  'parking lot': 274386,
#  'lot #': 236226,
#  '# sale': 39227,
#  'sale @': 302845,
#  'couple # shoppers': 141898,
#  '# shoppers #': 40446,
#  'shoppers # parking': 311630,
#  '# parking lot': 35089,
#  'parking lot #': 274387,
#  'lot # sale': 236231,
#  '# sale @': 39229,
#  'sale @ user': 302846,
#  'juneteenth': 219778,
#  'annual': 103084,
#  'celebration': 130480,
#  'end': 161614,
#  'slavery': 314910,
#  '-': 64747,
#  '# juneteenth': 26977,
#  'juneteenth ,': 219787,
#  ', #': 58813,
#  '# annual': 8579,
#  'annual #': 103085,
#  '# celebration': 13167,
#  'celebration end': 130504,
#  'end #': 161618,
#  '# slavery': 40915,
#  'slavery -': 314918,
#  '# juneteenth ,': 26980,
#  'juneteenth , #': 219788,
#  ', # annual': 58826,
#  '# annual #': 8580,
#  'annual # celebration': 103086,
#  '# celebration end': 13170,
#  'celebration end #': 130505,
#  'end # slavery': 161627,
#  '# slavery -': 40917,
#  'lornell': 235768,
#  'gone': 191882,
#  'ft': 182410,
#  'shi': 310610,
#  'missing': 249423,
#  'lornell gone': 235769,
#  'gone ft': 191942,
#  'ft shi': 182417,
#  "shi 's": 310616,
#  "'s missing": 55590,
#  'lornell gone ft': 235770,
#  'gone ft shi': 191943,
#  "ft shi 's": 182418,
#  "shi 's missing": 310617,
#  'fine': 175315,
#  'ill': 211571,
#  'boycott': 122492,
#  'user fine': 356515,
#  'fine ill': 175333,
#  'ill boycott': 211585,
#  'boycott !': 122493,
#  '@ user fine': 90504,
#  'user fine ill': 356516,
#  'fine ill boycott': 175334,
#  'ill boycott !': 211586,
#  'everybody': 165617,
#  'blocks': 119836,
#  '...': 73336,
#  '.she': 75495,
#  'annoying': 103066,
#  'mosquito': 252382,
#  'troll': 345113,
#  'user everybody': 356236,
#  'everybody blocks': 165632,
#  'blocks ...': 119839,
#  '... .she': 73984,
#  ".she 's": 75496,
#  "'s like": 55449,
#  'like annoying': 230750,
#  'annoying mosquito': 103073,
#  'mosquito troll': 252383,
#  'troll @': 345119,
#  '@ user everybody': 90424,
#  'user everybody blocks': 356237,
#  'everybody blocks ...': 165633,
#  'blocks ... .she': 119840,
#  "... .she 's": 73985,
#  ".she 's like": 75497,
#  "'s like annoying": 55455,
#  'like annoying mosquito': 230751,
#  'annoying mosquito troll': 103074,
#  'mosquito troll @': 252384,
#  'troll @ user': 345120,
#  'fuher': 182818,
#  'update': 350714,
#  'rave': 292117,
#  'caterpillars': 129704,
#  '*gasps': 58598,
#  'whispers*': 373561,
#  'wayward': 369991,
#  'chrysalis': 133832,
#  'butterflies': 126125,
#  'fuher update': 182836,
#  'update rave': 350752,
#  'rave caterpillars': 292121,
#  'caterpillars :': 129705,
#  ': *gasps': 83703,
#  '*gasps whispers*': 58599,
#  'whispers* wayward': 373562,
#  'wayward chrysalis': 369992,
#  'chrysalis ?': 133833,
#  '# butterflies': 12432,
#  'fuher update rave': 182837,
#  'update rave caterpillars': 350753,
#  'rave caterpillars :': 292122,
#  'caterpillars : *gasps': 129706,
#  ': *gasps whispers*': 83704,
#  '*gasps whispers* wayward': 58600,
#  'whispers* wayward chrysalis': 373563,
#  'wayward chrysalis ?': 369993,
#  'chrysalis ? #': 133834,
#  '? # butterflies': 87379,
#  'purchased': 288824,
#  'essential': 163752,
#  'oilsð\x9f\x92§': 268053,
#  'purchased essential': 288833,
#  'essential oilsð\x9f\x92§': 163760,
#  'purchased essential oilsð\x9f\x92§': 288834,
#  'afternoon': 96650,
#  'drinks': 157549,
#  'baking': 110466,
#  'fun': 183082,
#  'times': 339780,
#  'vlogger': 365384,
#  'youtuber': 383093,
#  'alcohol': 98039,
#  'winelover': 374922,
#  'foodie': 178678,
#  'yumy': 383459,
#  'lovewine': 238891,
#  'dailyvlogging': 146091,
#  'saturday afternoon': 303654,
#  'afternoon drinks': 96684,
#  'drinks baking': 157578,
#  'baking !': 110467,
#  '! fun': 3270,
#  'fun times': 183381,
#  'times #': 339783,
#  '# drinks': 17255,
#  'drinks #': 157552,
#  '# vlogger': 46871,
#  'vlogger #': 365385,
#  '# youtuber': 49137,
#  'youtuber #': 383094,
#  '# alcohol': 7826,
#  'alcohol #': 98043,
#  '# winelover': 48115,
#  'winelover #': 374923,
#  '# foodie': 20335,
#  'foodie #': 178679,
#  '# yumy': 49197,
#  'yumy #': 383460,
#  '# lovewine': 29561,
#  'lovewine #': 238892,
#  '# dailyvlogging': 15600,
#  'saturday afternoon drinks': 303656,
#  'afternoon drinks baking': 96685,
#  'drinks baking !': 157579,
#  'baking ! fun': 110468,
#  '! fun times': 3273,
#  'fun times #': 183382,
#  'times # drinks': 339788,
#  '# drinks #': 17256,
#  'drinks # vlogger': 157566,
#  '# vlogger #': 46872,
#  'vlogger # youtuber': 365388,
#  '# youtuber #': 49138,
#  'youtuber # alcohol': 383095,
#  '# alcohol #': 7827,
#  'alcohol # winelover': 98045,
#  '# winelover #': 48116,
#  'winelover # foodie': 374924,
#  '# foodie #': 20336,
#  'foodie # yumy': 178691,
#  '# yumy #': 49198,
#  'yumy # lovewine': 383461,
#  '# lovewine #': 29562,
#  'lovewine # dailyvlogging': 238893,
#  'oh': 267749,
#  'need': 259357,
#  'live': 233003,
#  'something': 317957,
#  'dead': 149752,
#  'sick': 312629,
#  'somehow': 317648,
#  'sustain': 329457,
#  'life': 229235,
#  'forgot': 179337,
#  'oh need': 267866,
#  'need live': 259569,
#  'live cause': 233105,
#  'cause something': 129953,
#  'something dead': 318018,
#  'dead &': 149766,
#  '; sick': 86767,
#  'sick somehow': 312702,
#  'somehow sustain': 317659,
#  'sustain life': 329458,
#  'life forgot': 229695,
#  'oh need live': 267867,
#  'need live cause': 259570,
#  'live cause something': 233106,
#  'cause something dead': 129954,
#  'something dead &': 318019,
#  'dead & amp': 149767,
#  'amp ; sick': 101733,
#  '; sick somehow': 86769,
#  'sick somehow sustain': 312703,
#  'somehow sustain life': 317660,
#  'sustain life forgot': 329459,
#  'scream': 305578,
#  'loud': 236444,
#  'faces': 168660,
#  '\\': 92605,
#  '/': 75582,
#  'scream #': 305579,
#  '# loud': 29202,
#  'loud #': 236447,
#  '# faces': 18882,
#  'faces \\': 168675,
#  '\\ !': 92606,
#  '! /': 2415,
#  'scream # loud': 305581,
#  '# loud #': 29203,
#  'loud # #': 236448,
#  '# # faces': 6182,
#  '# faces \\': 18886,
#  'faces \\ !': 168676,
#  '\\ ! /': 92607,
#  'model': 249990,
#  'u': 348348,
#  'time': 338976,
#  'urð\x9f\x93±': 351282,
#  'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 394080,
#  'ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 391492,
#  '# model': 31318,
#  'model love': 250027,
#  'love u': 237879,
#  'u take': 348844,
#  'take u': 330959,
#  'u time': 348863,
#  'time urð\x9f\x93±': 339642,
#  'urð\x9f\x93± !': 351283,
#  '! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 5859,
#  'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91 ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 394081,
#  '# model love': 31321,
#  'model love u': 250028,
#  'love u take': 237889,
#  'u take u': 348847,
#  'take u time': 330961,
#  'u time urð\x9f\x93±': 348864,
#  'time urð\x9f\x93± !': 339643,
#  'urð\x9f\x93± ! !': 351284,
#  '! ! !': 2,
#  '! ! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 466,
#  '! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91 ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 5860,
#  '``': 92738,
#  "''": 50512,
#  'lt.': 239301,
#  'governor': 194415,
#  'texas': 333981,
#  'basically': 111391,
#  'saying': 304397,
#  'victims': 364148,
#  'orlando': 271357,
#  'shooting': 311383,
#  'deserved': 152094,
#  '`` christian': 93008,
#  "christian ''": 133619,
#  "'' lt.": 50942,
#  'lt. governor': 239304,
#  'governor texas': 194420,
#  'texas .': 333996,
#  '. basically': 68693,
#  'basically saying': 111402,
#  'saying victims': 304480,
#  'victims orlando': 364207,
#  'orlando shooting': 271586,
#  'shooting deserved': 311440,
#  "`` christian ''": 93009,
#  "christian '' lt.": 133620,
#  "'' lt. governor": 50943,
#  'lt. governor texas': 239305,
#  'governor texas .': 194421,
#  'texas . basically': 333998,
#  '. basically saying': 68694,
#  'basically saying victims': 111403,
#  'saying victims orlando': 304481,
#  'victims orlando shooting': 364210,
#  'orlando shooting deserved': 271593,
#  'never': 260485,
#  'happy': 199940,
#  'continue': 140094,
#  'hold': 206410,
#  'make': 241014,
#  'never #': 260488,
#  '# happy': 23367,
#  'happy continue': 200376,
#  'continue hold': 140103,
#  'hold things': 206454,
#  'things make': 336600,
#  'make .': 241071,
#  '. happy': 69984,
#  'happy smile': 200944,
#  'never # happy': 260492,
#  '# happy continue': 23379,
#  'happy continue hold': 200377,
#  'continue hold things': 140104,
#  'hold things make': 206455,
#  'things make .': 336601,
#  'make . happy': 241075,
#  '. happy smile': 70004,
#  'disgusted': 154252,
#  'watching': 369077,
#  'defend': 150791,
#  'career': 128922,
#  'intelligence': 215045,
#  'informing': 213595,
#  'future': 183919,
#  'gen': 185731,
#  'laughable': 226024,
#  '..': 73137,
#  'disgusted watching': 154266,
#  'watching @': 369111,
#  'user defend': 355814,
#  'defend career': 150794,
#  'career &': 128931,
#  '; intelligence': 86210,
#  'intelligence @': 215053,
#  'user informing': 357579,
#  'informing future': 213596,
#  'future gen': 183966,
#  'gen laughable': 185737,
#  'laughable ?': 226025,
#  '? ..': 87751,
#  'disgusted watching @': 154267,
#  'watching @ user': 369112,
#  '@ user defend': 90248,
#  'user defend career': 355815,
#  'defend career &': 150795,
#  'career & amp': 128932,
#  'amp ; intelligence': 101501,
#  '; intelligence @': 86212,
#  'intelligence @ user': 215054,
#  '@ user informing': 90823,
#  'user informing future': 357580,
#  'informing future gen': 213597,
#  'future gen laughable': 183967,
#  'gen laughable ?': 185738,
#  'laughable ? ..': 226026,
#  'friyay': 182136,
#  'celeryman': 130582,
#  'ph': 278119,
#  'balance': 110494,
#  'health': 203236,
#  "'s friyay": 54962,
#  'friyay !': 182137,
#  '! celeryman': 2866,
#  'celeryman happy': 130583,
#  'happy .': 200090,
#  'happy ph': 200827,
#  'ph balance': 278122,
#  'balance .': 110506,
#  '# friyay': 20840,
#  'friyay #': 182141,
#  '# health': 23694,
#  "'s friyay !": 54963,
#  'friyay ! celeryman': 182138,
#  '! celeryman happy': 2867,
#  'celeryman happy .': 130584,
#  'happy . happy': 200100,
#  '. happy ph': 69999,
#  'happy ph balance': 200828,
#  'ph balance .': 278123,
#  'balance . #': 110507,
#  '. # friyay': 66787,
#  '# friyay #': 20841,
#  'friyay # health': 182146,
#  'playing': 280938,
#  'joe': 218556,
#  'bongiorno': 121087,
#  'wind': 374796,
#  'music': 254497,
#  'song': 318450,
#  'playing :': 280954,
#  ': joe': 84318,
#  'joe bongiorno': 218563,
#  'bongiorno -': 121088,
#  '- ``': 64981,
#  '`` wind': 93810,
#  "wind ''": 374799,
#  "'' music": 50977,
#  'music song': 254713,
#  'playing : joe': 280971,
#  ': joe bongiorno': 84319,
#  'joe bongiorno -': 218564,
#  'bongiorno - ``': 121089,
#  '- `` wind': 65041,
#  "`` wind ''": 93811,
#  "wind '' music": 374800,
#  "'' music song": 50978,
#  'friends': 181604,
#  'bachata': 109281,
#  'dancing': 146535,
#  'realize': 293341,
#  'everyone': 165766,
#  'pros': 287483,
#  'lol': 234074,
#  'wannagoagain': 367705,
#  'friends take': 181913,
#  'take bachata': 330757,
#  'bachata dancing': 109282,
#  'dancing realize': 146570,
#  'realize everyone': 293360,
#  'everyone pros': 165967,
#  'pros .': 287484,
#  '# lol': 28981,
#  'lol #': 234081,
#  '# wannagoagain': 47120,
#  'friends take bachata': 181914,
#  'take bachata dancing': 330758,
#  'bachata dancing realize': 109283,
#  'dancing realize everyone': 146571,
#  'realize everyone pros': 293361,
#  'everyone pros .': 165968,
#  'pros . #': 287485,
#  ...}

# %%
from sklearn.neural_network import MLPClassifier

# %%
param_grid = {
    'hidden_layer_sizes': [(10,),(5,5), (2,2),(10,2)],
    'activation': ['tanh', 'relu'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive']
}

mlpc = MLPClassifier()

# %%
grid_search.fit(X_train_v, y_train)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 24.6min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed: 25.7min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 26.6min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 29.4min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 30.3min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 31.0min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 32.1min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 51.5min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 55.6min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 57.2min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 57.5min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 57.9min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 59.2min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 87.6min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 89.7min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 94.5min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 94.7min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 96.7min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 100.2min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 101.4min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 105.2min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 109.3min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 110.6min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 113.5min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 113.7min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 115.4min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 116.1min
# /home/rodixxi/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 117.3min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 118.3min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 121.5min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 121.6min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 158.1min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 164.7min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 165.1min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 166.3min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 167.2min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 173.1min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 173.5min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 181.6min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 182.5min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 182.8min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 182.8min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 188.7min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 188.9min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 189.3min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 189.4min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 191.1min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 191.2min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 192.8min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 195.8min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 197.1min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 197.6min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 198.3min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 201.6min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 205.7min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 210.6min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 212.6min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 227.2min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 239.2min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 242.2min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 247.4min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 257.5min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 258.2min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 271.2min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 272.5min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 273.1min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 281.8min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 285.4min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 290.1min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 290.1min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 291.0min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 294.1min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 294.9min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 295.8min
# [Parallel(n_jobs=-1)]: Done  90 out of  96 | elapsed: 307.7min remaining: 20.5min
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed: 350.3min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'hidden_layer_sizes': [(10,), (5, 5), (2, 2), (10, 2)], 'activation': ['tanh', 'relu'], 'alpha': [0.0001, 0.05], 'learning_rate': ['constant', 'adaptive']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=20)

# %%
grid_search.best_params_
# Out:
# {'activation': 'tanh',
#  'alpha': 0.0001,
#  'hidden_layer_sizes': (10,),
#  'learning_rate': 'constant'}

# %%
mlp_clf = grid_search.best_estimator_

# %%
#mlp_clf.fit(X_train_v, y_train)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, classification_report

# %%
y_pred = mlp_clf.predict(X_test_v)

# %%
#confusion_matrix(y_test, y_pred)

# %%
print("roc_auc score: {}".format(roc_auc_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# roc_auc score: 0.7611220413312508
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5945
#            1       0.90      0.53      0.66       448
#
#    micro avg       0.96      0.96      0.96      6393
#    macro avg       0.93      0.76      0.82      6393
# weighted avg       0.96      0.96      0.96      6393

# %%
X_all = vectorizer.transform(X)
y_all = y

# %%
mlp_clf.fit(X_all, y_all)
# Out:
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
df_test = pd.read_csv("dataset/test.csv")

# %%
df_test.sample(5)
# Out:
#          id                                              tweet
# 4053  36016   @user so the @user can remove saudi arabia fr...
# 9188  41151  so sad that i missed the #youtubespacemum happ...
# 1244  33207  today is a perfect day to be  ! #happiness #li...
# 6163  38126   @user _animaladvocate:  wilko_val: these b#st...
# 3110  35073  @user #feminismiscancer #feminismisterrorism #...

# %%
dtest = vectorizer.transform(df_test['tweet'])
test_pred = mlp_clf.predict(dtest)

# %%
df_test['label'] = test_pred

# %%
submission = df_test[['id','label']]

# %%
submission.to_csv('sub_rodixxi_mlpC_GS.csv', index=False)
