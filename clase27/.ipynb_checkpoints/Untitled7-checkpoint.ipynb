# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv", index_col=0)

# %%
df.sample(5)
# Out:
#        label                                              tweet
# id
# 23480      0                       well i'm scared still ð­
# 28581      0  #lapride &amp; #bihdayweekend #vibes in the #h...
# 8210       0  hoe already looking for another nigga to fuckð...
# 6477       0  #liestoldindm most people lie to themselves, s...
# 16865      0  @user not funny "ha ha" but funny "weird"! pri...

# %%
df["label"].unique()
# Out:
# array([0, 1])

# %%
df["tweet"].nunique()
# Out:
# 29530

# %%
df.size
# Out:
# 63924

# %%
df["tweet"].value_counts()
# Out:
# #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦                                                                                    319
# i finally found a way how to delete old tweets! you might find it useful as well:    #deletetweets                                                                       82
# aww yeah it's all good bing bong bing bong                                                                                                                               75
# i'm so   and #grateful now that - #affirmations                                                                                                                          56
# @user you might be a libtard if... #libtard  #sjw #liberal #politics                                                                                                     40
# you might be a libtard if... #libtard  #sjw #liberal #politics                                                                                                           32
# ð #love #instagood #photooftheday top.tags #tbt #cute #me #beautiful #followme   #followâ¦                                                                           29
# have my lover stop being angry at me visit us..&gt;&gt;&gt;  #lover   #friend #astrologer #love                                                                          26
# #flagday2016   #flag #day #2016 #(30 #photos) buy things about "flag day 2016": â¦                                                                                      22
# get #up get   get  #enjoy #music #today #free #apps #free #music                                                                                                         21
# @user #feminismiscancer #feminismisterrorism #feminismmuktbharat why  #malevote is ignored  @user                                                                        20
# #sikh #temple vandalised in in #calgary, #wso condemns  act                                                                                                              20
# save $$ no logins x brokers   #me #change #memes #love   #education #university                                                                                          17
# can #lighttherapy help with   or #depression?    #altwaystoheal  #healthy is #happy !!                                                                                   16
# does #magnettherapy really work?   #altwaystoheal #healing #healthy   !!                                                                                                 14
# #music as #therapy as a tool for #healing!   #altwaystoheal #healthy is  !!                                                                                              14
# safe ways to heal your #acne!!    #altwaystoheal #healthy   #healing!!                                                                                                   14
# what is a #detoxdiet?  #altwaystoheal! #healthy  !                                                                                                                       14
# best #essentialoils for #anxiety !!     #healthy   #peace !!  #altwaystoheal !!                                                                                          14
# can #lighttherapy help with   or #depression?   #altwaystoheal #healthy is #happy !!                                                                                     14
# best essential oils for #healing!!    #altwaystoheal #healthy  !!                                                                                                        14
# herbal sleep remedies that work!!  #altwaystoheal #healthy #healing   !!                                                                                                 13
# best #lawofattraction #resources for #healing!    #altwaystoheal #healthy is  ! #idwp !                                                                                  13
# looking to feel more #joy? join me and 20 speakers on the free summit #unleashyourjoy                                                                                    13
# #lawofattraction for #healing!!    #altwaystoheal #healthy is  !!                                                                                                        12
# can #lighttherapy help with #sad or #depression?    #altwaystoheal  #healthy is   !!                                                                                     12
# #raw food diet benefits! -    #altwaystoheal #healthy   #healing #peace #joy #love !!                                                                                    12
# #people aren't protesting #trump because a #republican won-they do so because trump has fuhered  &amp;â¦                                                                11
# best #essentialoils for #anxiety !!     #healthy   #peace !! #altwaystoheal !!                                                                                           11
# #saysomething   bull up: you will dominate your bull and you will direct it whatever you want it to do. when                                                             11
#                                                                                                                                                                        ...
# my thoughts and prayers and deepest condolences are with the people of orlando the rest of america is with you.                                                           1
# today's lunchð #thankyou #thankful #lunch #yum #yummy   #ayutthaya #ã¿ã¤ã©ã³ã #ãã³ã³ã¯ #ã¢ã¦ã¿ã¤ #ã¿ã¤ #ã©ã³ã #å¹¸ã #æè¬ #ç¾å³ãã       1
#  juan happy love story: house blessing #video #juan   #love #story #house #blessing #philippines                                                                          1
# testing our templates over social media using a #poem i wrote a few weeks ago #broken   #writerinme poem:                                                                 1
# hmu. ðð#friday#turnup  #smile#love                                                                                                                                  1
#  @user and the other one is .........?come &amp; see at the open day sat 11th june 10-2pm 120 high st brentwood   #fleet                                                  1
# @user fg introduces a scheme &amp; state govt which is under fg says she won't paicipate?ekiti is now a separate country? this is                                         1
# soulmate ððð #mommy #daughter   #together #soulmate #rubygrace #medan                                                                                            1
# when you finally make it home to your best friend #bestfriends #cats #catlover #pets #catlady   #love #garfield                                                           1
# this is our last weekend with nothing planned. staing next weekend it's conces, conces and conces. #ilovemylife                                                           1
# @user the trouble is it's been going on since late 70's and has always happened   for football but can't be cured ? very sad                                              1
# #tvk3fathersday   fathers day to all tatay daddy enjoy wathing tha voice kids                                                                                             1
# gonna be busy end of the month. have to get the old one out, then (hopefully) install a whole new one till i go to london #homeimax                                       1
# first female mp to be murdered in britain and my timeline is full of arguments about whether it was brexit motivated or not.  #ripjocox                                   1
# more nonsense &amp; idiotic rhetoric from the gop nominee, as he gets more free press &amp; no pushback from the "fair &amp; balanced" network                            1
#  â #usd long positions added, eur shos increased - anz   #blog #silver #gold #forex                                                                                     1
# #election2016 politics &amp; politician's are stoopid or they think we all are. where are real people these days.                                                         1
# iiiiiiits show dayâ­ï¸â­ï¸   -kð¤ð»                                                                                                                               1
# going to greenwich university for my spo psychology masters :)                                                                                                            1
#  @user wohooo so excited for aaron and cassie!!!! #11192016 #wedding                                                                                                      1
#   father's day nd i"ll be wid u alwys dad.i am proud to say you my dad.#love u #dadððð                                                                           1
#  @user   2 share that i'm working w/ @user on the #hollywood #ambassador board #healthebay #ocean #jaxmalcolm                                                             1
# #babies   dorel baby relax varna swivel glider - beige  #bouncingbaby                                                                                                     1
# this is awful! just slap on the face to #americans hey my neighbor black just bought a $700,000 house. we r soâ¦                                                         1
# just 3 days until i get to see my best friend that i've not seen in 6 months                                                                                              1
# ben is literally one of the most fake human beings i have ever encountered ð­ð­ðð   #can'ttrusthim #donttrusthim #beware                                        1
# it has been a manic morning but we are finally on our way to chester ð #kyncalendargirls #knowyournormal                                                               1
# #eyeconography #ec79 #streetphotography79   #sunday to the children of the sun                                                                                            1
#  @user so geeked. love talking   hour! #foodtravelchat                                                                                                                    1
# finally got through season 1 of @user now onto season 2!!! #got                                                                                                           1
# Name: tweet, Length: 29530, dtype: int64

# %%
import nltk

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

# %%
def tweets_lemm(tweet):
    lemmatizer = WordNetLemmatizer()
    word_list = nltk.word_tokenize(tweet)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output

# %%
df['tweet'] = df['tweet'].apply(lambda x : tweets_lemm(x))

# %%
from sklearn.model_selection import train_test_split

# %%
X = df["tweet"]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /home/rodixxi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rodixxi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vectorizer = TfidfVectorizer(analyzer='word', 
                             tokenizer=nltk.word_tokenize, 
                             stop_words=stops, 
                             ngram_range=(1,3))

X_train_v = vectorizer.fit_transform(X_train)
X_test_v = vectorizer.transform(X_test)
# Out:
# /home/rodixxi/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ["'d", "'ll", "'re", "'s", "'ve", 'could', 'might', 'must', "n't", 'need', 'sha', 'wo', 'would'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
X_train_v.shape
# Out:
# (25569, 395065)

# %%
vectorizer.vocabulary_
# Out:
# {'#': 6061,
#  '16th': 77434,
#  'bihday': 116956,
#  'tapai': 331120,
#  '!': 0,
#  'many': 242860,
#  'come': 137179,
#  'best': 115017,
#  'cat': 129708,
#  'ð\x9f\x90¾ð\x9f\x90¾': 389067,
#  '# 16th': 6616,
#  '16th #': 77435,
#  '# bihday': 10786,
#  'bihday #': 116976,
#  '# tapai': 43318,
#  'tapai !': 331121,
#  '! many': 3850,
#  'many many': 243034,
#  'many come': 242926,
#  'come !': 137180,
#  '! best': 2744,
#  'best #': 115024,
#  '# cat': 13047,
#  'cat !': 129709,
#  '! ð\x9f\x90¾ð\x9f\x90¾': 5384,
#  '# 16th #': 6617,
#  '16th # bihday': 77436,
#  '# bihday #': 10788,
#  'bihday # tapai': 117102,
#  '# tapai !': 43319,
#  'tapai ! many': 331122,
#  '! many many': 3853,
#  'many many come': 243035,
#  'many come !': 242927,
#  'come ! best': 137184,
#  '! best #': 2745,
#  'best # cat': 115032,
#  '# cat !': 13048,
#  'cat ! ð\x9f\x90¾ð\x9f\x90¾': 129711,
#  'california': 127135,
#  'dreaming': 157234,
#  '...': 73092,
#  'goldengate': 191734,
#  'sanfrancisco': 302671,
#  'roadtrip': 299078,
#  'travel': 343615,
#  'relax': 295037,
#  '@': 88720,
#  'san': 302521,
#  'franciscoâ\x80¦': 180126,
#  'california dreaming': 127153,
#  'dreaming ...': 157235,
#  '... #': 73105,
#  '# goldengate': 22170,
#  'goldengate #': 191735,
#  '# sanfrancisco': 39296,
#  'sanfrancisco #': 302672,
#  '# roadtrip': 38703,
#  'roadtrip #': 299079,
#  '# travel': 45082,
#  'travel #': 343618,
#  '# relax': 38143,
#  'relax @': 295082,
#  '@ san': 89321,
#  'san franciscoâ\x80¦': 302532,
#  'california dreaming ...': 127154,
#  'dreaming ... #': 157236,
#  '... # goldengate': 73212,
#  '# goldengate #': 22171,
#  'goldengate # sanfrancisco': 191736,
#  '# sanfrancisco #': 39297,
#  'sanfrancisco # roadtrip': 302673,
#  '# roadtrip #': 38704,
#  'roadtrip # travel': 299084,
#  '# travel #': 45083,
#  'travel # relax': 343660,
#  '# relax @': 38146,
#  'relax @ san': 295083,
#  '@ san franciscoâ\x80¦': 89322,
#  'sexy': 309081,
#  'cora': 140922,
#  'porn': 282744,
#  'black': 118742,
#  'girl': 188151,
#  'sexy cora': 309137,
#  'cora porn': 140923,
#  'porn black': 282765,
#  'black girl': 118844,
#  'girl porn': 188395,
#  'sexy cora porn': 309138,
#  'cora porn black': 140924,
#  'porn black girl': 282766,
#  'black girl porn': 118845,
#  'time': 338400,
#  'user': 351514,
#  'time @': 338586,
#  '@ user': 89441,
#  'user !': 351515,
#  '! !': 1,
#  'time @ user': 338588,
#  '@ user !': 89442,
#  'user ! !': 351516,
#  'zealous': 382833,
#  '.': 66097,
#  'i_am': 210459,
#  'positive': 282909,
#  'affirmation': 96394,
#  'zealous .': 382834,
#  '. #': 66102,
#  '# i_am': 24828,
#  'i_am #': 210460,
#  '# positive': 36430,
#  'positive #': 282912,
#  '# affirmation': 7554,
#  'zealous . #': 382835,
#  '. # i_am': 66770,
#  '# i_am #': 24829,
#  'i_am # positive': 210461,
#  '# positive #': 36432,
#  'positive # affirmation': 282913,
#  'performing': 277054,
#  'tomorrow': 341152,
#  ',': 58618,
#  'im': 211720,
#  'feeling': 172690,
#  'anxious': 103808,
#  'ð\x9f\x98\x92ð\x9f\x91\x8dð\x9f\x8f': 393060,
#  '»': 383762,
#  'singing': 313196,
#  'edinburghâ\x80¦': 159854,
#  'performing tomorrow': 277070,
#  'tomorrow ,': 341220,
#  ', im': 61457,
#  'im feeling': 211778,
#  'feeling anxious': 172760,
#  'anxious ð\x9f\x98\x92ð\x9f\x91\x8dð\x9f\x8f': 103821,
#  'ð\x9f\x98\x92ð\x9f\x91\x8dð\x9f\x8f »': 393061,
#  '» #': 383766,
#  '# performing': 35506,
#  'performing #': 277057,
#  '# singing': 40588,
#  'singing #': 313197,
#  '# anxious': 8729,
#  'anxious #': 103809,
#  '# edinburghâ\x80¦': 17740,
#  'performing tomorrow ,': 277071,
#  'tomorrow , im': 341224,
#  ', im feeling': 61460,
#  'im feeling anxious': 211779,
#  'feeling anxious ð\x9f\x98\x92ð\x9f\x91\x8dð\x9f\x8f': 172761,
#  'anxious ð\x9f\x98\x92ð\x9f\x91\x8dð\x9f\x8f »': 103822,
#  'ð\x9f\x98\x92ð\x9f\x91\x8dð\x9f\x8f » #': 393062,
#  '» # performing': 383830,
#  '# performing #': 35507,
#  'performing # singing': 277058,
#  '# singing #': 40589,
#  'singing # anxious': 313198,
#  '# anxious #': 8730,
#  'anxious # edinburghâ\x80¦': 103811,
#  'happy': 199916,
#  'weekend': 370671,
#  "y'all": 379815,
#  'hello': 204210,
#  'saturday': 302973,
#  'goodmorning': 192926,
#  'sun': 326743,
#  'milano': 247655,
#  'italianweekend': 216519,
#  'happy weekend': 201046,
#  "weekend y'all": 371071,
#  "y'all !": 379816,
#  '! #': 503,
#  '# weekend': 47297,
#  'weekend #': 370687,
#  '# hello': 23847,
#  'hello #': 204216,
#  '# saturday': 39381,
#  'saturday #': 302984,
#  '# goodmorning': 22305,
#  'goodmorning #': 192927,
#  '# sun': 42689,
#  'sun #': 326749,
#  '# milano': 30951,
#  'milano #': 247656,
#  '# italianweekend': 26260,
#  "happy weekend y'all": 201060,
#  "weekend y'all !": 371072,
#  "y'all ! #": 379818,
#  '! # weekend': 2142,
#  '# weekend #': 47299,
#  'weekend # hello': 370731,
#  '# hello #': 23848,
#  'hello # saturday': 204227,
#  '# saturday #': 39383,
#  'saturday # goodmorning': 303005,
#  '# goodmorning #': 22306,
#  'goodmorning # sun': 192959,
#  '# sun #': 42691,
#  'sun # milano': 326786,
#  '# milano #': 30952,
#  'milano # italianweekend': 247658,
#  'feel': 172310,
#  'festival': 173593,
#  'opening': 270141,
#  'friday': 180872,
#  'winwritersfest': 374476,
#  'user feel': 355767,
#  'feel festival': 172438,
#  'festival opening': 173635,
#  'opening friday': 270172,
#  'friday #': 180902,
#  '# winwritersfest': 47956,
#  '@ user feel': 90389,
#  'user feel festival': 355768,
#  'feel festival opening': 172439,
#  'festival opening friday': 173636,
#  'opening friday #': 270173,
#  'friday # winwritersfest': 180990,
#  'â\x86\x9d': 385023,
#  '32.8': 80428,
#  'million': 247821,
#  'twitter': 347151,
#  'credentials': 143170,
#  'may': 244467,
#  'leaked': 226563,
#  'blog': 119965,
#  'silver': 312687,
#  'gold': 191668,
#  'forex': 179130,
#  'â\x86\x9d #': 385024,
#  '# 32.8': 6921,
#  '32.8 million': 80429,
#  'million twitter': 247849,
#  'twitter credentials': 347221,
#  'credentials may': 143171,
#  'may leaked': 244593,
#  'leaked #': 226564,
#  '# blog': 11247,
#  'blog #': 119970,
#  '# silver': 40526,
#  'silver #': 312688,
#  '# gold': 22157,
#  'gold #': 191672,
#  '# forex': 20425,
#  'â\x86\x9d # 32.8': 385025,
#  '# 32.8 million': 6922,
#  '32.8 million twitter': 80430,
#  'million twitter credentials': 247850,
#  'twitter credentials may': 347222,
#  'credentials may leaked': 143172,
#  'may leaked #': 244594,
#  'leaked # blog': 226565,
#  '# blog #': 11249,
#  'blog # silver': 119981,
#  '# silver #': 40527,
#  'silver # gold': 312689,
#  '# gold #': 22159,
#  'gold # forex': 191673,
#  'bodrum': 120827,
#  'bodrummarina': 120833,
#  'friends': 181607,
#  'marina': 243403,
#  '# bodrum': 11436,
#  'bodrum #': 120828,
#  '# bodrummarina': 11439,
#  'bodrummarina #': 120834,
#  '# friends': 20771,
#  'friends @': 181771,
#  '@ marina': 89142,
#  'marina bodrum': 243406,
#  '# bodrum #': 11437,
#  'bodrum # bodrummarina': 120829,
#  '# bodrummarina #': 11440,
#  'bodrummarina # friends': 120835,
#  '# friends @': 20777,
#  'friends @ marina': 181777,
#  '@ marina bodrum': 89143,
#  'read': 291889,
#  'pride': 285702,
#  'amazing': 100210,
#  'beautiful': 112724,
#  'cute': 144760,
#  'equality': 163332,
#  'equalrights': 163371,
#  'gay': 185184,
#  'gaypride': 185343,
#  'â\x80¦': 384925,
#  'read pride': 292008,
#  'pride .': 285717,
#  '# amazing': 8230,
#  'amazing #': 100223,
#  '# beautiful': 10078,
#  'beautiful #': 112731,
#  '# cute': 15428,
#  'cute #': 144764,
#  '# equality': 18299,
#  'equality #': 163333,
#  '# equalrights': 18306,
#  'equalrights #': 163372,
#  '# gay': 21328,
#  'gay #': 185187,
#  '# gaypride': 21367,
#  'gaypride â\x80¦': 185353,
#  'read pride .': 292009,
#  'pride . #': 285718,
#  '. # amazing': 66166,
#  '# amazing #': 8232,
#  'amazing # beautiful': 100227,
#  '# beautiful #': 10080,
#  'beautiful # cute': 112752,
#  '# cute #': 15429,
#  'cute # equality': 144790,
#  '# equality #': 18300,
#  'equality # equalrights': 163337,
#  '# equalrights #': 18307,
#  'equalrights # gay': 163373,
#  '# gay #': 21330,
#  'gay # gaypride': 185200,
#  '# gaypride â\x80¦': 21371,
#  'getting': 187309,
#  'mood': 251125,
#  'ready': 292162,
#  'performance': 276996,
#  'pippin': 279371,
#  'user getting': 356170,
#  'getting mood': 187477,
#  'mood ready': 251219,
#  'ready @': 292227,
#  'user performance': 358715,
#  'performance pippin': 277023,
#  'pippin .': 279372,
#  '# pippin': 35911,
#  '@ user getting': 90510,
#  'user getting mood': 356175,
#  'getting mood ready': 187478,
#  'mood ready @': 251220,
#  'ready @ user': 292228,
#  '@ user performance': 91265,
#  'user performance pippin': 358716,
#  'performance pippin .': 277024,
#  'pippin . #': 279373,
#  '. # pippin': 67154,
#  "'ve": 56503,
#  '``': 92708,
#  'way': 368871,
#  'home': 206762,
#  'like': 230265,
#  'hour': 208602,
#  'lol': 233944,
#  "'ve ``": 56520,
#  '`` way': 93745,
#  'way home': 369061,
#  'home ``': 206860,
#  '`` like': 93304,
#  'like hour': 230793,
#  'hour lol': 208678,
#  "'ve `` way": 56523,
#  '`` way home': 93746,
#  'way home ``': 369064,
#  'home `` like': 206861,
#  '`` like hour': 93306,
#  'like hour lol': 230795,
#  'china': 133217,
#  ':': 83232,
#  'rmb': 298957,
#  'depreciation': 151771,
#  'headwind': 203069,
#  'asian': 105928,
#  'currencies': 144423,
#  '-': 64535,
#  'anz': 104223,
#  '# china': 13661,
#  'china :': 133230,
#  ': rmb': 84566,
#  'rmb depreciation': 298958,
#  'depreciation headwind': 151772,
#  'headwind asian': 203070,
#  'asian currencies': 105951,
#  'currencies -': 144426,
#  '- anz': 64857,
#  'anz #': 104224,
#  'â\x86\x9d # china': 385046,
#  '# china :': 13665,
#  'china : rmb': 133232,
#  ': rmb depreciation': 84567,
#  'rmb depreciation headwind': 298959,
#  'depreciation headwind asian': 151773,
#  'headwind asian currencies': 203071,
#  'asian currencies -': 105952,
#  'currencies - anz': 144427,
#  '- anz #': 64858,
#  'anz # blog': 104225,
#  'agusto': 97117,
#  'rhodesia': 297692,
#  'club': 135741,
#  'social': 316577,
#  'agusto !': 97118,
#  '! @': 2561,
#  '@ rhodesia': 89295,
#  'rhodesia club': 297693,
#  'club social': 135805,
#  'agusto ! @': 97119,
#  '! @ rhodesia': 2569,
#  '@ rhodesia club': 89296,
#  'rhodesia club social': 297694,
#  'dad': 145355,
#  'â\x9d¤ï¸\x8f': 386227,
#  'favorite': 171746,
#  'superhero': 327856,
#  'tb': 331469,
#  'father': 170874,
#  "'s": 53539,
#  'day': 147354,
#  'fathersday': 171286,
#  '# #': 6068,
#  '# dad': 15541,
#  'dad â\x9d¤ï¸\x8f': 145632,
#  'â\x9d¤ï¸\x8f favorite': 386301,
#  'favorite #': 171747,
#  '# superhero': 42876,
#  'superhero !': 327857,
#  '# tb': 43382,
#  'tb #': 331470,
#  '# father': 19210,
#  "father 's": 170904,
#  "'s #": 53549,
#  '# day': 15861,
#  'day !': 147355,
#  '! fathersday': 3166,
#  '# # dad': 6147,
#  '# dad â\x9d¤ï¸\x8f': 15564,
#  'dad â\x9d¤ï¸\x8f favorite': 145633,
#  'â\x9d¤ï¸\x8f favorite #': 386302,
#  'favorite # superhero': 171754,
#  '# superhero !': 42877,
#  'superhero ! #': 327858,
#  '! # tb': 1981,
#  '# tb #': 43383,
#  'tb # father': 331476,
#  "# father 's": 19212,
#  "father 's #": 170905,
#  "'s # day": 53574,
#  '# day !': 15862,
#  'day ! fathersday': 147378,
#  'media': 245413,
#  'types': 347635,
#  "'shopped": 56427,
#  'yuge': 382530,
#  'bigly': 116828,
#  'crowd': 143671,
#  'there..in': 335407,
#  'mind': 247941,
#  'media types': 245509,
#  "types 'shopped": 347636,
#  "'shopped .": 56428,
#  '. yuge': 72442,
#  'yuge bigly': 382531,
#  'bigly crowd': 116831,
#  'crowd there..in': 143681,
#  'there..in mind': 335408,
#  'mind .': 247960,
#  "media types 'shopped": 245510,
#  "types 'shopped .": 347637,
#  "'shopped . yuge": 56429,
#  '. yuge bigly': 72443,
#  'yuge bigly crowd': 382532,
#  'bigly crowd there..in': 116832,
#  'crowd there..in mind': 143682,
#  'there..in mind .': 335409,
#  'redneck': 294262,
#  'island': 216204,
#  'woohoo': 376333,
#  'pumped': 288041,
#  'woo': 376258,
#  'hoo': 207481,
#  'via': 363368,
#  'giphy': 188147,
#  ', redneck': 63060,
#  'redneck island': 294265,
#  'island ,': 216212,
#  ', woohoo': 64383,
#  'woohoo ,': 376344,
#  ', pumped': 62930,
#  'pumped ,': 288052,
#  'redneck ,': 294263,
#  ', woo': 64380,
#  'woo hoo': 376264,
#  'hoo ,': 207486,
#  ', happy': 61251,
#  'happy redneck': 200827,
#  'redneck via': 294269,
#  'via giphy': 363395,
#  ', redneck island': 63062,
#  'redneck island ,': 294266,
#  'island , woohoo': 216213,
#  ', woohoo ,': 64384,
#  'woohoo , pumped': 376346,
#  ', pumped ,': 62931,
#  'pumped , redneck': 288053,
#  ', redneck ,': 63061,
#  'redneck , woo': 294264,
#  ', woo hoo': 64382,
#  'woo hoo ,': 376266,
#  'hoo , happy': 207487,
#  ', happy redneck': 61269,
#  'happy redneck via': 200828,
#  'redneck via giphy': 294270,
#  'dailysketch': 146069,
#  'e3': 158792,
#  'new': 260729,
#  'york': 381813,
#  'george': 186054,
#  'washington': 368040,
#  'bridge': 123835,
#  '# dailysketch': 15642,
#  'dailysketch #': 146070,
#  '# e3': 17513,
#  'e3 @': 158808,
#  '@ new': 89196,
#  'new york': 261685,
#  'york -': 381820,
#  '- george': 65102,
#  'george washington': 186072,
#  'washington bridge': 368043,
#  '# # dailysketch': 6149,
#  '# dailysketch #': 15643,
#  'dailysketch # e3': 146071,
#  '# e3 @': 17517,
#  'e3 @ new': 158809,
#  '@ new york': 89198,
#  'new york -': 261689,
#  'york - george': 381821,
#  '- george washington': 65103,
#  'george washington bridge': 186073,
#  'days': 149098,
#  'skin': 314084,
#  'inmyskin': 213632,
#  'healthychick': 203520,
#  'selfesteemâ\x80¦': 307244,
#  'days happy': 149311,
#  'happy skin': 200895,
#  'skin inmyskin': 314104,
#  'inmyskin #': 213633,
#  '# healthychick': 23738,
#  'healthychick #': 203521,
#  '# selfesteemâ\x80¦': 39817,
#  'days happy skin': 149312,
#  'happy skin inmyskin': 200897,
#  'skin inmyskin #': 314105,
#  'inmyskin # healthychick': 213634,
#  '# healthychick #': 23739,
#  'healthychick # selfesteemâ\x80¦': 203522,
#  'model': 249614,
#  'love': 236380,
#  'u': 347719,
#  'take': 330103,
#  'urð\x9f\x93±': 350616,
#  'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 393319,
#  'ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 390701,
#  '# model': 31294,
#  'model love': 249655,
#  'love u': 237691,
#  'u take': 348201,
#  'take u': 330363,
#  'u time': 348213,
#  'time urð\x9f\x93±': 339090,
#  'urð\x9f\x93± !': 350617,
#  '! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 5867,
#  'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91 ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 393320,
#  '# model love': 31297,
#  'model love u': 249656,
#  'love u take': 237700,
#  'u take u': 348204,
#  'take u time': 330365,
#  'u time urð\x9f\x93±': 348214,
#  'time urð\x9f\x93± !': 339091,
#  'urð\x9f\x93± ! !': 350618,
#  '! ! !': 2,
#  '! ! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 467,
#  '! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91 ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 5868,
#  'release': 295179,
#  'slime': 314702,
#  'school': 304423,
#  'fundraising': 183475,
#  'games': 184626,
#  'kickstaercampaign': 221298,
#  'indiedev': 213079,
#  'apple': 104591,
#  'action': 95094,
#  'ios': 215566,
#  'new release': 261433,
#  'release !': 295180,
#  '! slime': 4485,
#  'slime school': 314705,
#  'school !': 304424,
#  '# fundraising': 20986,
#  'fundraising #': 183476,
#  '# games': 21244,
#  'games #': 184630,
#  '# kickstaercampaign': 27296,
#  'kickstaercampaign #': 221299,
#  '# indiedev': 25446,
#  'indiedev #': 213080,
#  '# apple': 8787,
#  'apple #': 104592,
#  '# action': 7370,
#  'action #': 95097,
#  '# ios': 25992,
#  'new release !': 261434,
#  'release ! slime': 295184,
#  '! slime school': 4486,
#  'slime school !': 314706,
#  'school ! #': 304426,
#  '! # fundraising': 1104,
#  '# fundraising #': 20987,
#  'fundraising # games': 183478,
#  '# games #': 21245,
#  'games # kickstaercampaign': 184635,
#  '# kickstaercampaign #': 27297,
#  'kickstaercampaign # indiedev': 221301,
#  '# indiedev #': 25447,
#  'indiedev # apple': 213081,
#  '# apple #': 8788,
#  'apple # action': 104593,
#  '# action #': 7371,
#  'action # ios': 95101,
#  'see': 305857,
#  'us': 350619,
#  'allentown': 98507,
#  'fest': 173581,
#  'allentownafest2016': 98510,
#  'funnights': 183568,
#  'beer': 113712,
#  'buffalo': 125369,
#  'come see': 137433,
#  'see us': 306546,
#  'us weekend': 351063,
#  'weekend allentown': 370879,
#  'allentown fest': 98508,
#  'fest !': 173582,
#  '# allentownafest2016': 8000,
#  'allentownafest2016 #': 98511,
#  '# funnights': 21014,
#  'funnights #': 183569,
#  '# beer': 10220,
#  'beer #': 113715,
#  '# buffalo': 12285,
#  'come see us': 137440,
#  'see us weekend': 306551,
#  'us weekend allentown': 351064,
#  'weekend allentown fest': 370880,
#  'allentown fest !': 98509,
#  'fest ! #': 173583,
#  '! # allentownafest2016': 569,
#  '# allentownafest2016 #': 8001,
#  'allentownafest2016 # funnights': 98512,
#  '# funnights #': 21015,
#  'funnights # beer': 183570,
#  '# beer #': 10221,
#  'beer # buffalo': 113717,
#  'waiting': 366217,
#  'watch': 368155,
#  'naitik': 257754,
#  'scene': 304279,
#  'ð\x9f\x99\x88': 394196,
#  'ð\x9f\x98\x94': 393077,
#  'last': 224972,
#  'telecast': 332559,
#  '?': 87140,
#  'ð\x9f\x98\xad': 393791,
#  'westandwithyoukaran': 372238,
#  'waiting watch': 366407,
#  'watch #': 368160,
#  '# naitik': 32371,
#  'naitik scene': 257757,
#  'scene ð\x9f\x99\x88': 304311,
#  'ð\x9f\x99\x88 #': 394197,
#  'scene ð\x9f\x98\x94': 304309,
#  'ð\x9f\x98\x94 #': 393078,
#  'naitik last': 257755,
#  'last scene': 225183,
#  'scene telecast': 304301,
#  'telecast ?': 332560,
#  '? ð\x9f\x98\xad': 88689,
#  'ð\x9f\x98\xad #': 393794,
#  '# westandwithyoukaran': 47470,
#  'westandwithyoukaran â\x9d¤ï¸\x8f': 372239,
#  'waiting watch #': 366408,
#  'watch # naitik': 368173,
#  '# naitik scene': 32373,
#  'naitik scene ð\x9f\x99\x88': 257759,
#  'scene ð\x9f\x99\x88 #': 304312,
#  'ð\x9f\x99\x88 # naitik': 394201,
#  'naitik scene ð\x9f\x98\x94': 257758,
#  'scene ð\x9f\x98\x94 #': 304310,
#  'ð\x9f\x98\x94 # naitik': 393086,
#  '# naitik last': 32372,
#  'naitik last scene': 257756,
#  'last scene telecast': 225184,
#  'scene telecast ?': 304302,
#  'telecast ? ð\x9f\x98\xad': 332561,
#  '? ð\x9f\x98\xad #': 88690,
#  'ð\x9f\x98\xad # westandwithyoukaran': 393805,
#  '# westandwithyoukaran â\x9d¤ï¸\x8f': 47471,
#  '10': 76220,
#  'roxe': 300218,
#  'hogaye': 206256,
#  'body': 120836,
#  'invited': 215458,
#  'iftar': 211124,
#  '(': 56916,
#  'buhatnainsafi': 125437,
#  '10 roxe': 76310,
#  'roxe hogaye': 300219,
#  'hogaye body': 206257,
#  'body invited': 120904,
#  'invited iftar': 215467,
#  'iftar :': 211131,
#  ': (': 83468,
#  '( #': 56919,
#  '# buhatnainsafi': 12299,
#  '10 roxe hogaye': 76311,
#  'roxe hogaye body': 300220,
#  'hogaye body invited': 206258,
#  'body invited iftar': 120905,
#  'invited iftar :': 215468,
#  'iftar : (': 211132,
#  ': ( #': 83469,
#  '( # buhatnainsafi': 56926,
#  'allahsoil': 98351,
#  'muslims': 254600,
#  'arenâ\x80\x99t': 105094,
#  'ones': 269533,
#  'displaced': 154551,
#  'uncle': 349034,
#  'sam': 302417,
#  '2016in4wordsâ\x80¦': 78993,
#  'user #': 351540,
#  '# allahsoil': 7935,
#  'allahsoil muslims': 98408,
#  'muslims arenâ\x80\x99t': 254606,
#  'arenâ\x80\x99t ones': 105095,
#  'ones displaced': 269547,
#  'displaced uncle': 154554,
#  'uncle sam': 349045,
#  'sam â\x80¦': 302425,
#  'â\x80¦ â\x80¦': 384962,
#  'â\x80¦ #': 384926,
#  '# 2016in4wordsâ\x80¦': 6750,
#  '@ user #': 89443,
#  'user # allahsoil': 351593,
#  '# allahsoil muslims': 7963,
#  'allahsoil muslims arenâ\x80\x99t': 98409,
#  'muslims arenâ\x80\x99t ones': 254607,
#  'arenâ\x80\x99t ones displaced': 105096,
#  'ones displaced uncle': 269548,
#  'displaced uncle sam': 154555,
#  'uncle sam â\x80¦': 349046,
#  'sam â\x80¦ â\x80¦': 302426,
#  'â\x80¦ â\x80¦ #': 384963,
#  'â\x80¦ # 2016in4wordsâ\x80¦': 384928,
#  'possible': 283169,
#  'live': 232806,
#  'dreams': 157252,
#  'wide': 373580,
#  'awake': 107864,
#  'family': 169427,
#  'la': 224056,
#  'familia': 169319,
#  'sis': 313477,
#  'possible live': 283192,
#  'live dreams': 232944,
#  'dreams wide': 157317,
#  'wide awake': 373581,
#  'awake #': 107865,
#  '# family': 19006,
#  'family #': 169434,
#  '# la': 27674,
#  'la familia': 224088,
#  'familia bihday': 169322,
#  'bihday sis': 117548,
#  'sis @': 313488,
#  'possible live dreams': 283193,
#  'live dreams wide': 232946,
#  'dreams wide awake': 157318,
#  'wide awake #': 373582,
#  'awake # family': 107869,
#  '# family #': 19008,
#  'family # la': 169498,
#  '# la familia': 27678,
#  'la familia bihday': 224089,
#  'familia bihday sis': 169323,
#  'bihday sis @': 117549,
#  'sis @ user': 313489,
#  'stfu': 322660,
#  'bitch': 118482,
#  'anything': 104030,
#  'wan': 366960,
#  'na': 257337,
#  'talk': 330739,
#  'shit': 310324,
#  'fucking': 182646,
#  'face': 168294,
#  'bro': 124313,
#  'stfu bitch': 322661,
#  'bitch ,': 118495,
#  ', u': 64064,
#  'u anything': 347799,
#  'anything wan': 104132,
#  'wan na': 366961,
#  'na talk': 257588,
#  'talk shit': 330818,
#  'shit ,': 310337,
#  ', come': 60131,
#  'come fucking': 137337,
#  'fucking face': 182683,
#  'face bro': 168353,
#  'bro #': 124316,
#  '# bitch': 10983,
#  'stfu bitch ,': 322662,
#  'bitch , u': 118497,
#  ', u anything': 64066,
#  'u anything wan': 347800,
#  'anything wan na': 104133,
#  'wan na talk': 366995,
#  'na talk shit': 257590,
#  'talk shit ,': 330819,
#  'shit , come': 310340,
#  ', come fucking': 60138,
#  'come fucking face': 137338,
#  'fucking face bro': 182684,
#  'face bro #': 168354,
#  'bro # bitch': 124317,
#  'still': 322711,
#  "n't": 255456,
#  'said': 301968,
#  'town': 342744,
#  'made': 240023,
#  'orlando': 270948,
#  'user still': 360086,
#  "still n't": 322949,
#  "n't said": 256788,
#  'said shit': 302089,
#  'shit town': 310421,
#  'town made': 342770,
#  'made .': 240053,
#  '# orlando': 34547,
#  '@ user still': 91759,
#  "user still n't": 360097,
#  "still n't said": 322960,
#  "n't said shit": 256791,
#  'said shit town': 302090,
#  'shit town made': 310422,
#  'town made .': 342771,
#  'made . #': 240054,
#  '. # orlando': 67106,
#  'alice': 98174,
#  ')': 57655,
#  'doggy': 155435,
#  'petstagram': 277682,
#  'instapets': 214599,
#  'pet': 277580,
#  'pets': 277657,
#  'dog': 155248,
#  'dogs': 155472,
#  'lovely': 238246,
#  'loveit': 238149,
#  'alice )': 98175,
#  ') )': 57867,
#  ') #': 57663,
#  '# doggy': 16879,
#  'doggy #': 155436,
#  '# petstagram': 35600,
#  'petstagram #': 277683,
#  '# instapets': 25819,
#  'instapets #': 214600,
#  '# pet': 35573,
#  'pet #': 277581,
#  '# pets': 35594,
#  'pets #': 277658,
#  '# dog': 16845,
#  'dog #': 155251,
#  '# dogs': 16895,
#  'dogs #': 155473,
#  '# lovely': 29433,
#  'lovely #': 238250,
#  '# loveit': 29402,
#  'loveit #': 238150,
#  '# â\x80¦': 49163,
#  'alice ) )': 98176,
#  ') ) )': 57871,
#  ') ) #': 57868,
#  ') # doggy': 57708,
#  '# doggy #': 16880,
#  'doggy # #': 155437,
#  '# # petstagram': 6347,
#  '# petstagram #': 35601,
#  'petstagram # instapets': 277684,
#  '# instapets #': 25820,
#  'instapets # pet': 214601,
#  '# pet #': 35574,
#  'pet # pets': 277585,
#  '# pets #': 35595,
#  'pets # dog': 277661,
#  '# dog #': 16847,
#  'dog # dogs': 155264,
#  '# dogs #': 16896,
#  'dogs # lovely': 155488,
#  '# lovely #': 29434,
#  'lovely # loveit': 238260,
#  '# loveit #': 29403,
#  'loveit # â\x80¦': 238167,
#  'slimandsassy': 314698,
#  'doterra': 156489,
#  'great': 195217,
#  'aicle': 97331,
#  'essentialoils': 163700,
#  'weightloss': 371458,
#  '# slimandsassy': 40857,
#  'slimandsassy #': 314699,
#  '# doterra': 17111,
#  'doterra great': 156492,
#  'great aicle': 195303,
#  'aicle @': 97342,
#  '# essentialoils': 18356,
#  'essentialoils #': 163701,
#  '# weightloss': 47382,
#  '# slimandsassy #': 40858,
#  'slimandsassy # doterra': 314700,
#  '# doterra great': 17113,
#  'doterra great aicle': 156493,
#  'great aicle @': 195306,
#  'aicle @ user': 97343,
#  'user # essentialoils': 351890,
#  '# essentialoils #': 18357,
#  'essentialoils # weightloss': 163703,
#  'song': 317935,
#  'f*cking': 168113,
#  'awesome': 108191,
#  'thrilled': 337459,
#  'album': 97913,
#  'cantwait': 128496,
#  'palyhappy': 273365,
#  'song f*cking': 317992,
#  'f*cking awesome': 168114,
#  'awesome ,': 108242,
#  'im thrilled': 211880,
#  'thrilled album': 337469,
#  'album !': 97914,
#  '# cantwait': 12839,
#  'cantwait #': 128497,
#  '# palyhappy': 34954,
#  'song f*cking awesome': 317993,
#  'f*cking awesome ,': 168115,
#  'awesome , im': 108243,
#  ', im thrilled': 61464,
#  'im thrilled album': 211881,
#  'thrilled album !': 337470,
#  'album ! #': 97916,
#  '! # cantwait': 759,
#  '# cantwait #': 12840,
#  'cantwait # palyhappy': 128511,
#  'bestsellers': 115710,
#  'inspiration': 213949,
#  'golf': 191766,
#  'never': 260173,
#  'go': 189777,
#  'bed': 113520,
#  'without': 375052,
#  'dream': 157104,
#  'wakeup': 366541,
#  'hope': 207596,
#  "''": 50360,
#  '# bestsellers': 10558,
#  'bestsellers #': 115711,
#  '# inspiration': 25629,
#  'inspiration #': 213952,
#  '# golf': 22188,
#  'golf ``': 191774,
#  '`` never': 93414,
#  'never go': 260335,
#  'go bed': 189952,
#  'bed without': 113599,
#  'without #': 375055,
#  '# dream': 17219,
#  'dream wakeup': 157197,
#  'wakeup without': 366551,
#  '# hope': 24387,
#  "hope ''": 207618,
#  'user # bestsellers': 351666,
#  '# bestsellers #': 10559,
#  'bestsellers # inspiration': 115712,
#  '# inspiration #': 25631,
#  'inspiration # golf': 213964,
#  '# golf ``': 22190,
#  'golf `` never': 191775,
#  '`` never go': 93416,
#  'never go bed': 260337,
#  'go bed without': 189960,
#  'bed without #': 113600,
#  ...}

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'hidden_layer_sizes': [(10,)],
    'activation': ['tanh']
}

mlpc = MLPClassifier()
grid_search = GridSearchCV(mlpc,
                           param_grid,
                           cv=5,
                           scoring='roc_auc',
                           verbose=20,
                           refit=True,
                           n_jobs=-1)

# %%
grid_search.fit(X_train_v, y_train)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 24.6min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed: 25.7min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 26.6min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 29.4min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 30.3min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 31.0min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 32.1min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 51.5min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 55.6min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 57.2min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 57.5min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 57.9min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 59.2min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 87.6min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 89.7min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 94.5min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 94.7min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 96.7min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 100.2min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 101.4min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 105.2min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 109.3min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 110.6min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 113.5min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 113.7min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 115.4min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 116.1min
# /home/rodixxi/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 117.3min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 118.3min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 121.5min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 121.6min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 158.1min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 164.7min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 165.1min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 166.3min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 167.2min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 173.1min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 173.5min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 181.6min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 182.5min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 182.8min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 182.8min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 188.7min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 188.9min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 189.3min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 189.4min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 191.1min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 191.2min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 192.8min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 195.8min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 197.1min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 197.6min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 198.3min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 201.6min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 205.7min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 210.6min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 212.6min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 227.2min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 239.2min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 242.2min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 247.4min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 257.5min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 258.2min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 271.2min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 272.5min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 273.1min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 281.8min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 285.4min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 290.1min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 290.1min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 291.0min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 294.1min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 294.9min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 295.8min
# [Parallel(n_jobs=-1)]: Done  90 out of  96 | elapsed: 307.7min remaining: 20.5min
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed: 350.3min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'hidden_layer_sizes': [(10,), (5, 5), (2, 2), (10, 2)], 'activation': ['tanh', 'relu'], 'alpha': [0.0001, 0.05], 'learning_rate': ['constant', 'adaptive']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=20)

# %%
grid_search.best_params_
# Out:
# {'activation': 'tanh',
#  'alpha': 0.0001,
#  'hidden_layer_sizes': (10,),
#  'learning_rate': 'constant'}

# %%
mlp_clf = grid_search.best_estimator_

# %%
#mlp_clf.fit(X_train_v, y_train)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, classification_report

# %%
y_pred = mlp_clf.predict(X_test_v)

# %%
#confusion_matrix(y_test, y_pred)

# %%
print("roc_auc score: {}".format(roc_auc_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# roc_auc score: 0.7611220413312508
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5945
#            1       0.90      0.53      0.66       448
#
#    micro avg       0.96      0.96      0.96      6393
#    macro avg       0.93      0.76      0.82      6393
# weighted avg       0.96      0.96      0.96      6393

# %%
X_all = vectorizer.transform(X)
y_all = y

# %%
mlp_clf.fit(X_all, y_all)
# Out:
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
df_test = pd.read_csv("dataset/test.csv")

# %%
df_test.sample(5)
# Out:
#          id                                              tweet
# 4053  36016   @user so the @user can remove saudi arabia fr...
# 9188  41151  so sad that i missed the #youtubespacemum happ...
# 1244  33207  today is a perfect day to be  ! #happiness #li...
# 6163  38126   @user _animaladvocate:  wilko_val: these b#st...
# 3110  35073  @user #feminismiscancer #feminismisterrorism #...

# %%
dtest = vectorizer.transform(df_test['tweet'])
test_pred = mlp_clf.predict(dtest)

# %%
df_test['label'] = test_pred

# %%
submission = df_test[['id','label']]

# %%
submission.to_csv('sub_rodixxi_mlpC_GS.csv', index=False)
