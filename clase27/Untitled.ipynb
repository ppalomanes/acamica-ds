# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv", index_col=0)

# %%
df.sample(5)
# Out:
#        label                                              tweet
# id
# 15472      0   â #turkey quaerly gross domestic product de...
# 8670       0   @user @user they are the #silent #majority &a...
# 21804      0  we gotta stay humble sy...sike who i'm kidding...
# 5535       0  #beutiful poetry   poetry  #2 lines poetry  #e...
# 29743      0  how utterly pathetic. wish ali was around to b...

# %%
df["label"].unique()
# Out:
# array([0, 1])

# %%
df["tweet"].nunique()
# Out:
# 29530

# %%
df.size
# Out:
# 63924

# %%
df["tweet"].value_counts()
# Out:
# #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦                                                     319
# i finally found a way how to delete old tweets! you might find it useful as well:    #deletetweets                                        82
# aww yeah it's all good bing bong bing bong                                                                                                75
# i'm so   and #grateful now that - #affirmations                                                                                           56
# @user you might be a libtard if... #libtard  #sjw #liberal #politics                                                                      40
# you might be a libtard if... #libtard  #sjw #liberal #politics                                                                            32
# ð #love #instagood #photooftheday top.tags #tbt #cute #me #beautiful #followme   #followâ¦                                            29
# have my lover stop being angry at me visit us..&gt;&gt;&gt;  #lover   #friend #astrologer #love                                           26
# #flagday2016   #flag #day #2016 #(30 #photos) buy things about "flag day 2016": â¦                                                       22
# get #up get   get  #enjoy #music #today #free #apps #free #music                                                                          21
# #sikh #temple vandalised in in #calgary, #wso condemns  act                                                                               20
# @user #feminismiscancer #feminismisterrorism #feminismmuktbharat why  #malevote is ignored  @user                                         20
# save $$ no logins x brokers   #me #change #memes #love   #education #university                                                           17
# can #lighttherapy help with   or #depression?    #altwaystoheal  #healthy is #happy !!                                                    16
# can #lighttherapy help with   or #depression?   #altwaystoheal #healthy is #happy !!                                                      14
# best #essentialoils for #anxiety !!     #healthy   #peace !!  #altwaystoheal !!                                                           14
# #music as #therapy as a tool for #healing!   #altwaystoheal #healthy is  !!                                                               14
# safe ways to heal your #acne!!    #altwaystoheal #healthy   #healing!!                                                                    14
# best essential oils for #healing!!    #altwaystoheal #healthy  !!                                                                         14
# does #magnettherapy really work?   #altwaystoheal #healing #healthy   !!                                                                  14
# what is a #detoxdiet?  #altwaystoheal! #healthy  !                                                                                        14
# looking to feel more #joy? join me and 20 speakers on the free summit #unleashyourjoy                                                     13
# herbal sleep remedies that work!!  #altwaystoheal #healthy #healing   !!                                                                  13
# best #lawofattraction #resources for #healing!    #altwaystoheal #healthy is  ! #idwp !                                                   13
# can #lighttherapy help with #sad or #depression?    #altwaystoheal  #healthy is   !!                                                      12
# #lawofattraction for #healing!!    #altwaystoheal #healthy is  !!                                                                         12
# #raw food diet benefits! -    #altwaystoheal #healthy   #healing #peace #joy #love !!                                                     12
#   happy day!  #altwaystoheal  #healthy                                                                                                    11
# best #essentialoils for #anxiety !!     #healthy   #peace !! #altwaystoheal !!                                                            11
# #saysomething   bull up: you will dominate your bull and you will direct it whatever you want it to do. when                              11
#                                                                                                                                         ...
# @user i'll be missing you #champ #thegreatest                                                                                              1
# "kscrashcorrectors: "flcrashcorrectors: "flcrashcorrectors: "lopezchiro:   #father'sday from #lopez #family #â¦                           1
# "#trump won because #politicalcorrectness has gone too far."  you know what you never heard? "#obama won because  has gone too far."       1
# hello there sweetie! ð i will be glad to see you here ï¸ð                                                                           1
# i fail to understand how, in this day, people can believe that race or sexual orientation can define a person as bad or wrong. #smh        1
# now playing  :  eiko yamashita - " eternal dream" on     music song                                                                        1
# what a digital world we live in....                                                                                                        1
# .. mais ou est @user  doe?                                                                                                                 1
# come on england!!!! #euro2016 #engvrus   #nervous ððððâ½ï¸â½ï¸â½ï¸â½ï¸                                                 1
# are you #black &amp; feel like the  â¦ stomping on you? listen  #retweet #tampa #miamiâ¦                                                 1
# @user a bit of heabreak too! #reflective                                                                                                   1
# judge a man by his questions rather than his answers.  voltaire #wisdom #leadership  #quote #inspirational                                 1
# @user just words-fake words in this case    gather around her false light children and you will die                                        1
#  @user damon forum, listas!!! #ohodontics #oos #friends #fun   #dentist @ westin santa fe,â¦                                              1
# @user your comments about  mrs. obama are offensive and fuher confirm that you are a racist jackass.  #idiot                               1
# thank you for following @user it's nice to meet you. ð·#friends   tuesday ð                                                           1
# #teenageson reckons that he's gone 'beyond the call of duty' with my #fathersday prezzie    ð                                           1
# #enteainmentsystem   gorilla simulator: you need to do to adapt to the environment. the need to tear the c                                 1
# pretty decent game so far                                                                                                                  1
# life is too sho to be anything but  . salam #ramadhan everybody. #bekindtooneanotherâ¦                                                    1
# extremely   to announce that the #nominations to #watctop50in rising star awards open on 1st aug! #pipeline                                1
# i've just had nearly 6 hours straight sleep. feel reborn. #sleepdeprivation #mumlife #wantmore   #love #babylife #sleeplikeababy           1
# if only i knew how to sleep                                                                                                                1
# i'm going to study international business and languages in september! #ibl #study   #qouteâ¦                                              1
#  â #cad cpi preview: what to expect of usd/cad   #blog #silver #gold #forex                                                              1
# tomorrow i am so excited to do my first music video. #bjmckenzie #bjmuzic   #norway                                                        1
# barbeque done pa 1ðð #together #family #unity #teamwork #friends #sister #brother   #funâ¦                                          1
# ascot times with this babe â¤ï¸â¤ï¸ #ascot #fashion #monochrome #style   #instahappyday                                                1
# #tgif   #ff to my #gamedev #indiedev #indiegamedev #squad! @user @user @user @user                                                         1
# what at an awful sta to the day. if the football continues my luck we'll get beaten 10-0 #gutted                                           1
# Name: tweet, Length: 29530, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df["tweet"]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /home/rcrespillo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vectorizer = TfidfVectorizer(analyzer='word', 
                             tokenizer=nltk.word_tokenize, 
                             stop_words=stops, 
                             ngram_range=(1,3))

X_train_v = vectorizer.fit_transform(X_train)
X_test_v = vectorizer.transform(X_test)

# %%
X_train_v.shape
# Out:
# (25569, 395407)

# %%
vectorizer.vocabulary_
# Out:
# {'arsenal': 33441,
#  ',': 19065,
#  'club': 42401,
#  'sets': 95022,
#  'ridiculed': 91828,
#  '.': 21372,
#  'arsenal ,': 33444,
#  ', club': 19527,
#  'club sets': 42418,
#  'sets ridiculed': 95027,
#  'ridiculed .': 91829,
#  'arsenal , club': 33445,
#  ', club sets': 19528,
#  'club sets ridiculed': 42419,
#  'sets ridiculed .': 95028,
#  'monday': 77382,
#  'sta': 98714,
#  'workout': 115987,
#  'routine': 92499,
#  '!': 0,
#  'got': 60034,
#  'ta': 101421,
#  'get': 57834,
#  '#': 1873,
#  'summer': 100348,
#  'staed': 98810,
#  'â\x98\x80ï¸\x8fð\x9f\x92ªð\x9f\x8f': 118272,
#  '»': 117825,
#  'ð\x9f\x92ªð\x9f\x8f': 119797,
#  'monday sta': 77432,
#  'sta workout': 98797,
#  'workout routine': 115995,
#  'routine !': 92500,
#  '! got': 1047,
#  'got ta': 60195,
#  'ta get': 101428,
#  'get #': 57837,
#  '# summer': 14059,
#  'summer workout': 100451,
#  'workout staed': 115999,
#  'staed !': 98811,
#  '! â\x98\x80ï¸\x8fð\x9f\x92ªð\x9f\x8f': 1588,
#  'â\x98\x80ï¸\x8fð\x9f\x92ªð\x9f\x8f »': 118273,
#  '» ð\x9f\x92ªð\x9f\x8f': 117925,
#  'ð\x9f\x92ªð\x9f\x8f »': 119798,
#  'monday sta workout': 77433,
#  'sta workout routine': 98798,
#  'workout routine !': 115996,
#  'routine ! got': 92501,
#  '! got ta': 1051,
#  'got ta get': 60198,
#  'ta get #': 101429,
#  'get # summer': 57845,
#  '# summer workout': 14065,
#  'summer workout staed': 100452,
#  'workout staed !': 116000,
#  'staed ! â\x98\x80ï¸\x8fð\x9f\x92ªð\x9f\x8f': 98812,
#  '! â\x98\x80ï¸\x8fð\x9f\x92ªð\x9f\x8f »': 1589,
#  'â\x98\x80ï¸\x8fð\x9f\x92ªð\x9f\x8f » ð\x9f\x92ªð\x9f\x8f': 118274,
#  '» ð\x9f\x92ªð\x9f\x8f »': 117926,
#  '@': 28062,
#  'user': 108094,
#  'fantastic': 52838,
#  'prize': 88231,
#  'familytreat': 52731,
#  'winitwednesday': 115027,
#  '@ user': 28277,
#  'user fantastic': 109342,
#  'fantastic prize': 52843,
#  'prize !': 88232,
#  '! !': 1,
#  '! #': 178,
#  '# familytreat': 6154,
#  'familytreat #': 52732,
#  '# winitwednesday': 15861,
#  '@ user fantastic': 28614,
#  'user fantastic prize': 109343,
#  'fantastic prize !': 52844,
#  'prize ! !': 88233,
#  '! ! !': 2,
#  '! ! #': 3,
#  '! # familytreat': 333,
#  '# familytreat #': 6155,
#  'familytreat # winitwednesday': 52733,
#  "'ve": 18426,
#  'delayed': 46868,
#  'flight': 54915,
#  'even': 51022,
#  'disgusting': 47848,
#  'service': 94936,
#  'provide': 88687,
#  'suppo': 100920,
#  'staff': 98840,
#  'assist': 33659,
#  'depaures': 47071,
#  "user 've": 108512,
#  "'ve delayed": 18441,
#  'delayed flight': 46875,
#  'flight even': 54927,
#  'even !': 51023,
#  '! disgusting': 942,
#  'disgusting service': 47853,
#  'service provide': 94953,
#  'provide .': 88688,
#  '. suppo': 23162,
#  'suppo staff': 100948,
#  'staff assist': 98852,
#  'assist depaures': 33660,
#  "@ user 've": 28290,
#  "user 've delayed": 108514,
#  "'ve delayed flight": 18442,
#  'delayed flight even': 46876,
#  'flight even !': 54928,
#  'even ! disgusting': 51024,
#  '! disgusting service': 943,
#  'disgusting service provide': 47855,
#  'service provide .': 94954,
#  'provide . suppo': 88689,
#  '. suppo staff': 23163,
#  'suppo staff assist': 100949,
#  'staff assist depaures': 98853,
#  'fathersday': 53203,
#  'thoughts': 103781,
#  'gay': 57528,
#  'non-dads': 81613,
#  'never': 80302,
#  'children': 41593,
#  'thankfully': 102915,
#  'things': 103362,
#  'changing': 41178,
#  'loss': 72894,
#  'lgbt': 70732,
#  'orlando': 83564,
#  '# fathersday': 6237,
#  'fathersday thoughts': 53272,
#  'thoughts #': 103782,
#  '# gay': 7008,
#  'gay non-dads': 57556,
#  'non-dads .': 81614,
#  '. never': 22827,
#  'never got': 80350,
#  'got children': 60074,
#  'children .': 41605,
#  '. thankfully': 23192,
#  'thankfully ,': 102916,
#  ', things': 20707,
#  'things changing': 103381,
#  'changing #': 41179,
#  '# loss': 9584,
#  'loss #': 72897,
#  '# lgbt': 9277,
#  'lgbt #': 70733,
#  '# orlando': 11361,
#  '# fathersday thoughts': 6256,
#  'fathersday thoughts #': 53273,
#  'thoughts # gay': 103783,
#  '# gay non-dads': 7012,
#  'gay non-dads .': 57557,
#  'non-dads . never': 81615,
#  '. never got': 22829,
#  'never got children': 80351,
#  'got children .': 60075,
#  'children . thankfully': 41608,
#  '. thankfully ,': 23193,
#  'thankfully , things': 102917,
#  ', things changing': 20708,
#  'things changing #': 103382,
#  'changing # loss': 41180,
#  '# loss #': 9585,
#  'loss # lgbt': 72898,
#  '# lgbt #': 9278,
#  'lgbt # orlando': 70738,
#  'travel': 105658,
#  'sunday': 100571,
#  'family': 52596,
#  'couple': 44190,
#  'life': 70875,
#  'chiangmai': 41490,
#  'thailand': 102641,
#  'â\x80¦': 118139,
#  'travel sunday': 105694,
#  'sunday family': 100622,
#  'family #': 52599,
#  '# travel': 14892,
#  'travel #': 105659,
#  '# couple': 4747,
#  'couple #': 44191,
#  '# family': 6136,
#  '# life': 9316,
#  'life #': 70880,
#  '# chiangmai': 4278,
#  'chiangmai #': 41491,
#  '# thailand': 14492,
#  'thailand â\x80¦': 102644,
#  'travel sunday family': 105695,
#  'sunday family #': 100623,
#  'family # travel': 52630,
#  '# travel #': 14893,
#  'travel # couple': 105664,
#  '# couple #': 4748,
#  'couple # family': 44196,
#  '# family #': 6137,
#  'family # life': 52621,
#  '# life #': 9317,
#  'life # chiangmai': 70890,
#  '# chiangmai #': 4279,
#  'chiangmai # thailand': 41492,
#  '# thailand â\x80¦': 14494,
#  'feeling': 53619,
#  'horrible': 64487,
#  'people': 85040,
#  'florida': 55024,
#  '...': 23598,
#  'sorry': 98102,
#  'prayfororlando': 87709,
#  'user feeling': 109366,
#  'feeling horrible': 53669,
#  'horrible people': 64507,
#  'people orlando': 85252,
#  'orlando florida': 83621,
#  'florida ...': 55033,
#  '... #': 23602,
#  '# sorry': 13713,
#  'sorry #': 98103,
#  '# prayfororlando': 12075,
#  '@ user feeling': 28623,
#  'user feeling horrible': 109370,
#  'feeling horrible people': 53671,
#  'horrible people orlando': 64508,
#  'people orlando florida': 85253,
#  'orlando florida ...': 83622,
#  'florida ... #': 55034,
#  '... # sorry': 23668,
#  '# sorry #': 13714,
#  'sorry # prayfororlando': 98104,
#  'allahsoil': 31206,
#  'many': 74997,
#  'politicians': 86956,
#  'claim': 42027,
#  'jihad': 67522,
#  'attack': 33775,
#  'humanity': 65002,
#  'teambtsâ\x80¦': 102136,
#  'user #': 108105,
#  '# allahsoil': 2464,
#  'allahsoil many': 31229,
#  'many politicians': 75072,
#  'politicians claim': 86961,
#  'claim jihad': 42030,
#  'jihad attack': 67523,
#  'attack humanity': 33795,
#  'humanity â\x80¦': 65011,
#  'â\x80¦ #': 118140,
#  '# teambtsâ\x80¦': 14391,
#  '@ user #': 28279,
#  'user # allahsoil': 108119,
#  '# allahsoil many': 2476,
#  'allahsoil many politicians': 31230,
#  'many politicians claim': 75073,
#  'politicians claim jihad': 86962,
#  'claim jihad attack': 42031,
#  'jihad attack humanity': 67524,
#  'attack humanity â\x80¦': 33796,
#  'humanity â\x80¦ #': 65012,
#  'â\x80¦ # teambtsâ\x80¦': 118149,
#  'ca': 39610,
#  "n't": 78856,
#  'help': 63342,
#  'thank': 102648,
#  'awesomeness': 34271,
#  'cwc': 45190,
#  'network': 80288,
#  '32': 25637,
#  'amazing': 31762,
#  "ca n't": 39614,
#  "n't help": 79102,
#  'help thank': 63389,
#  'thank @': 102673,
#  'user @': 108688,
#  'user awesomeness': 108834,
#  'awesomeness #': 34272,
#  '# cwc': 4938,
#  'cwc network': 45191,
#  'network .': 80289,
#  '. 32': 22008,
#  '32 amazing': 25638,
#  'amazing .': 31787,
#  "ca n't help": 39639,
#  "n't help thank": 79103,
#  'help thank @': 63390,
#  'thank @ user': 102674,
#  '@ user @': 28341,
#  'user @ user': 108691,
#  '@ user awesomeness': 28396,
#  'user awesomeness #': 108835,
#  'awesomeness # cwc': 34273,
#  '# cwc network': 4939,
#  'cwc network .': 45192,
#  'network . 32': 80290,
#  '. 32 amazing': 22009,
#  '32 amazing .': 25639,
#  'tuxedo': 106586,
#  'pay/gift': 84809,
#  'favor': 53352,
#  'bag': 34841,
#  'great': 60537,
#  'wedding': 113684,
#  'sandyscandybags': 93212,
#  'via': 111682,
#  'father': 53046,
#  "'s": 17566,
#  'day': 45814,
#  'tuxedo pay/gift': 106587,
#  'pay/gift favor': 84810,
#  'favor bag': 53353,
#  'bag great': 34853,
#  'great wedding': 60699,
#  'wedding sandyscandybags': 113717,
#  'sandyscandybags via': 93213,
#  'via @': 111692,
#  'user father': 109348,
#  "father 's": 53057,
#  "'s day": 17797,
#  'tuxedo pay/gift favor': 106588,
#  'pay/gift favor bag': 84811,
#  'favor bag great': 53354,
#  'bag great wedding': 34854,
#  'great wedding sandyscandybags': 60700,
#  'wedding sandyscandybags via': 113718,
#  'sandyscandybags via @': 93214,
#  'via @ user': 111693,
#  '@ user father': 28616,
#  "user father 's": 109349,
#  "father 's day": 53061,
#  'stay': 99129,
#  'tuned': 106479,
#  'saint': 93052,
#  'issue': 67031,
#  '4': 25745,
#  'printers': 88201,
#  'comics': 43031,
#  'makecomics': 74551,
#  'user stay': 110704,
#  'stay tuned': 99158,
#  'tuned !': 106480,
#  '! saint': 1362,
#  'saint issue': 93053,
#  'issue #': 67032,
#  '# 4': 2175,
#  '4 printers': 25801,
#  'printers !': 88202,
#  '# comics': 4582,
#  'comics #': 43034,
#  '# makecomics': 9839,
#  '@ user stay': 29144,
#  'user stay tuned': 110705,
#  'stay tuned !': 99159,
#  'tuned ! saint': 106481,
#  '! saint issue': 1363,
#  'saint issue #': 93054,
#  'issue # 4': 67033,
#  '# 4 printers': 2177,
#  '4 printers !': 25802,
#  'printers ! #': 88203,
#  '! # comics': 268,
#  '# comics #': 4583,
#  'comics # makecomics': 43036,
#  'wonder': 115519,
#  'glass': 58796,
#  'half': 61614,
#  'empty': 50109,
#  'full': 56782,
#  'miss': 76820,
#  'point': 86825,
#  'refillable': 90735,
#  'user people': 110300,
#  'people wonder': 85321,
#  'wonder glass': 115526,
#  'glass half': 58797,
#  'half empty': 61625,
#  'empty half': 50118,
#  'half full': 61627,
#  'full ,': 56787,
#  ', miss': 20189,
#  'miss point': 76872,
#  'point .': 86828,
#  '. glass': 22453,
#  'glass refillable': 58801,
#  'refillable .': 90736,
#  '. #': 21375,
#  '@ user people': 28968,
#  'user people wonder': 110306,
#  'people wonder glass': 85322,
#  'wonder glass half': 115527,
#  'glass half empty': 58798,
#  'half empty half': 61626,
#  'empty half full': 50119,
#  'half full ,': 61628,
#  'full , miss': 56788,
#  ', miss point': 20191,
#  'miss point .': 76873,
#  'point . glass': 86829,
#  '. glass refillable': 22454,
#  'glass refillable .': 58802,
#  'refillable . #': 90737,
#  '. # travel': 21788,
#  "'m": 17072,
#  'lazy': 70001,
#  'christian': 41809,
#  'cause': 40717,
#  'think': 103444,
#  'kids': 68567,
#  'taken': 101627,
#  'thought': 103724,
#  'crime': 44626,
#  'twitter': 106741,
#  'posts': 87384,
#  'lmao': 72251,
#  "'m lazy": 17217,
#  'lazy christian': 70006,
#  'christian cause': 41813,
#  "cause n't": 40743,
#  "n't think": 79349,
#  'think kids': 103534,
#  'kids taken': 68632,
#  'taken thought': 101642,
#  'thought crime': 103743,
#  'crime twitter': 44632,
#  'twitter posts': 106787,
#  'posts ,': 87387,
#  ', lmao': 20086,
#  'lmao .': 72252,
#  "'m lazy christian": 17218,
#  'lazy christian cause': 70007,
#  "christian cause n't": 41814,
#  "cause n't think": 40744,
#  "n't think kids": 79355,
#  'think kids taken': 103535,
#  'kids taken thought': 68633,
#  'taken thought crime': 101643,
#  'thought crime twitter': 103744,
#  'crime twitter posts': 44633,
#  'twitter posts ,': 106788,
#  'posts , lmao': 87389,
#  ', lmao .': 20087,
#  'happiness': 61918,
#  'wake': 112682,
#  'go': 58882,
#  'beach': 35405,
#  'ð\x9f\x98\x8d': 120265,
#  'goodday': 59807,
#  'goodmorningâ\x80¦': 59859,
#  'happiness wake': 61987,
#  'wake go': 112705,
#  'go beach': 58943,
#  'beach ð\x9f\x98\x8d': 35452,
#  'ð\x9f\x98\x8d #': 120266,
#  '# happiness': 7673,
#  'happiness #': 61921,
#  '# goodday': 7322,
#  'goodday #': 59810,
#  '# goodmorningâ\x80¦': 7339,
#  'happiness wake go': 61988,
#  'wake go beach': 112706,
#  'go beach ð\x9f\x98\x8d': 58944,
#  'beach ð\x9f\x98\x8d #': 35453,
#  'ð\x9f\x98\x8d # happiness': 120274,
#  '# happiness #': 7674,
#  'happiness # goodday': 61928,
#  '# goodday #': 7324,
#  'goodday # goodmorningâ\x80¦': 59813,
#  'happier': 61891,
#  'long': 72488,
#  'time': 104103,
#  'finally': 54157,
#  'yay': 116795,
#  'happier long': 61902,
#  'long time': 72539,
#  'time .': 104140,
#  '# finally': 6421,
#  'finally #': 54165,
#  '# yay': 16107,
#  'happier long time': 61903,
#  'long time .': 72541,
#  'time . #': 104141,
#  '. # finally': 21510,
#  '# finally #': 6422,
#  'finally # yay': 54169,
#  'one': 82843,
#  'word': 115668,
#  '-': 20931,
#  'coward': 44317,
#  'victims': 111763,
#  'families': 52557,
#  'orlandoshooting': 83679,
#  'one word': 83085,
#  'word -': 115679,
#  '- coward': 21060,
#  'coward .': 44318,
#  '. thoughts': 23214,
#  'thoughts victims': 103800,
#  'victims ,': 111771,
#  ', families': 19744,
#  'families .': 52561,
#  'orlando #': 83567,
#  '# orlandoshooting': 11380,
#  'one word -': 83086,
#  'word - coward': 115680,
#  '- coward .': 21061,
#  'coward . thoughts': 44319,
#  '. thoughts victims': 23217,
#  'thoughts victims ,': 103801,
#  'victims , families': 111772,
#  ', families .': 19745,
#  'families . #': 52562,
#  '. # orlando': 21664,
#  '# orlando #': 11362,
#  'orlando # orlandoshooting': 83578,
#  'ð\x9f\x87¬ð\x9f\x87§': 118873,
#  'london': 72420,
#  'soon': 98005,
#  'ð\x9f\x87¬ð\x9f\x87§ london': 118876,
#  'london ð\x9f\x87¬ð\x9f\x87§': 72459,
#  'ð\x9f\x87¬ð\x9f\x87§ #': 118874,
#  '# soon': 13708,
#  'soon #': 98013,
#  'ð\x9f\x87¬ð\x9f\x87§ london ð\x9f\x87¬ð\x9f\x87§': 118877,
#  'london ð\x9f\x87¬ð\x9f\x87§ #': 72460,
#  'ð\x9f\x87¬ð\x9f\x87§ # soon': 118875,
#  '# soon #': 13709,
#  'soon # summer': 98018,
#  'aware': 34141,
#  'facebook': 52296,
#  'legislature': 70446,
#  "n't aware": 78917,
#  'aware facebook': 34146,
#  'facebook legislature': 52310,
#  'legislature .': 70447,
#  "n't aware facebook": 78918,
#  'aware facebook legislature': 34147,
#  'facebook legislature .': 52311,
#  'fuji': 56773,
#  'mountfuji': 78011,
#  'japan': 67340,
#  'japanð\x9f\x87¯ð\x9f\x87µ': 67368,
#  'travelphotography': 105721,
#  'traveltheworld': 105725,
#  'mountâ\x80¦': 78014,
#  '# fuji': 6858,
#  'fuji #': 56774,
#  '# mountfuji': 10453,
#  'mountfuji #': 78012,
#  '# japan': 8694,
#  'japan #': 67341,
#  '# japanð\x9f\x87¯ð\x9f\x87µ': 8701,
#  'japanð\x9f\x87¯ð\x9f\x87µ #': 67369,
#  '# travelphotography': 14905,
#  'travelphotography #': 105722,
#  '# traveltheworld': 14907,
#  'traveltheworld #': 105726,
#  'life @': 70985,
#  '@ mountâ\x80¦': 28206,
#  '# fuji #': 6859,
#  'fuji # mountfuji': 56775,
#  '# mountfuji #': 10454,
#  'mountfuji # japan': 78013,
#  '# japan #': 8695,
#  'japan # japanð\x9f\x87¯ð\x9f\x87µ': 67345,
#  '# japanð\x9f\x87¯ð\x9f\x87µ #': 8702,
#  'japanð\x9f\x87¯ð\x9f\x87µ # travel': 67370,
#  'travel # travelphotography': 105675,
#  '# travelphotography #': 14906,
#  'travelphotography # traveltheworld': 105723,
#  '# traveltheworld #': 14908,
#  'traveltheworld # life': 105727,
#  '# life @': 9320,
#  'life @ mountâ\x80¦': 70986,
#  'wishing': 115192,
#  'friday': 56202,
#  'weekend': 113945,
#  '# wishing': 15891,
#  'wishing #': 115193,
#  '# great': 7450,
#  'great #': 60542,
#  '# friday': 6779,
#  'friday #': 56216,
#  '# weekend': 15676,
#  '# wishing #': 15892,
#  'wishing # great': 115195,
#  '# great #': 7451,
#  'great # friday': 60544,
#  '# friday #': 6781,
#  'friday # weekend': 56247,
#  'keep': 68230,
#  'truely': 106046,
#  'love': 73046,
#  'motivate': 77931,
#  'encourage': 50175,
#  'enhances': 50401,
#  '&': 16504,
#  'amp': 32047,
#  ';': 26995,
#  'makes': 74577,
#  'simple': 96299,
#  'ð\x9f\x91\x8cð\x9f\x8f¾ð\x9f\x91\x8að\x9f\x8f¾ð\x9f\x99\x8cð\x9f\x8f¾': 119389,
#  'keep people': 68290,
#  'people life': 85213,
#  'life truely': 71111,
#  'truely #': 106047,
#  '# love': 9599,
#  'love ,': 73205,
#  ', #': 19069,
#  '# motivate': 10421,
#  'motivate ,': 77934,
#  '# encourage': 5806,
#  'encourage ,': 50176,
#  '# enhances': 5847,
#  'enhances ,': 50402,
#  ', &': 19185,
#  '& amp': 16505,
#  'amp ;': 32048,
#  '; makes': 27380,
#  'makes #': 74580,
#  '# simple': 13411,
#  'simple ð\x9f\x91\x8cð\x9f\x8f¾ð\x9f\x91\x8að\x9f\x8f¾ð\x9f\x99\x8cð\x9f\x8f¾': 96315,
#  'keep people life': 68291,
#  'people life truely': 85215,
#  'life truely #': 71112,
#  'truely # love': 106048,
#  '# love ,': 9603,
#  'love , #': 73206,
#  ', # motivate': 19140,
#  '# motivate ,': 10423,
#  'motivate , #': 77935,
#  ', # encourage': 19096,
#  '# encourage ,': 5807,
#  'encourage , #': 50177,
#  ', # enhances': 19097,
#  '# enhances ,': 5848,
#  'enhances , &': 50403,
#  ', & amp': 19186,
#  '& amp ;': 16506,
#  'amp ; makes': 32188,
#  '; makes #': 27381,
#  'makes # simple': 74585,
#  '# simple ð\x9f\x91\x8cð\x9f\x8f¾ð\x9f\x91\x8að\x9f\x8f¾ð\x9f\x99\x8cð\x9f\x8f¾': 13412,
#  'protesting': 88605,
#  'trump': 106080,
#  'republican': 91290,
#  'won-they': 115516,
#  'fuhered': 56770,
#  '# people': 11644,
#  "people n't": 85240,
#  "n't protesting": 79241,
#  'protesting #': 88606,
#  '# trump': 14982,
#  'trump #': 106084,
#  '# republican': 12628,
#  'republican won-they': 91301,
#  'won-they trump': 115517,
#  'trump fuhered': 106123,
#  'fuhered &': 56771,
#  '; â\x80¦': 27597,
#  "# people n't": 11647,
#  "people n't protesting": 85243,
#  "n't protesting #": 79242,
#  'protesting # trump': 88607,
#  '# trump #': 14984,
#  'trump # republican': 106090,
#  '# republican won-they': 12629,
#  'republican won-they trump': 91302,
#  'won-they trump fuhered': 115518,
#  'trump fuhered &': 106124,
#  'fuhered & amp': 56772,
#  'amp ; â\x80¦': 32292,
#  'playlist': 86567,
#  'playtime': 86589,
#  'ready': 90046,
#  'diverse': 48012,
#  'sweet': 101241,
#  'like': 71282,
#  'peopleâ\x80¦': 85342,
#  '# playlist': 11863,
#  'playlist #': 86570,
#  '# playtime': 11865,
#  'playtime ready': 86592,
#  'ready .': 90063,
#  '# diverse': 5329,
#  'diverse #': 48013,
#  '# sweet': 14229,
#  'sweet ...': 101250,
#  '... like': 23932,
#  'like peopleâ\x80¦': 71475,
#  '# playlist #': 11864,
#  'playlist # playtime': 86571,
#  '# playtime ready': 11866,
#  'playtime ready .': 86593,
#  'ready . #': 90064,
#  '. # diverse': 21471,
#  '# diverse #': 5330,
#  'diverse # sweet': 48014,
#  '# sweet ...': 14231,
#  'sweet ... like': 101251,
#  '... like peopleâ\x80¦': 23933,
#  'nah': 79591,
#  'creates': 44545,
#  'lie': 70844,
#  'ignores': 65474,
#  'request': 91317,
#  'prove': 88669,
#  'truth': 106232,
#  'user nah': 110134,
#  'nah ,': 79594,
#  ', @': 19309,
#  'user creates': 109132,
#  'creates lie': 44546,
#  'lie ignores': 70854,
#  'ignores request': 65475,
#  'request prove': 91320,
#  'prove truth': 88670,
#  'truth .': 106243,
#  '. @': 22033,
#  '@ user nah': 28906,
#  'user nah ,': 110135,
#  'nah , @': 79595,
#  ', @ user': 19310,
#  '@ user creates': 28520,
#  'user creates lie': 109133,
#  'creates lie ignores': 44547,
#  'lie ignores request': 70855,
#  'ignores request prove': 65476,
#  'request prove truth': 91321,
#  'prove truth .': 88671,
#  'truth . @': 106245,
#  '. @ user': 22036,
#  'minipin': 76700,
#  'madrid': 74216,
#  'spain': 98275,
#  '# minipin': 10200,
#  'minipin @': 76701,
#  '@ madrid': 28193,
#  'madrid ,': 74222,
#  ', spain': 20610,
#  '# minipin @': 10201,
#  'minipin @ madrid': 76702,
#  '@ madrid ,': 28194,
#  'madrid , spain': 74223,
#  'â\x80\x9cand': 118084,
#  'make': 74377,
#  '?': 27641,
#  'though': 103694,
#  'nothing': 81766,
#  'youâ\x80\x99ve': 117447,
#  'everything': 51530,
#  'find': 54256,
#  'kind': 68778,
#  'hâ\x80¦': 65218,
#  'user â\x80\x9cand': 111265,
#  'â\x80\x9cand make': 118085,
#  'make ?': 74402,
#  '? even': 27860,
#  'even though': 51131,
#  'though nothing': 103718,
#  'nothing ,': 81773,
#  ', youâ\x80\x99ve': 20911,
#  'youâ\x80\x99ve got': 117448,
#  'got everything': 60089,
#  'everything !': 51531,
#  '! find': 994,
#  'find kind': 54300,
#  'kind hâ\x80¦': 68803,
#  '@ user â\x80\x9cand': 29355,
#  'user â\x80\x9cand make': 111266,
#  'â\x80\x9cand make ?': 118086,
#  'make ? even': 74404,
#  '? even though': 27862,
#  'even though nothing': 51134,
#  'though nothing ,': 103719,
#  'nothing , youâ\x80\x99ve': 81776,
#  ', youâ\x80\x99ve got': 20912,
#  'youâ\x80\x99ve got everything': 117449,
#  'got everything !': 60090,
#  'everything ! find': 51533,
#  '! find kind': 996,
#  'find kind hâ\x80¦': 54301,
#  'content': 43637,
#  'w/': 112392,
#  'atm': 33765,
#  'user content': 109104,
#  'content w/': 43651,
#  'w/ life': 112407,
#  'life atm': 70992,
#  '@ user content': 28509,
#  'user content w/': 109105,
#  'content w/ life': 43652,
#  'w/ life atm': 112408,
#  'omg': 82786,
#  'definitely': 46824,
#  'fairytail': 52456,
#  'ayesir': 34337,
#  'user omg': 110235,
#  'omg definitely': 82803,
#  'definitely #': 46825,
#  '# fairytail': 6115,
#  'fairytail #': 52457,
#  '# ayesir': 2917,
#  'ayesir #': 34338,
#  '@ user omg': 28940,
#  'user omg definitely': 110239,
#  'omg definitely #': 82804,
#  'definitely # fairytail': 46826,
#  '# fairytail #': 6116,
#  'fairytail # ayesir': 52458,
#  '# ayesir #': 2918,
#  'night': 81295,
#  'absolutely': 29970,
#  'unbelievable': 107268,
#  'â\x9d¤ï¸\x8fð\x9f\x87¬ð\x9f\x87§ð\x9f\x98³': 118564,
#  'littlemix': 72027,
#  'littlemixconce': 72031,
#  'juhuâ\x80¦': 67886,
#  'amazing night': 31818,
#  'night absolutely': 81333,
#  'absolutely unbelievable': 29983,
#  'unbelievable â\x9d¤ï¸\x8fð\x9f\x87¬ð\x9f\x87§ð\x9f\x98³': 107269,
#  'â\x9d¤ï¸\x8fð\x9f\x87¬ð\x9f\x87§ð\x9f\x98³ #': 118565,
#  '# littlemix': 9472,
#  'littlemix #': 72028,
#  '# littlemixconce': 9474,
#  'littlemixconce #': 72032,
#  '# juhuâ\x80¦': 8802,
#  'amazing night absolutely': 31819,
#  'night absolutely unbelievable': 81334,
#  'absolutely unbelievable â\x9d¤ï¸\x8fð\x9f\x87¬ð\x9f\x87§ð\x9f\x98³': 29984,
#  'unbelievable â\x9d¤ï¸\x8fð\x9f\x87¬ð\x9f\x87§ð\x9f\x98³ #': 107270,
#  'â\x9d¤ï¸\x8fð\x9f\x87¬ð\x9f\x87§ð\x9f\x98³ # littlemix': 118566,
#  '# littlemix #': 9473,
#  'littlemix # littlemixconce': 72030,
#  '# littlemixconce #': 9475,
#  'littlemixconce # juhuâ\x80¦': 72033,
#  'snapchat': 97381,
#  'ð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xad': 120638,
#  'ripchristina': 92062,
#  'snap': 97374,
#  'crying': 44802,
#  'snapchat ð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xad': 97398,
#  'ð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xad #': 120639,
#  '# ripchristina': 12748,
#  'ripchristina #': 92063,
#  '# snap': 13605,
#  'snap #': 97375,
#  '# snapchat': 13607,
#  'snapchat #': 97382,
#  '# crying': 4857,
#  'snapchat ð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xad #': 97399,
#  'ð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xad # ripchristina': 120640,
#  '# ripchristina #': 12749,
#  'ripchristina # snap': 92068,
#  '# snap #': 13606,
#  'snap # snapchat': 97377,
#  '# snapchat #': 13608,
#  'snapchat # crying': 97384,
#  'new': 80457,
#  'cover': 44276,
#  'facebook-page': 52320,
#  'gary': 57456,
#  'jules': 67892,
#  'mad': 74097,
#  'world': 116044,
#  ':': 26494,
#  'garyjules': 57464,
#  'madworld': 74228,
#  'pop': 87094,
#  'new cover': 80534,
#  'cover facebook-page': 44287,
#  'facebook-page .': 52321,
#  '. gary': 22424,
#  'gary jules': 57459,
#  'jules -': 67893,
#  '- mad': 21139,
#  'mad world': 74120,
#  'world :': 116079,
#  ': #': 26497,
#  '# garyjules': 6994,
#  'garyjules #': 57465,
#  '# madworld': 9803,
#  'madworld #': 74229,
#  '# cover': 4755,
#  'cover #': 44277,
#  '# mad': 9789,
#  'mad #': 74098,
#  '# world': 16004,
#  'world #': 116051,
#  '# pop': 11956,
#  'new cover facebook-page': 80535,
#  'cover facebook-page .': 44288,
#  'facebook-page . gary': 52322,
#  '. gary jules': 22425,
#  'gary jules -': 57460,
#  'jules - mad': 67894,
#  '- mad world': 21140,
#  'mad world :': 74121,
#  'world : #': 116080,
#  ': # garyjules': 26507,
#  '# garyjules #': 6995,
#  'garyjules # madworld': 57466,
#  '# madworld #': 9804,
#  'madworld # cover': 74230,
#  '# cover #': 4756,
#  'cover # mad': 44280,
#  '# mad #': 9790,
#  'mad # world': 74100,
#  '# world #': 16005,
#  'world # pop': 116057,
#  'crap': 44417,
#  'funeral': 56968,
#  'tomorrow': 104930,
#  'sucks': 100267,
#  'mourning': 78018,
#  'person': 85508,
#  'morningperson': 77837,
#  'sleepin': 96836,
#  'cry': 44783,
#  'burial': 39346,
#  '# crap': 4796,
#  'crap ,': 44420,
#  '# funeral': 6884,
#  'funeral go': 56971,
#  'go tomorrow': 59048,
#  'tomorrow #': 104939,
#  '# sucks': 14036,
#  'sucks #': 100268,
#  '# mourning': 10455,
#  'mourning person': 78019,
#  'person .': 85515,
#  '# morningperson': 10402,
#  'morningperson #': 77838,
#  '# sleepin': 13505,
#  'sleepin #': 96837,
#  '# cry': 4852,
#  'cry #': 44784,
#  '# wake': 15531,
#  'wake #': 112685,
#  '# burial': 3881,
#  '# crap ,': 4797,
#  'crap , #': 44421,
#  ', # funeral': 19108,
#  '# funeral go': 6885,
#  'funeral go tomorrow': 56972,
#  'go tomorrow #': 59049,
#  'tomorrow # sucks': 104944,
#  '# sucks #': 14037,
#  'sucks # mourning': 100269,
#  '# mourning person': 10456,
#  'mourning person .': 78020,
#  'person . #': 85516,
#  '. # morningperson': 21625,
#  '# morningperson #': 10403,
#  'morningperson # sleepin': 77839,
#  '# sleepin #': 13506,
#  'sleepin # cry': 96838,
#  '# cry #': 4853,
#  'cry # wake': 44789,
#  '# wake #': 15532,
#  'wake # burial': 112686,
#  'really': 90300,
#  'hu': 64865,
#  'feelings': 53724,
#  '(': 18546,
#  "'ve really": 18501,
#  'really hu': 90356,
#  'hu feelings': 64876,
#  'feelings :': 53734,
#  ': (': 26561,
#  "'ve really hu": 18502,
#  'really hu feelings': 90357,
#  'hu feelings :': 64877,
#  'feelings : (': 53735,
#  'speak': 98311,
#  'bring': 38815,
#  'smile': 97088,
#  'face': 52232,
#  'smiles': 97230,
#  'friends': 56422,
#  'people speak': 85274,
#  'speak ,': 98314,
#  ', bring': 19463,
#  'bring smile': 38830,
#  'smile face': 97185,
#  'face .': 52248,
#  '# smiles': 13569,
#  'smiles #': 97231,
#  '# friends': 6805,
#  'people speak ,': 85275,
#  'speak , bring': 98315,
#  ', bring smile': 19464,
#  'bring smile face': 38831,
#  'smile face .': 97187,
#  'face . #': 52249,
#  '. # smiles': 21744,
#  ...}

# %%
from sklearn.neural_network import MLPClassifier

# %%
param_grid = {'hidden_layer_sizes': [(10,),(5,5), (2,2)]}

mlp_clf = MLPClassifier(hidden_layer_sizes=(10,), n)

# %%
mlp_clf.fit(X_train_v, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, classification_report

# %%
y_pred = mlp_clf.predict(X_test_v)

# %%
#confusion_matrix(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-f3c243426ad0> in <module>()
# ----> 1 cm = confusion_matrix(y_test, y_pred)
#
# TypeError: 'tuple' object is not callable

# %%
print("roc_auc score: {}".format(roc_auc_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# roc_auc score: 0.7816318484921302
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5945
#           1       0.92      0.57      0.70       448
#
# avg / total       0.96      0.97      0.96      6393

# %%
X_all = vectorizer.transform(X)
y_all = y

# %%
mlp_clf.fit(X_all, y_all)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
df_test = pd.read_csv("dataset/test.csv")

# %%
df_test.sample(5)
# Out:
#           id                                              tweet
# 14877  46840           million dollar smile  #nicedog   #smile
# 4754   36717  the end... see you in september. ð #school ...
# 14367  46330  no words needed. &lt;3 #canonbeach #oregoncoas...
# 12581  44544  be   n #healthy i don't make jokes. i just wat...
# 10466  42429  it's not the #memories which make us   .. it's...

# %%
dtest = vectorizer.transform(df_test['tweet'])
test_pred = mlp_clf.predict(dtest)

# %%
df_test['label'] = test_pred

# %%
submission = df_test[['id','label']]

# %%
submission.to_csv('sub_rodixxi_mlpC.csv', index=False)
