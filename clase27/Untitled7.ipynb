# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv", index_col=0)

# %%
df.sample(5)
# Out:
#        label                                              tweet
# id
# 21983      0   nove :) #flylondon #friends   #sunglasses #love
# 18279      0            battlefield 1 looks unbelievable   ð
# 5198       1  this is beyond upsetting. i was one of her big...
# 31931      1  @user #feminismiscancer #feminismisterrorism #...
# 4775       0   @user doing that thing where you find an old,...

# %%
df["label"].unique()
# Out:
# array([0, 1])

# %%
df["tweet"].nunique()
# Out:
# 29530

# %%
df.size
# Out:
# 63924

# %%
df["tweet"].value_counts()
# Out:
# #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦                                                            319
# i finally found a way how to delete old tweets! you might find it useful as well:    #deletetweets                                               82
# aww yeah it's all good bing bong bing bong                                                                                                       75
# i'm so   and #grateful now that - #affirmations                                                                                                  56
# @user you might be a libtard if... #libtard  #sjw #liberal #politics                                                                             40
# you might be a libtard if... #libtard  #sjw #liberal #politics                                                                                   32
# ð #love #instagood #photooftheday top.tags #tbt #cute #me #beautiful #followme   #followâ¦                                                   29
# have my lover stop being angry at me visit us..&gt;&gt;&gt;  #lover   #friend #astrologer #love                                                  26
# #flagday2016   #flag #day #2016 #(30 #photos) buy things about "flag day 2016": â¦                                                              22
# get #up get   get  #enjoy #music #today #free #apps #free #music                                                                                 21
# @user #feminismiscancer #feminismisterrorism #feminismmuktbharat why  #malevote is ignored  @user                                                20
# #sikh #temple vandalised in in #calgary, #wso condemns  act                                                                                      20
# save $$ no logins x brokers   #me #change #memes #love   #education #university                                                                  17
# can #lighttherapy help with   or #depression?    #altwaystoheal  #healthy is #happy !!                                                           16
# what is a #detoxdiet?  #altwaystoheal! #healthy  !                                                                                               14
# #music as #therapy as a tool for #healing!   #altwaystoheal #healthy is  !!                                                                      14
# best essential oils for #healing!!    #altwaystoheal #healthy  !!                                                                                14
# can #lighttherapy help with   or #depression?   #altwaystoheal #healthy is #happy !!                                                             14
# safe ways to heal your #acne!!    #altwaystoheal #healthy   #healing!!                                                                           14
# does #magnettherapy really work?   #altwaystoheal #healing #healthy   !!                                                                         14
# best #essentialoils for #anxiety !!     #healthy   #peace !!  #altwaystoheal !!                                                                  14
# herbal sleep remedies that work!!  #altwaystoheal #healthy #healing   !!                                                                         13
# looking to feel more #joy? join me and 20 speakers on the free summit #unleashyourjoy                                                            13
# best #lawofattraction #resources for #healing!    #altwaystoheal #healthy is  ! #idwp !                                                          13
# #lawofattraction for #healing!!    #altwaystoheal #healthy is  !!                                                                                12
# can #lighttherapy help with #sad or #depression?    #altwaystoheal  #healthy is   !!                                                             12
# #raw food diet benefits! -    #altwaystoheal #healthy   #healing #peace #joy #love !!                                                            12
#   happy day!  #altwaystoheal  #healthy                                                                                                           11
# #people aren't protesting #trump because a #republican won-they do so because trump has fuhered  &amp;â¦                                        11
# stuck in the rat race? find your freedom.   #masterkeyexperience                                                                                 11
#                                                                                                                                                ...
# if you want to be  , be kind to the #poor; it is a #sin to despise anyone.  #jesus #faith #believe #wisdom                                        1
# sterling is making me so angry!   #sterling. ohhh and fuck you @user you nobody!                                                                  1
# brick by boring brick. âð»ï¸ #blonde #blueeyes                                                                                               1
# ð 3 years of aho! i'm so excited!!! the team has so much young talent! ðª   #caniac #hockey                                                  1
# â­â­â­â­â­ review by stacy kripas: "beautiful work! very   with the scarf." #katerynag                                                       1
#  @user   and looking forward to #halloween                                                                                                        1
# @user lax misses you &lt;3 i miss happy hour hopping with you. no one else can keep up   #notthesame                                              1
#  @user yay, i'm exhibitor of the day!  #goldsmithsfair #weektwo  !!!                                                                              1
# can't believe how excited i got at winning a load of knitting needles off ebay... i'm getting old ð±   #knitting #crafts #wool #ebay            1
# @user @user @user sure. ððð                                                                                                              1
# #toradora #anime #animeedit i made it.   #breakups #alone #lonely                                                                                 1
# schedule for this week is almost full.. yeaaayyy #dancing                                                                                         1
# good luck cheryl! #itwillbealrightonthenight xx                                                                                                   1
# yes, thanks #trump for pointing to a poll that shows you losing. #trumpfail  .                                                                    1
# #socialstudies   attack bull chase: when you leave the lot despite the fact that you're a strong source                                           1
# finally got to see #harrypotter @user &amp; have some butter beer &amp; i couldn't of felt more   /we were supposed 2 have gone together          1
# fallout 4 vr at e3, and not once did they mention psvr!   #e32016                                                                                 1
# today involves a day in the house looking for a new tv series to watch, any recommendations would be nice ð #tv #tvseries #dayin   âºï¸      1
# scream out #loud with #the   #faces \!/                                                                                                           1
# looks like i will be seeing @user tomorrow after all!!   ððâºï¸âºï¸                                                                     1
# @user #allahsoil the more familiar we become, the more difficult it is to stereotype. . â¦   #emiratiâ¦                                         1
# texts with bae.  #textpost     #ofcourse #weregettingmarried #yes heas #loveâ¦                                                                   1
# thank you for this! ðð #pizza #pizzaislove #sbarro #cheese                                                                                  1
# #khoyathefilm #afterpay   #soldout #faces! with @user @user                                                                                       1
# @user dear john,france actually still helping 'em selling alcool 24/7 and heavly lacking about police in hot violence spots.                      1
# @user @user just running running the updates on mine.                                                                                             1
# happy father's day â¼ï¸â¤ï¸  #loveyou #fathersday   #sunday #father #daddy dayâ¦                                                             1
# #stayunchained and have a   #fridayfeeling  #love #volkswagen #freedom #joy                                                                       1
# @user   well i;m glad then   be     #smile #more #sex                                                                                             1
#  @user it is coming.........7 july release date   #lmll #ibiza #techno                                                                            1
# Name: tweet, Length: 29530, dtype: int64

# %%
import nltk

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def tweets_lemm(tweet):
    lemmatizer = WordNetLemmatizer()
    word_list = nltk.word_tokenize(tweet)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output

# %%
df['tweet'] = df['tweet'].apply(lambda x : tweets_lemm(x))

# %%
from sklearn.model_selection import train_test_split

# %%
X = df["tweet"]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /home/rcrespillo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vectorizer = TfidfVectorizer(analyzer='word', 
                             tokenizer=nltk.word_tokenize, 
                             stop_words=stops, 
                             ngram_range=(1,3))

X_train_v = vectorizer.fit_transform(X_train)
X_test_v = vectorizer.transform(X_test)

# %%
X_train_v.shape
# Out:
# (25569, 390590)

# %%
vectorizer.vocabulary_
# Out:
# {'â\x86\x9d': 380764,
#  '#': 5900,
#  'united': 345109,
#  'state': 317372,
#  '30-year': 78484,
#  'bond': 119228,
#  'auction': 105391,
#  '2.475': 76672,
#  '%': 48717,
#  'previous': 281660,
#  '2.615': 76686,
#  'blog': 118072,
#  'silver': 308364,
#  'gold': 188375,
#  'forex': 176160,
#  'â\x86\x9d #': 380765,
#  '# united': 44919,
#  'united state': 345125,
#  'state 30-year': 317401,
#  '30-year bond': 78485,
#  'bond auction': 119237,
#  'auction 2.475': 105394,
#  '2.475 %': 76673,
#  '% previous': 48840,
#  'previous 2.615': 281693,
#  '2.615 %': 76687,
#  '% #': 48718,
#  '# blog': 10925,
#  'blog #': 118077,
#  '# silver': 39564,
#  'silver #': 308365,
#  '# gold': 21472,
#  'gold #': 188379,
#  '# forex': 19774,
#  'â\x86\x9d # united': 380863,
#  '# united state': 44922,
#  'united state 30-year': 345129,
#  'state 30-year bond': 317402,
#  '30-year bond auction': 78486,
#  'bond auction 2.475': 119238,
#  'auction 2.475 %': 105395,
#  '2.475 % previous': 76674,
#  '% previous 2.615': 48843,
#  'previous 2.615 %': 281694,
#  '2.615 % #': 76688,
#  '% # blog': 48722,
#  '# blog #': 10927,
#  'blog # silver': 118091,
#  '# silver #': 39565,
#  'silver # gold': 308367,
#  '# gold #': 21474,
#  'gold # forex': 188381,
#  'hand': 196145,
#  '|': 378909,
#  'ombre': 264767,
#  'blue': 118441,
#  'hand |': 196246,
#  '| #': 378910,
#  '# ombre': 33344,
#  'ombre #': 264768,
#  '# blue': 11004,
#  'hand | #': 196247,
#  '| # ombre': 378943,
#  '# ombre #': 33345,
#  'ombre # blue': 264769,
#  'exercise': 164320,
#  "'m": 50000,
#  'workout': 373242,
#  'gum': 193895,
#  'basement': 109602,
#  'lose': 232352,
#  'wate': 364561,
#  'people': 272036,
#  'wo': 371146,
#  "n't": 251972,
#  'call': 125098,
#  'fat': 168008,
#  'like': 227202,
#  'always': 98058,
#  '# exercise': 18072,
#  "exercise 'm": 164330,
#  "'m workout": 51009,
#  'workout gum': 373284,
#  'gum basement': 193901,
#  'basement lose': 109603,
#  'lose wate': 232397,
#  'wate people': 364562,
#  'people wo': 272883,
#  "wo n't": 371151,
#  "n't call": 252285,
#  'call fat': 125180,
#  'fat like': 168026,
#  'like always': 227460,
#  "# exercise 'm": 18074,
#  "exercise 'm workout": 164331,
#  "'m workout gum": 51010,
#  'workout gum basement': 373285,
#  'gum basement lose': 193902,
#  'basement lose wate': 109604,
#  'lose wate people': 232398,
#  'wate people wo': 364563,
#  "people wo n't": 272884,
#  "wo n't call": 371162,
#  "n't call fat": 252288,
#  'call fat like': 125181,
#  'fat like always': 168027,
#  'feeling': 169896,
#  'overwhelmed': 268407,
#  'look': 231439,
#  'see': 301631,
#  'million': 244423,
#  'reason': 289427,
#  'happy': 197233,
#  '.': 64213,
#  'love': 233053,
#  'craig': 140311,
#  '!': 0,
#  "'m feeling": 50341,
#  'feeling #': 169899,
#  '# overwhelmed': 33876,
#  'overwhelmed look': 268414,
#  'look see': 231795,
#  'see million': 302104,
#  'million reason': 244458,
#  'reason #': 289431,
#  '# happy': 22649,
#  'happy .': 197380,
#  '. love': 68466,
#  'love craig': 233804,
#  'craig !': 140312,
#  '! !': 1,
#  "'m feeling #": 50342,
#  'feeling # overwhelmed': 169925,
#  '# overwhelmed look': 33878,
#  'overwhelmed look see': 268415,
#  'look see million': 231797,
#  'see million reason': 302105,
#  'million reason #': 244459,
#  'reason # happy': 289433,
#  '# happy .': 22657,
#  'happy . love': 197396,
#  '. love craig': 68473,
#  'love craig !': 233805,
#  'craig ! !': 140313,
#  '@': 86685,
#  'user': 346579,
#  'spoiler': 315651,
#  'good': 188767,
#  'dinosaur': 151087,
#  'thing': 330909,
#  'fucking': 179632,
#  'sad': 297104,
#  'funny': 180579,
#  'thegooddinosaur': 330354,
#  'thefuck': 330336,
#  '@ user': 87421,
#  'user spoiler': 354876,
#  'spoiler good': 315654,
#  'good dinosaur': 188957,
#  'dinosaur !': 151088,
#  '! thing': 4550,
#  'thing fucking': 331093,
#  'fucking sad': 179713,
#  'sad #': 297113,
#  '# funny': 20361,
#  'funny #': 180583,
#  '# thegooddinosaur': 43015,
#  'thegooddinosaur #': 330355,
#  '# thefuck': 43003,
#  '@ user spoiler': 89594,
#  'user spoiler good': 354877,
#  'spoiler good dinosaur': 315655,
#  'good dinosaur !': 188958,
#  'dinosaur ! thing': 151089,
#  '! thing fucking': 4551,
#  'thing fucking sad': 331094,
#  'fucking sad #': 179714,
#  'sad # funny': 297124,
#  '# funny #': 20363,
#  'funny # thegooddinosaur': 180634,
#  '# thegooddinosaur #': 43016,
#  'thegooddinosaur # thefuck': 330356,
#  'calm': 125405,
#  'i_am': 207614,
#  'positive': 279047,
#  'affirmation': 94847,
#  'calm .': 125419,
#  '. #': 64219,
#  '# i_am': 24113,
#  'i_am #': 207615,
#  '# positive': 35510,
#  'positive #': 279050,
#  '# affirmation': 7337,
#  'calm . #': 125420,
#  '. # i_am': 64887,
#  '# i_am #': 24114,
#  'i_am # positive': 207616,
#  '# positive #': 35512,
#  'positive # affirmation': 279051,
#  'word': 372270,
#  'treasured': 339024,
#  'hea': 199839,
#  '(': 55172,
#  'psalm': 283698,
#  '119:11': 74751,
#  ')': 55919,
#  'vlicobs': 359617,
#  'xoxo': 375536,
#  'grace': 191219,
#  'amenâ\x80¦': 99033,
#  'word treasured': 372448,
#  'treasured hea': 339025,
#  'hea .': 199870,
#  '. (': 66008,
#  '( psalm': 55763,
#  'psalm 119:11': 283699,
#  '119:11 )': 74752,
#  ') #': 55926,
#  '# vlicobs': 45611,
#  'vlicobs #': 359618,
#  '# xoxo': 47499,
#  'xoxo #': 375537,
#  '# love': 28439,
#  'love #': 233076,
#  '# grace': 21828,
#  'grace #': 191220,
#  '# amenâ\x80¦': 8020,
#  'word treasured hea': 372449,
#  'treasured hea .': 339026,
#  'hea . (': 199872,
#  '. ( psalm': 66018,
#  '( psalm 119:11': 55764,
#  'psalm 119:11 )': 283700,
#  '119:11 ) #': 74753,
#  ') # vlicobs': 56099,
#  '# vlicobs #': 45612,
#  'vlicobs # xoxo': 359619,
#  '# xoxo #': 47500,
#  'xoxo # love': 375543,
#  '# love #': 28441,
#  'love # grace': 233265,
#  '# grace #': 21829,
#  'grace # amenâ\x80¦': 191222,
#  'ca': 124599,
#  'wait': 361657,
#  'new': 257103,
#  'appstore': 103197,
#  'really': 288928,
#  'user @': 348605,
#  'user ca': 349529,
#  "ca n't": 124617,
#  "n't wait": 253615,
#  'wait new': 361906,
#  'new #': 257107,
#  '# appstore': 8551,
#  'appstore .': 103198,
#  '# really': 36957,
#  '@ user @': 87573,
#  'user @ user': 348612,
#  '@ user ca': 87875,
#  "user ca n't": 349530,
#  "ca n't wait": 124741,
#  "n't wait new": 253667,
#  'wait new #': 361907,
#  'new # appstore': 257114,
#  '# appstore .': 8552,
#  'appstore . #': 103199,
#  '. # really': 65364,
#  'aesthete': 94731,
#  'farmer': 167652,
#  'dorset': 153937,
#  'dorsethour': 153945,
#  'wednesday': 365983,
#  'countryside': 139556,
#  'mylife': 251587,
#  'style': 320789,
#  'trend': 339204,
#  'aesthete farmer': 94732,
#  'farmer dorset': 167657,
#  'dorset #': 153938,
#  '# dorsethour': 16533,
#  'dorsethour #': 153946,
#  '# wednesday': 46172,
#  'wednesday #': 365992,
#  '# dorset': 16529,
#  '# countryside': 14445,
#  'countryside #': 139557,
#  '# #': 5905,
#  '# mylife': 31406,
#  'mylife style': 251597,
#  'style #': 320795,
#  '# trend': 44143,
#  'trend @': 339213,
#  'aesthete farmer dorset': 94733,
#  'farmer dorset #': 167658,
#  'dorset # dorsethour': 153940,
#  '# dorsethour #': 16534,
#  'dorsethour # wednesday': 153947,
#  '# wednesday #': 46174,
#  'wednesday # dorset': 365996,
#  '# dorset #': 16530,
#  'dorset # countryside': 153939,
#  '# countryside #': 14446,
#  'countryside # #': 139558,
#  '# # mylife': 6145,
#  '# mylife style': 31408,
#  'mylife style #': 251598,
#  'style # trend': 320823,
#  '# trend @': 44145,
#  'trend @ user': 339214,
#  'friday': 177886,
#  'peugeot208wrx': 273934,
#  'user friday': 350978,
#  'friday feeling': 178104,
#  'feeling !': 169897,
#  '! #': 482,
#  '# friday': 20029,
#  'friday #': 177914,
#  '# feeling': 18838,
#  '# peugeot208wrx': 34691,
#  'peugeot208wrx @': 273935,
#  '@ user friday': 88392,
#  'user friday feeling': 350985,
#  'friday feeling !': 178105,
#  'feeling ! #': 169898,
#  '! # friday': 1047,
#  '# friday #': 20031,
#  'friday # feeling': 177936,
#  '# feeling #': 18839,
#  'feeling # peugeot208wrx': 169926,
#  '# peugeot208wrx @': 34692,
#  'peugeot208wrx @ user': 273936,
#  "'s": 51775,
#  'freedom': 177557,
#  'make': 237486,
#  'u': 342815,
#  'ð\x9f\x8c¤ð\x9f\x8d\x80': 383522,
#  'hufpfoten': 206661,
#  'podenco': 277602,
#  'galgo': 181265,
#  'sunshine': 322919,
#  'lovemydogs': 235174,
#  "'s freedom": 52975,
#  'freedom make': 177606,
#  'make u': 238137,
#  'u happy': 343269,
#  'happy ð\x9f\x8c¤ð\x9f\x8d\x80': 198402,
#  'ð\x9f\x8c¤ð\x9f\x8d\x80 #': 383523,
#  '# hufpfoten': 23916,
#  'hufpfoten #': 206662,
#  '# podenco': 35240,
#  'podenco #': 277603,
#  '# galgo': 20519,
#  'galgo #': 181266,
#  '# freedom': 19935,
#  'freedom #': 177561,
#  '# sunshine': 41786,
#  'sunshine #': 322923,
#  '# lovemydogs': 28689,
#  "'s freedom make": 52977,
#  'freedom make u': 177607,
#  'make u happy': 238149,
#  'u happy ð\x9f\x8c¤ð\x9f\x8d\x80': 343275,
#  'happy ð\x9f\x8c¤ð\x9f\x8d\x80 #': 198403,
#  'ð\x9f\x8c¤ð\x9f\x8d\x80 # hufpfoten': 383524,
#  '# hufpfoten #': 23917,
#  'hufpfoten # podenco': 206663,
#  '# podenco #': 35241,
#  'podenco # galgo': 277604,
#  '# galgo #': 20520,
#  'galgo # freedom': 181267,
#  '# freedom #': 19936,
#  'freedom # sunshine': 177570,
#  '# sunshine #': 41787,
#  'sunshine # lovemydogs': 322940,
#  'man': 238847,
#  'ha': 194736,
#  'anything': 102375,
#  'eah': 156397,
#  'worry': 373927,
#  ',': 56894,
#  'go': 186523,
#  'get': 183121,
#  'married': 240297,
#  'â\x80\x94robe': 380288,
#  'frost': 179267,
#  'wedding': 365758,
#  "'s funny": 53004,
#  'funny thing': 180726,
#  'thing man': 331198,
#  'man ha': 239040,
#  "ha n't": 195180,
#  "n't anything": 252136,
#  'anything eah': 102427,
#  'eah worry': 156429,
#  'worry ,': 373933,
#  ', go': 59271,
#  'go get': 186866,
#  'get married': 183697,
#  'married â\x80\x94robe': 240335,
#  'â\x80\x94robe frost': 380291,
#  'frost #': 179268,
#  '# wedding': 46121,
#  'wedding #': 365764,
#  "'s funny thing": 53012,
#  'funny thing man': 180727,
#  'thing man ha': 331199,
#  "man ha n't": 239042,
#  "ha n't anything": 195181,
#  "n't anything eah": 252138,
#  'anything eah worry': 102428,
#  'eah worry ,': 156430,
#  'worry , go': 373938,
#  ', go get': 59280,
#  'go get married': 186873,
#  'get married â\x80\x94robe': 183702,
#  'married â\x80\x94robe frost': 240336,
#  'â\x80\x94robe frost #': 380292,
#  'frost # wedding': 179270,
#  '# wedding #': 46122,
#  'wedding # love': 365788,
#  'come': 134897,
#  'hour': 205856,
#  'try': 340779,
#  'amazing': 98577,
#  '4': 78913,
#  '$': 48513,
#  'treat': 339031,
#  'calgary': 125022,
#  'yyc': 378455,
#  'come new': 135177,
#  'new hour': 257551,
#  'hour !': 205857,
#  '! try': 4640,
#  'try amazing': 340814,
#  'amazing 4': 98673,
#  '4 $': 78946,
#  '$ 4': 48622,
#  '4 treat': 79163,
#  'treat !': 339032,
#  '# calgary': 12232,
#  'calgary #': 125023,
#  '# yyc': 47917,
#  'come new hour': 135179,
#  'new hour !': 257552,
#  'hour ! try': 205863,
#  '! try amazing': 4641,
#  'try amazing 4': 340815,
#  'amazing 4 $': 98674,
#  '4 $ 4': 78947,
#  '$ 4 treat': 48623,
#  '4 treat !': 79164,
#  'treat ! #': 339034,
#  '! # calgary': 710,
#  '# calgary #': 12233,
#  'calgary # yyc': 125024,
#  'tbt': 326851,
#  'drbanner': 154581,
#  '..': 70996,
#  'marvelstheavengers': 240414,
#  'hulk': 206817,
#  'follow': 174968,
#  'awesome': 106397,
#  'every': 162608,
#  'way': 364788,
#  '# tbt': 42369,
#  'tbt #': 326854,
#  '# drbanner': 16656,
#  'drbanner get': 154582,
#  'get ..': 183219,
#  '.. #': 71000,
#  '# marvelstheavengers': 29549,
#  'marvelstheavengers #': 240415,
#  '# hulk': 23940,
#  'hulk follow': 206824,
#  'follow @': 175042,
#  "user 's": 347935,
#  "'s awesome": 52171,
#  'awesome every': 106481,
#  'every way': 162830,
#  '# tbt #': 42370,
#  'tbt # drbanner': 326859,
#  '# drbanner get': 16657,
#  'drbanner get ..': 154583,
#  'get .. #': 183220,
#  '.. # marvelstheavengers': 71018,
#  '# marvelstheavengers #': 29550,
#  'marvelstheavengers # hulk': 240416,
#  '# hulk follow': 23942,
#  'hulk follow @': 206825,
#  'follow @ user': 175043,
#  "@ user 's": 87438,
#  "user 's awesome": 347950,
#  "'s awesome every": 52172,
#  'awesome every way': 106482,
#  'fathersday': 168443,
#  'superheroes': 323248,
#  'rockstars': 295246,
#  'ð\x9f\x92\x99': 385977,
#  'rockstar': 295239,
#  'superhero': 323232,
#  'dadâ\x80¦': 143532,
#  'happy fathersday': 197792,
#  'fathersday superheroes': 168649,
#  'superheroes rockstars': 323253,
#  'rockstars ð\x9f\x92\x99': 295247,
#  'ð\x9f\x92\x99 #': 385978,
#  '# fathersday': 18637,
#  'fathersday #': 168453,
#  '# rockstar': 37806,
#  'rockstar #': 295240,
#  '# superhero': 41842,
#  'superhero #': 323235,
#  '# dadâ\x80¦': 15103,
#  'happy fathersday superheroes': 197794,
#  'fathersday superheroes rockstars': 168650,
#  'superheroes rockstars ð\x9f\x92\x99': 323254,
#  'rockstars ð\x9f\x92\x99 #': 295248,
#  'ð\x9f\x92\x99 # fathersday': 385985,
#  '# fathersday #': 18639,
#  'fathersday # rockstar': 168522,
#  '# rockstar #': 37807,
#  'rockstar # superhero': 295241,
#  '# superhero #': 41844,
#  'superhero # dadâ\x80¦': 323238,
#  'n': 251802,
#  'healthy': 200575,
#  'popular': 278790,
#  'right': 293994,
#  'â\x80\x93': 380089,
#  'howard': 206304,
#  'cosell': 138775,
#  'n #': 251803,
#  '# healthy': 22999,
#  "healthy 's": 200663,
#  "'s popular": 53874,
#  "popular n't": 278798,
#  "n't always": 252119,
#  'always right': 98350,
#  'right .': 294060,
#  ". 's": 65892,
#  "'s right": 54027,
#  "right n't": 294204,
#  'always popular': 98318,
#  'popular .': 278793,
#  '. â\x80\x93': 70599,
#  'â\x80\x93 howard': 380143,
#  'howard cosell': 206307,
#  'n # healthy': 251808,
#  "# healthy 's": 23004,
#  "healthy 's popular": 200664,
#  "'s popular n't": 53875,
#  "popular n't always": 278799,
#  "n't always right": 252123,
#  'always right .': 98351,
#  "right . 's": 294062,
#  ". 's right": 65965,
#  "'s right n't": 54035,
#  "right n't always": 294205,
#  "n't always popular": 252122,
#  'always popular .': 98319,
#  'popular . â\x80\x93': 278795,
#  '. â\x80\x93 howard': 70611,
#  'â\x80\x93 howard cosell': 380144,
#  'oil': 264029,
#  'reach': 287808,
#  'fresh': 177770,
#  '10-month': 74397,
#  'high': 202524,
#  'amid': 99407,
#  'output': 268140,
#  'disruption': 151965,
#  '# oil': 33232,
#  'oil reach': 264061,
#  'reach fresh': 287818,
#  'fresh 10-month': 177794,
#  '10-month high': 74398,
#  'high amid': 202546,
#  'amid output': 99411,
#  'output disruption': 268143,
#  'disruption #': 151966,
#  'â\x86\x9d # oil': 380835,
#  '# oil reach': 33237,
#  'oil reach fresh': 264062,
#  'reach fresh 10-month': 287819,
#  'fresh 10-month high': 177795,
#  '10-month high amid': 74399,
#  'high amid output': 202547,
#  'amid output disruption': 99412,
#  'output disruption #': 268144,
#  'disruption # blog': 151967,
#  'thought': 332215,
#  'factory': 165973,
#  ':': 81277,
#  'bbc': 110033,
#  'neutrality': 256558,
#  'wing': 370149,
#  'fascism': 167708,
#  'politics': 278294,
#  'medium': 242119,
#  'blm': 117971,
#  'brexit': 121629,
#  'trump': 340122,
#  'leadership': 223417,
#  '+4': 56876,
#  'thought factory': 332313,
#  'factory :': 165977,
#  ': bbc': 81803,
#  'bbc neutrality': 110051,
#  'neutrality right': 256559,
#  'right wing': 294266,
#  'wing fascism': 370162,
#  'fascism #': 167709,
#  '# politics': 35331,
#  'politics #': 278297,
#  '# medium': 29784,
#  'medium #': 242124,
#  '# blm': 10905,
#  'blm #': 117972,
#  '# brexit': 11567,
#  'brexit #': 121630,
#  '# trump': 44267,
#  'trump #': 340126,
#  '# leadership': 27304,
#  'leadership +4': 223433,
#  'thought factory :': 332314,
#  'factory : bbc': 165978,
#  ': bbc neutrality': 81804,
#  'bbc neutrality right': 110052,
#  'neutrality right wing': 256560,
#  'right wing fascism': 294268,
#  'wing fascism #': 370163,
#  'fascism # politics': 167712,
#  '# politics #': 35332,
#  'politics # medium': 278305,
#  '# medium #': 29786,
#  'medium # blm': 242127,
#  '# blm #': 10906,
#  'blm # brexit': 117973,
#  '# brexit #': 11568,
#  'brexit # trump': 121641,
#  '# trump #': 44269,
#  'trump # leadership': 340145,
#  '# leadership +4': 27307,
#  'passed': 270458,
#  'naked': 254255,
#  'girl': 184989,
#  'hardcore': 198758,
#  'compilation': 136313,
#  'passed naked': 270491,
#  'naked girl': 254274,
#  'girl hardcore': 185282,
#  'hardcore compilation': 198775,
#  'passed naked girl': 270492,
#  'naked girl hardcore': 254275,
#  'girl hardcore compilation': 185285,
#  'last': 221871,
#  'week': 366149,
#  'christina': 131604,
#  'grimmie': 192977,
#  'orlando': 267279,
#  'yesterday': 377008,
#  'british': 122212,
#  'politician': 278233,
#  '-': 62686,
#  'doe': 152553,
#  'hate': 199162,
#  '?': 85141,
#  'last week': 222150,
#  'week christina': 366358,
#  'christina grimmie': 131614,
#  'grimmie ,': 192984,
#  ', orlando': 60817,
#  'orlando ,': 267351,
#  ', yesterday': 62625,
#  'yesterday british': 377064,
#  'british politician': 122232,
#  'politician -': 278238,
#  '- doe': 63163,
#  'doe hate': 152630,
#  'hate come': 199245,
#  'come ?': 134962,
#  'last week christina': 222154,
#  'week christina grimmie': 366359,
#  'christina grimmie ,': 131617,
#  'grimmie , orlando': 192987,
#  ', orlando ,': 60818,
#  'orlando , yesterday': 267359,
#  ', yesterday british': 62627,
#  'yesterday british politician': 377065,
#  'british politician -': 122233,
#  'politician - doe': 278239,
#  '- doe hate': 63164,
#  'doe hate come': 152631,
#  'hate come ?': 199246,
#  'precious': 280735,
#  'aronia': 103684,
#  'berry': 113044,
#  'developing': 150154,
#  'despite': 149828,
#  'rain': 286688,
#  'still': 318288,
#  'fabulous': 165517,
#  'see precious': 302183,
#  'precious #': 280738,
#  '# aronia': 8657,
#  'aronia #': 103685,
#  '# berry': 10125,
#  'berry developing': 113049,
#  'developing ,': 150155,
#  ', despite': 58617,
#  'despite #': 149829,
#  '# rain': 36666,
#  'rain still': 286754,
#  'still look': 318493,
#  'look #': 231444,
#  '# fabulous': 18241,
#  'see precious #': 302184,
#  'precious # aronia': 280739,
#  '# aronia #': 8658,
#  'aronia # berry': 103686,
#  '# berry developing': 10126,
#  'berry developing ,': 113050,
#  'developing , despite': 150156,
#  ', despite #': 58618,
#  'despite # rain': 149831,
#  '# rain still': 36672,
#  'rain still look': 286755,
#  'still look #': 318494,
#  'look # fabulous': 231451,
#  'flagday2016': 173816,
#  'flag': 173770,
#  'day': 144912,
#  '2016': 76895,
#  '30': 78431,
#  'photo': 274269,
#  'buy': 124265,
#  '``': 90531,
#  'â\x80¦': 380669,
#  '# flagday2016': 19394,
#  'flagday2016 #': 173817,
#  '# flag': 19388,
#  'flag #': 173773,
#  '# day': 15344,
#  'day #': 144988,
#  '# 2016': 6548,
#  '2016 #': 76904,
#  '# (': 6306,
#  '( 30': 55355,
#  '30 #': 78432,
#  '# photo': 34765,
#  'photo )': 274311,
#  ') buy': 56255,
#  'buy thing': 124350,
#  'thing ``': 330994,
#  '`` flag': 91264,
#  'flag day': 173783,
#  'day 2016': 145463,
#  '2016 ``': 76975,
#  '`` :': 90810,
#  ': â\x80¦': 82909,
#  '# flagday2016 #': 19395,
#  'flagday2016 # flag': 173818,
#  '# flag #': 19389,
#  'flag # day': 173774,
#  '# day #': 15346,
#  'day # 2016': 144996,
#  '# 2016 #': 6549,
#  '2016 # (': 76905,
#  '# ( 30': 6307,
#  '( 30 #': 55356,
#  '30 # photo': 78434,
#  '# photo )': 34767,
#  'photo ) buy': 274312,
#  ') buy thing': 56256,
#  'buy thing ``': 124351,
#  'thing `` flag': 330997,
#  '`` flag day': 91265,
#  'flag day 2016': 173785,
#  'day 2016 ``': 145465,
#  '2016 `` :': 76976,
#  '`` : â\x80¦': 90820,
#  'getting': 184157,
#  'turn': 341515,
#  'bluetooth': 118581,
#  'car': 126604,
#  'choose': 131329,
#  'playlist': 276878,
#  'different': 150729,
#  'genre': 182876,
#  'user getting': 351105,
#  'getting turn': 184439,
#  'turn bluetooth': 341541,
#  'bluetooth car': 118582,
#  'car ca': 126659,
#  "n't choose": 252319,
#  'choose playlist': 131394,
#  'playlist different': 276886,
#  'different genre': 150757,
#  '@ user getting': 88431,
#  'user getting turn': 351116,
#  'getting turn bluetooth': 184440,
#  'turn bluetooth car': 341542,
#  'bluetooth car ca': 118583,
#  "car ca n't": 126660,
#  "ca n't choose": 124639,
#  "n't choose playlist": 252320,
#  'choose playlist different': 131395,
#  'playlist different genre': 276887,
#  'hehe': 201362,
#  'found': 176704,
#  'approximate': 103185,
#  'date': 144535,
#  'ð\x9f\x92\x83ð\x9f\x91\x8dð\x9f\x8e\x89': 385471,
#  'somuchfunlasttime': 313369,
#  'ð\x9f\x92\x95': 385728,
#  'user hehe': 351638,
#  'hehe ,': 201365,
#  ', look': 60121,
#  'look like': 231653,
#  'like found': 227682,
#  'found approximate': 176730,
#  'approximate date': 103186,
#  'date ð\x9f\x92\x83ð\x9f\x91\x8dð\x9f\x8e\x89': 144634,
#  'ð\x9f\x92\x83ð\x9f\x91\x8dð\x9f\x8e\x89 #': 385472,
#  '# somuchfunlasttime': 40364,
#  'somuchfunlasttime ð\x9f\x92\x95': 313370,
#  '@ user hehe': 88552,
#  'user hehe ,': 351639,
#  'hehe , look': 201366,
#  ', look like': 60128,
#  'look like found': 231687,
#  'like found approximate': 227683,
#  'found approximate date': 176731,
#  'approximate date ð\x9f\x92\x83ð\x9f\x91\x8dð\x9f\x8e\x89': 103187,
#  'date ð\x9f\x92\x83ð\x9f\x91\x8dð\x9f\x8e\x89 #': 144635,
#  'ð\x9f\x92\x83ð\x9f\x91\x8dð\x9f\x8e\x89 # somuchfunlasttime': 385473,
#  '# somuchfunlasttime ð\x9f\x92\x95': 40365,
#  'feel': 169448,
#  'technology': 327683,
#  'fails': 166103,
#  'anger': 100718,
#  'feel right': 169774,
#  'right #': 294009,
#  '# technology': 42580,
#  'technology fails': 327692,
#  'fails #': 166104,
#  '# anger': 8225,
#  'feel right #': 169775,
#  'right # technology': 294026,
#  '# technology fails': 42582,
#  'technology fails #': 327693,
#  'fails # anger': 166105,
#  'dream': 154598,
#  'limit': 228511,
#  'saintpetersburg': 297992,
#  'travel': 338702,
#  'fitness': 173498,
#  'boy': 120539,
#  'life': 225897,
#  'liveâ\x80¦': 230086,
#  'dream ha': 154687,
#  'ha limit': 195136,
#  'limit .': 228514,
#  '# saintpetersburg': 38201,
#  'saintpetersburg #': 297993,
#  '# travel': 44042,
#  'travel #': 338706,
#  '# fitness': 19339,
#  'fitness #': 173499,
#  '# workout': 47196,
#  'workout #': 373248,
#  '# boy': 11393,
#  'boy #': 120544,
#  '# man': 29337,
#  'man #': 238855,
#  '# life': 27674,
#  'life #': 225917,
#  '# liveâ\x80¦': 28128,
#  'dream ha limit': 154689,
#  'ha limit .': 195137,
#  'limit . #': 228515,
#  '. # saintpetersburg': 65421,
#  '# saintpetersburg #': 38202,
#  'saintpetersburg # travel': 297994,
#  '# travel #': 44043,
#  'travel # fitness': 338723,
#  '# fitness #': 19340,
#  'fitness # workout': 173553,
#  '# workout #': 47198,
#  'workout # boy': 373252,
#  '# boy #': 11394,
#  'boy # man': 120583,
#  '# man #': 29338,
#  'man # life': 238868,
#  '# life #': 27676,
#  'life # liveâ\x80¦': 226014,
#  'milk': 244362,
#  'run': 296458,
#  'vine': 359096,
#  'loop': 232187,
#  'comedy': 135368,
#  'milk run': 244376,
#  'run #': 296462,
#  '# vine': 45510,
#  'vine #': 359097,
#  '# milk': 30178,
#  'milk #': 244363,
#  '# loop': 28356,
#  'loop #': 232188,
#  '# comedy': 13946,
#  'milk run #': 244377,
#  'run # vine': 296483,
#  '# vine #': 45511,
#  'vine # milk': 359101,
#  '# milk #': 30179,
#  'milk # loop': 244364,
#  '# loop #': 28357,
#  'loop # comedy': 232189,
#  'fully': 180051,
#  'blocked': 118027,
#  'lol': 230674,
#  'dam': 143744,
#  'know': 219811,
#  'pissed': 275579,
#  'ur': 345896,
#  'pant': 269782,
#  'lmao': 230261,
#  "user 'm": 347839,
#  "'m fully": 50365,
#  'fully blocked': 180059,
#  'blocked ?': 118037,
#  '? ?': 85642,
#  '? lol': 86115,
#  'lol dam': 230742,
#  "dam n't": 143745,
#  "n't know": 252852,
#  'know u': 220258,
#  'u pissed': 343478,
#  'pissed ur': 275591,
#  'ur pant': 346008,
#  'pant lmao': 269794,
#  "@ user 'm": 87435,
#  "user 'm fully": 347858,
#  "'m fully blocked": 50366,
#  'fully blocked ?': 180060,
#  'blocked ? ?': 118038,
#  '? ? lol': 85665,
#  '? lol dam': 86117,
#  "lol dam n't": 230743,
#  "dam n't know": 143746,
#  "n't know u": 252896,
#  'know u pissed': 220262,
#  'u pissed ur': 343479,
#  'pissed ur pant': 275592,
#  'ur pant lmao': 346009,
#  'check': 129823,
#  'shared': 305453,
#  'choosejoy': 131402,
#  'could': 138947,
#  'breakup': 121451,
#  'secret': 301478,
#  'via': 358298,
#  'check shared': 129952,
#  'shared #': 305454,
#  '# choosejoy': 13282,
#  'choosejoy #': 131403,
#  'healthy could': 200691,
#  'could breakup': 138996,
#  'breakup secret': 121459,
#  'secret healthy': 301512,
#  'healthy life': 200733,
#  'life ?': 226216,
#  '? via': 86486,
#  'via @': 358311,
#  'check shared #': 129953,
#  'shared # choosejoy': 305455,
#  '# choosejoy #': 13283,
#  'choosejoy # healthy': 131404,
#  '# healthy could': 23013,
#  'healthy could breakup': 200692,
#  'could breakup secret': 138997,
#  'breakup secret healthy': 121460,
#  'secret healthy life': 301513,
#  'healthy life ?': 200734,
#  'life ? via': 226228,
#  '? via @': 86488,
#  'via @ user': 358313,
#  'personalised': 273695,
#  '...': 71192,
#  'gbp': 182403,
#  '6.99': 80203,
#  'shop': 306721,
#  'cool': 138288,
#  'home': 204093,
#  'fun': 180089,
#  'personalised new': 273710,
#  'new ...': 257196,
#  '... gbp': 72216,
#  'gbp 6.99': 182440,
#  ...}

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'hidden_layer_sizes': [(10,)],
    'activation': ['tanh']
}

mlpc = MLPClassifier()
grid_search = GridSearchCV(mlpc,
                           param_grid,
                           cv=5,
                           scoring='roc_auc',
                           verbose=20,
                           refit=True,
                           n_jobs=-1)

# %%
grid_search.fit(X_train_v, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] activation=tanh, hidden_layer_sizes=(10,) .......................
# [CV] activation=tanh, hidden_layer_sizes=(10,) .......................
# [CV] activation=tanh, hidden_layer_sizes=(10,) .......................
# [CV] activation=tanh, hidden_layer_sizes=(10,) .......................
# [CV]  activation=tanh, hidden_layer_sizes=(10,), score=0.9657378686560694, total=16.1min
# [CV] activation=tanh, hidden_layer_sizes=(10,) .......................
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 16.1min
# [CV]  activation=tanh, hidden_layer_sizes=(10,), score=0.9644016414330027, total=16.2min
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 16.2min remaining: 24.3min
# [CV]  activation=tanh, hidden_layer_sizes=(10,), score=0.9636810980378373, total=16.2min
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed: 16.2min remaining: 10.8min
# [CV]  activation=tanh, hidden_layer_sizes=(10,), score=0.9616489313404157, total=16.3min
# [CV]  activation=tanh, hidden_layer_sizes=(10,), score=0.9678115949691298, total= 4.6min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 20.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 20.7min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'hidden_layer_sizes': [(10,)], 'activation': ['tanh']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=20)

# %%
grid_search.best_params_
# Out:
# {'activation': 'tanh', 'hidden_layer_sizes': (10,)}

# %%
mlp_clf = grid_search.best_estimator_

# %%
#mlp_clf.fit(X_train_v, y_train)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, classification_report

# %%
y_pred = mlp_clf.predict(X_test_v)

# %%
#confusion_matrix(y_test, y_pred)

# %%
print("roc_auc score: {}".format(roc_auc_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# roc_auc score: 0.7726805613961313
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5945
#           1       0.96      0.55      0.70       448
#
# avg / total       0.97      0.97      0.96      6393

# %%
X_all = vectorizer.transform(X)
y_all = y

# %%
mlp_clf.fit(X_all, y_all)
# Out:
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
df_test = pd.read_csv("dataset/test.csv")

# %%
df_test.head()
# Out:
#       id                                              tweet
# 0  31963  #studiolife #aislife #requires #passion #dedic...
# 1  31964   @user #white #supremacists want everyone to s...
# 2  31965  safe ways to heal your #acne!!    #altwaystohe...
# 3  31966  is the hp and the cursed child book up for res...
# 4  31967    3rd #bihday to my amazing, hilarious #nephew...

# %%
df_test['tweet'] = df_test['tweet'].apply(lambda x : tweets_lemm(x))

# %%
df_test.head()
# Out:
#       id                                              tweet
# 0  31963  # studiolife # aislife # requires # passion # ...
# 1  31964  @ user # white # supremacist want everyone to ...
# 2  31965  safe way to heal your # acne ! ! # altwaystohe...
# 3  31966  is the hp and the cursed child book up for res...
# 4  31967  3rd # bihday to my amazing , hilarious # nephe...

# %%
dtest = vectorizer.transform(df_test['tweet'])
test_pred = mlp_clf.predict(dtest)

# %%
df_test['label'] = test_pred

# %%
submission = df_test[['id','label']]

# %%
submission.to_csv('sub_rodixxi_mlpC_GS_lemma.csv', index=False)
