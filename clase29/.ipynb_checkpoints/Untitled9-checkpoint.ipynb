# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv", index_col=0)

# %%
df.sample(5)
# Out:
#        label                                              tweet
# id
# 10276      0   â #usd/cad trims gains to 1.2720 ahead of d...
# 17967      0  it's already half way to 2017 and i still don'...
# 7083       0  34 weeks #thiy #four #weeks #testosterone   #f...
# 8171       1  this is a completely justified call out on my ...
# 9560       0  @user ...#ourleadersaresleeping ...  ... #diss...

# %%
df["label"].unique()
# Out:
# array([0, 1])

# %%
df["tweet"].nunique()
# Out:
# 29530

# %%
df.size
# Out:
# 63924

# %%
df["tweet"].value_counts()
# Out:
# #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦                                                        319
# i finally found a way how to delete old tweets! you might find it useful as well:    #deletetweets                                           82
# aww yeah it's all good bing bong bing bong                                                                                                   75
# i'm so   and #grateful now that - #affirmations                                                                                              56
# @user you might be a libtard if... #libtard  #sjw #liberal #politics                                                                         40
# you might be a libtard if... #libtard  #sjw #liberal #politics                                                                               32
# ð #love #instagood #photooftheday top.tags #tbt #cute #me #beautiful #followme   #followâ¦                                               29
# have my lover stop being angry at me visit us..&gt;&gt;&gt;  #lover   #friend #astrologer #love                                              26
# #flagday2016   #flag #day #2016 #(30 #photos) buy things about "flag day 2016": â¦                                                          22
# get #up get   get  #enjoy #music #today #free #apps #free #music                                                                             21
# #sikh #temple vandalised in in #calgary, #wso condemns  act                                                                                  20
# @user #feminismiscancer #feminismisterrorism #feminismmuktbharat why  #malevote is ignored  @user                                            20
# save $$ no logins x brokers   #me #change #memes #love   #education #university                                                              17
# can #lighttherapy help with   or #depression?    #altwaystoheal  #healthy is #happy !!                                                       16
# does #magnettherapy really work?   #altwaystoheal #healing #healthy   !!                                                                     14
# #music as #therapy as a tool for #healing!   #altwaystoheal #healthy is  !!                                                                  14
# what is a #detoxdiet?  #altwaystoheal! #healthy  !                                                                                           14
# can #lighttherapy help with   or #depression?   #altwaystoheal #healthy is #happy !!                                                         14
# safe ways to heal your #acne!!    #altwaystoheal #healthy   #healing!!                                                                       14
# best #essentialoils for #anxiety !!     #healthy   #peace !!  #altwaystoheal !!                                                              14
# best essential oils for #healing!!    #altwaystoheal #healthy  !!                                                                            14
# looking to feel more #joy? join me and 20 speakers on the free summit #unleashyourjoy                                                        13
# best #lawofattraction #resources for #healing!    #altwaystoheal #healthy is  ! #idwp !                                                      13
# herbal sleep remedies that work!!  #altwaystoheal #healthy #healing   !!                                                                     13
# #raw food diet benefits! -    #altwaystoheal #healthy   #healing #peace #joy #love !!                                                        12
# can #lighttherapy help with #sad or #depression?    #altwaystoheal  #healthy is   !!                                                         12
# #lawofattraction for #healing!!    #altwaystoheal #healthy is  !!                                                                            12
#   happy day!  #altwaystoheal  #healthy                                                                                                       11
# best #essentialoils for #anxiety !!     #healthy   #peace !! #altwaystoheal !!                                                               11
# #saysomething   bull up: you will dominate your bull and you will direct it whatever you want it to do. when                                 11
#                                                                                                                                            ...
# racism won't cease. white priviledge must be beast. god, help us through this.   #melanin #poetry #write                                      1
# this is very sad ð¥ð¥                                                                                                                     1
# mmmm can't wait for my date with my handsomeðððððð  #pizzzza                                                                1
# #fashionblog   rooster simulation: i want to climb the vast expanse of mountains. it reached the leakage coc                                  1
# cute&amp;yammyð #strawberryacai#starbucks#nyc#dancer  @ new york, new york                                                                 1
# jerri and dixie is happy since she is blowing hard! on reddit: #dixie #jerri #since   #blowing                                                1
# ó¾§ new york ó¾§ #finally #newyork #best #vacation #love #mum #family #sweet #night #longtrip  !!!                                          1
# mr wings has a 6 page spread in a magazine that has just come out and is all sad because he isn't the coverboy lol                            1
# brent a nude makes for a very happy christmas and kerry and adrienne: #nude #makes #brent #very   #christmas                                  1
# if you want to be  , be kind to the #poor; it is a #sin to despise anyone.  #jesus #faith #believe #wisdom                                    1
# #bihdaygift   gorilla simulator: you need to do to adapt to the environment. the need to tear the city. ma                                    1
#  @user when you get home from working a 5-9, and your boyfriend worked til 5 so you didn't see him all day &amp; he is already aslâ¦         1
# finally deciding to sta my book tube channel!!!! #booktube   #reading                                                                         1
#   i keep hearing stories of sadness and i want it to stop. people make someones day! with a smile, a coffee, or just a touch.                 1
# do more of what makes you happy     #domoreofwhatmakesyouhappy #exploretheworldâ¦                                                            1
# do whatever makes you happy.  #pamperingmyself   life #saloon #hairdoâ¦                                                                      1
# suspected henrico vandal's mother: 'my son isn't racist'                                                                                      1
# i honestly wouldn't rather be anywhere else than ridin down the road, with a beautiful sunset comin, listenin to some luke with pals          1
# oh she blocked me.   at least i have love island to look forward to on sunday :)                                                              1
# mma fans: losses don't matter, it's great! mma fans about rhonda rousey: she's lost twice, she is trash.  #doublestandards                    1
# prayers to all victims and their families that were affected by the orlando shooting. violence must stop.                                     1
# it's so hot i'm happy lol ð
# ð #green #warm   #lala @ aliso and wood canyons wilderness park                                              1
# 3 bottles eh dug and he stas telling us he was already dead before them #deep                                                                 1
#  @user stone roses done. now time for @user in a d club.   days                                                                               1
# very   to be a pa of #oldpofest at mathew' pub in #poland #maine this year alongâ¦                                                           1
# first day of school!   #quinnhaley.                                                                                                           1
# seeing #findingdory today!!!  @user @user #dory #ellendegeneres   #fridayfun #movienight @user                                                1
# bye bye #hec! it was a pleasure! #hecgrad16 #graduation   #proud #happiness #masterâ¦                                                        1
# remember the day when people on #bbuk went on to become reality tv stars, no it seems reality tv stars become big brother contestants.        1
# saddie fattie.... #bigcheeks #smalllips  fattie  #fat #snapchat #exploding #puffedupâ¦                                                       1
# Name: tweet, Length: 29530, dtype: int64

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def tweets_lemm(tweet):
    lemmatizer = WordNetLemmatizer()
    word_list = nltk.word_tokenize(tweet)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output

# %%
df['tweet'] = df['tweet'].apply(lambda x : tweets_lemm(x))

# %%
from sklearn.model_selection import train_test_split

# %%
X = df["tweet"]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /home/rcrespillo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vectorizer = TfidfVectorizer(analyzer='word', 
                             tokenizer=nltk.word_tokenize, 
                             stop_words=stops, 
                             ngram_range=(1,3))

X_train_v = vectorizer.fit_transform(X_train)
X_test_v = vectorizer.transform(X_test)

# %%
X_train_v.shape
# Out:
# (25569, 390316)

# %%
vectorizer.vocabulary_
# Out:
# {'positive': 279083,
#  '.': 64365,
#  '#': 5970,
#  'i_am': 207230,
#  'affirmation': 94955,
#  'positive .': 279134,
#  '. #': 64372,
#  '# i_am': 24275,
#  'i_am #': 207231,
#  '# positive': 35723,
#  'positive #': 279086,
#  '# affirmation': 7429,
#  'positive . #': 279135,
#  '. # i_am': 65045,
#  '# i_am #': 24276,
#  'i_am # positive': 207232,
#  '# positive #': 35725,
#  'positive # affirmation': 279087,
#  'hope': 204523,
#  'weekend': 366333,
#  'happy': 196837,
#  'beautiful': 110832,
#  '!': 0,
#  ':': 81418,
#  ')': 56095,
#  'salonlife': 298179,
#  'stylist': 320737,
#  'vermontsalon': 357856,
#  '...': 71374,
#  'hope weekend': 204775,
#  'weekend happy': 366619,
#  'happy beautiful': 197129,
#  'beautiful !': 110833,
#  '! !': 1,
#  '! :': 2484,
#  ': )': 81675,
#  ') #': 56102,
#  '# beautiful': 9892,
#  'beautiful #': 110839,
#  '# salonlife': 38435,
#  'salonlife #': 298180,
#  '# stylist': 41644,
#  'stylist #': 320738,
#  '# vermontsalon': 45624,
#  'vermontsalon #': 357857,
#  '# weekend': 46468,
#  'weekend ...': 366502,
#  'hope weekend happy': 204777,
#  'weekend happy beautiful': 366620,
#  'happy beautiful !': 197130,
#  'beautiful ! !': 110834,
#  '! ! :': 32,
#  '! : )': 2489,
#  ': ) #': 81677,
#  ') # beautiful': 56116,
#  '# beautiful #': 9894,
#  'beautiful # salonlife': 110911,
#  '# salonlife #': 38436,
#  'salonlife # stylist': 298181,
#  '# stylist #': 41645,
#  'stylist # vermontsalon': 320739,
#  '# vermontsalon #': 45625,
#  'vermontsalon # weekend': 357858,
#  '# weekend ...': 46473,
#  '@': 86803,
#  'user': 346268,
#  'matter': 240772,
#  'week': 365805,
#  'away': 106168,
#  'pridemonth': 281835,
#  'pride': 281789,
#  'londonlgbtpride': 230788,
#  'excâ\x80¦': 164172,
#  '@ user': 87553,
#  'user @': 348313,
#  'user matter': 352465,
#  'matter week': 240882,
#  'week away': 365984,
#  'away :': 106217,
#  ': #': 81422,
#  '# pridemonth': 36104,
#  'pridemonth #': 281836,
#  '# pride': 36096,
#  'pride #': 281792,
#  '# londonlgbtpride': 28390,
#  'londonlgbtpride #': 230789,
#  '# excâ\x80¦': 18264,
#  '@ user @': 87705,
#  'user @ user': 348317,
#  '@ user matter': 89039,
#  'user matter week': 352466,
#  'matter week away': 240883,
#  'week away :': 365989,
#  'away : #': 106218,
#  ': # pridemonth': 81539,
#  '# pridemonth #': 36105,
#  'pridemonth # pride': 281837,
#  '# pride #': 36097,
#  'pride # londonlgbtpride': 281800,
#  '# londonlgbtpride #': 28391,
#  'londonlgbtpride # excâ\x80¦': 230790,
#  '100': 74649,
#  '%': 48972,
#  'right': 293928,
#  'single': 308799,
#  'singlelife': 308904,
#  'teamsingle': 327215,
#  'singlesquad': 308921,
#  'lonely': 230811,
#  'fml': 174601,
#  'lol': 230461,
#  '100 %': 74650,
#  '% right': 49115,
#  'right .': 293995,
#  '# #': 5977,
#  '# single': 39851,
#  'single #': 308802,
#  '# singlelife': 39856,
#  'singlelife #': 308905,
#  '# teamsingle': 42727,
#  'teamsingle #': 327216,
#  '# singlesquad': 39867,
#  'singlesquad #': 308922,
#  '# lonely': 28397,
#  'lonely #': 230812,
#  '# fml': 19737,
#  'fml #': 174602,
#  '# lol': 28351,
#  '100 % right': 74657,
#  '% right .': 49116,
#  'right . #': 293996,
#  '. # #': 64373,
#  '# # single': 6288,
#  '# single #': 39852,
#  'single # singlelife': 308821,
#  '# singlelife #': 39857,
#  'singlelife # teamsingle': 308906,
#  '# teamsingle #': 42728,
#  'teamsingle # singlesquad': 327217,
#  '# singlesquad #': 39868,
#  'singlesquad # lonely': 308923,
#  '# lonely #': 28398,
#  'lonely # fml': 230819,
#  '# fml #': 19738,
#  'fml # lol': 174606,
#  'another': 101534,
#  'day': 144673,
#  'music': 250608,
#  'song': 313413,
#  'selfie': 302950,
#  'another day': 101617,
#  'day #': 144755,
#  '# music': 31358,
#  'music #': 250612,
#  '# song': 40602,
#  'song #': 313418,
#  '# selfie': 39077,
#  'another day #': 101619,
#  'day # music': 144895,
#  '# music #': 31359,
#  'music # song': 250689,
#  '# song #': 40603,
#  'song # selfie': 313428,
#  'old': 264295,
#  'acquaintance': 93568,
#  'found': 176591,
#  'murdered': 250518,
#  'back': 107536,
#  'home': 203705,
#  'attack': 105032,
#  'orlando': 267211,
#  'mass': 240380,
#  'murder': 250484,
#  'roswell': 295871,
#  'even': 161496,
#  'mentioning': 243078,
#  'anywhere': 102578,
#  'else': 157999,
#  'old acquaintance': 264332,
#  'acquaintance found': 93569,
#  'found murdered': 176670,
#  'murdered back': 250526,
#  'back home': 107785,
#  'home .': 203776,
#  '. attack': 66730,
#  'attack orlando': 105101,
#  'orlando .': 267296,
#  '. mass': 68783,
#  'mass murder': 240392,
#  'murder roswell': 250513,
#  'roswell .': 295872,
#  '. even': 67492,
#  'even mentioning': 161738,
#  'mentioning anywhere': 243079,
#  'anywhere else': 102588,
#  'else .': 158020,
#  'old acquaintance found': 264333,
#  'acquaintance found murdered': 93570,
#  'found murdered back': 176671,
#  'murdered back home': 250527,
#  'back home .': 107788,
#  'home . attack': 203780,
#  '. attack orlando': 66731,
#  'attack orlando .': 105102,
#  'orlando . mass': 267303,
#  '. mass murder': 68784,
#  'mass murder roswell': 240395,
#  'murder roswell .': 250514,
#  'roswell . even': 295873,
#  '. even mentioning': 67502,
#  'even mentioning anywhere': 161739,
#  'mentioning anywhere else': 243080,
#  'anywhere else .': 102589,
#  'young': 377277,
#  'boy': 120343,
#  '-': 62872,
#  'asian': 104259,
#  'childhood': 130601,
#  'friend': 178206,
#  'young boy': 377328,
#  'boy -': 120400,
#  '- #': 62875,
#  '# asian': 8820,
#  'asian #': 104260,
#  '# boy': 11507,
#  'boy #': 120349,
#  '# childhood': 13320,
#  'childhood #': 130602,
#  '# friend': 20298,
#  'young boy -': 377329,
#  'boy - #': 120401,
#  '- # asian': 62886,
#  '# asian #': 8821,
#  'asian # boy': 104264,
#  '# boy #': 11508,
#  'boy # childhood': 120360,
#  '# childhood #': 13321,
#  'childhood # friend': 130606,
#  'obama': 262785,
#  'suppoing': 323349,
#  'communism+': 135736,
#  'islam': 212899,
#  'deadly': 147162,
#  'ideology': 207693,
#  "n't": 251901,
#  "'bout": 49573,
#  'race-only': 286059,
#  'nazi=â\x80¦': 255079,
#  'user #': 346302,
#  '# obama': 33316,
#  'obama suppoing': 262900,
#  'suppoing #': 323350,
#  '# communism+': 14154,
#  'communism+ #': 135737,
#  '# islam': 25584,
#  'islam another': 212927,
#  'another deadly': 101629,
#  'deadly ideology': 147163,
#  "ideology n't": 207703,
#  "n't 'bout": 251944,
#  "'bout #": 49574,
#  '# race-only': 36780,
#  'race-only suppoing': 286060,
#  '# nazi=â\x80¦': 31932,
#  '@ user #': 87555,
#  'user # obama': 347097,
#  '# obama suppoing': 33333,
#  'obama suppoing #': 262901,
#  'suppoing # communism+': 323352,
#  '# communism+ #': 14155,
#  'communism+ # islam': 135738,
#  '# islam another': 25587,
#  'islam another deadly': 212928,
#  'another deadly ideology': 101630,
#  "deadly ideology n't": 147164,
#  "ideology n't 'bout": 207704,
#  "n't 'bout #": 251945,
#  "'bout # race-only": 49575,
#  '# race-only suppoing': 36781,
#  'race-only suppoing #': 286061,
#  'suppoing # nazi=â\x80¦': 323353,
#  'precisely': 280765,
#  'opendata': 266374,
#  'book': 119208,
#  'club': 133225,
#  'precisely #': 280766,
#  '# opendata': 33760,
#  'opendata book': 266375,
#  'book club': 119282,
#  'club ...': 133242,
#  'precisely # opendata': 280767,
#  '# opendata book': 33761,
#  'opendata book club': 266376,
#  'book club ...': 119283,
#  'quotesforlife': 285649,
#  'gorilla': 189984,
#  'simulator': 308467,
#  'need': 255419,
#  'adapt': 94188,
#  'environment': 160237,
#  'tear': 327263,
#  'city': 131872,
#  '# quotesforlife': 36744,
#  'quotesforlife gorilla': 285650,
#  'gorilla simulator': 190003,
#  'simulator :': 308468,
#  ': need': 82517,
#  'need adapt': 255473,
#  'adapt environment': 94189,
#  'environment .': 160241,
#  '. need': 69010,
#  'need tear': 255823,
#  'tear city': 327288,
#  'city .': 131894,
#  '# quotesforlife gorilla': 36745,
#  'quotesforlife gorilla simulator': 285651,
#  'gorilla simulator :': 190004,
#  'simulator : need': 308469,
#  ': need adapt': 82518,
#  'need adapt environment': 255474,
#  'adapt environment .': 94190,
#  'environment . need': 160243,
#  '. need tear': 69030,
#  'need tear city': 255825,
#  'tear city .': 327289,
#  'filed': 171090,
#  'repo': 291958,
#  'one': 264876,
#  'find': 171806,
#  'since': 308484,
#  'friday': 177714,
#  'user filed': 350501,
#  'filed repo': 171091,
#  'repo one': 291978,
#  'one find': 265225,
#  'find !': 171807,
#  '! since': 4385,
#  'since friday': 308562,
#  'friday !': 177715,
#  '@ user filed': 88479,
#  'user filed repo': 350502,
#  'filed repo one': 171092,
#  'repo one find': 291979,
#  'one find !': 265226,
#  'find ! since': 171811,
#  '! since friday': 4386,
#  'since friday !': 308563,
#  'baby': 107112,
#  'graco': 191019,
#  'mode': 246129,
#  '3': 78155,
#  'lite': 228982,
#  'click': 132600,
#  'connect': 137111,
#  'travel': 338483,
#  'system': 324775,
#  'zeal': 378139,
#  'bouncingbaby': 120146,
#  '# baby': 9260,
#  'baby graco': 107278,
#  'graco mode': 191022,
#  'mode 3': 246138,
#  '3 lite': 78333,
#  'lite click': 228988,
#  'click connect': 132607,
#  'connect travel': 137116,
#  'travel system': 338592,
#  'system -': 324778,
#  '- zeal': 64000,
#  'zeal #': 378140,
#  '# bouncingbaby': 11484,
#  '# baby graco': 9277,
#  'baby graco mode': 107280,
#  'graco mode 3': 191023,
#  'mode 3 lite': 246139,
#  '3 lite click': 78334,
#  'lite click connect': 228989,
#  'click connect travel': 132608,
#  'connect travel system': 137117,
#  'travel system -': 338593,
#  'system - zeal': 324780,
#  '- zeal #': 64001,
#  'zeal # bouncingbaby': 378141,
#  'photobomb': 274341,
#  'bull': 123260,
#  'dominate': 152981,
#  'direct': 150915,
#  'whatever': 368003,
#  'want': 362688,
#  'yo': 376921,
#  '# photobomb': 34976,
#  'photobomb bull': 274344,
#  'bull :': 123263,
#  ': dominate': 82105,
#  'dominate bull': 152982,
#  'bull direct': 123267,
#  'direct whatever': 150920,
#  'whatever want': 368049,
#  'want .': 362724,
#  '. yo': 70714,
#  '# photobomb bull': 34978,
#  'photobomb bull :': 274345,
#  'bull : dominate': 123264,
#  ': dominate bull': 82106,
#  'dominate bull direct': 152983,
#  'bull direct whatever': 123268,
#  'direct whatever want': 150921,
#  'whatever want .': 368051,
#  'want . yo': 362737,
#  'expose': 164776,
#  'it..': 213289,
#  'mean': 241606,
#  'nothing': 261473,
#  'racist': 286226,
#  'say': 299331,
#  'waiting': 361856,
#  'user expose': 350350,
#  'expose .': 164777,
#  '. it..': 68306,
#  'it.. mean': 213292,
#  'mean nothing': 241705,
#  'nothing .': 261496,
#  '. expose': 67576,
#  'expose racist': 164787,
#  'racist say': 286339,
#  'say .': 299402,
#  '. waiting': 70472,
#  'waiting .': 361880,
#  '@ user expose': 88431,
#  'user expose .': 350351,
#  'expose . it..': 164778,
#  '. it.. mean': 68307,
#  'it.. mean nothing': 213293,
#  'mean nothing .': 241706,
#  'nothing . expose': 261498,
#  '. expose racist': 67577,
#  'expose racist say': 164789,
#  'racist say .': 286340,
#  'say . waiting': 299406,
#  '. waiting .': 70473,
#  'keyboard': 217866,
#  'warrior': 363550,
#  'typing': 342435,
#  'anything': 102416,
#  'retweets': 293195,
#  'wakeup': 362164,
#  'user keyboard': 351816,
#  'keyboard warrior': 217869,
#  'warrior typing': 363590,
#  'typing anything': 342436,
#  'anything retweets': 102499,
#  'retweets .': 293196,
#  '# wakeup': 46026,
#  '@ user keyboard': 88876,
#  'user keyboard warrior': 351817,
#  'keyboard warrior typing': 217870,
#  'warrior typing anything': 363591,
#  'typing anything retweets': 342437,
#  'anything retweets .': 102500,
#  'retweets . #': 293197,
#  '. # wakeup': 65842,
#  'â\x86\x9d': 380388,
#  'china': 130826,
#  'investment': 212266,
#  'data': 144275,
#  'cause': 127704,
#  'concern': 136448,
#  'danske': 144033,
#  'blog': 117950,
#  'silver': 308233,
#  'gold': 188166,
#  'forex': 176062,
#  'â\x86\x9d #': 380389,
#  '# china': 13384,
#  'china :': 130836,
#  ': investment': 82324,
#  'investment data': 212269,
#  'data cause': 144285,
#  'cause concern': 127742,
#  'concern -': 136451,
#  '- danske': 63322,
#  'danske #': 144034,
#  '# blog': 11038,
#  'blog #': 117956,
#  '# silver': 39786,
#  'silver #': 308234,
#  '# gold': 21664,
#  'gold #': 188170,
#  '# forex': 19987,
#  'â\x86\x9d # china': 380412,
#  '# china :': 13388,
#  'china : investment': 130837,
#  ': investment data': 82325,
#  'investment data cause': 212270,
#  'data cause concern': 144286,
#  'cause concern -': 127743,
#  'concern - danske': 136452,
#  '- danske #': 63323,
#  'danske # blog': 144035,
#  '# blog #': 11040,
#  'blog # silver': 117970,
#  '# silver #': 39787,
#  'silver # gold': 308236,
#  '# gold #': 21666,
#  'gold # forex': 188172,
#  'â\x9a¡ï¸\x8f': 381051,
#  'â\x80\x9c': 380017,
#  'charlespaladino': 129411,
#  "'s": 51976,
#  'comment': 135434,
#  'spark': 314589,
#  'call': 124885,
#  'resignationâ\x80\x9d': 292398,
#  'â\x9a¡ï¸\x8f â\x80\x9c': 381057,
#  'â\x80\x9c #': 380018,
#  '# charlespaladino': 13110,
#  "charlespaladino 's": 129412,
#  "'s comment": 52674,
#  'comment spark': 135514,
#  'spark call': 314597,
#  'call #': 124887,
#  '# resignationâ\x80\x9d': 37531,
#  'â\x9a¡ï¸\x8f â\x80\x9c #': 381058,
#  'â\x80\x9c # charlespaladino': 380019,
#  "# charlespaladino 's": 13111,
#  "charlespaladino 's comment": 129413,
#  "'s comment spark": 52677,
#  'comment spark call': 135515,
#  'spark call #': 314598,
#  'call # resignationâ\x80\x9d': 124897,
#  'born': 119783,
#  'perfect': 272975,
#  'great': 191614,
#  '=': 85140,
#  'user born': 349103,
#  'born #': 119788,
#  '# perfect': 34762,
#  'perfect :': 273000,
#  ') great': 56511,
#  'great day': 191742,
#  'day =': 145272,
#  '= )': 85158,
#  '@ user born': 87953,
#  'user born #': 349104,
#  'born # perfect': 119790,
#  '# perfect :': 34765,
#  'perfect : )': 273001,
#  ': ) great': 81705,
#  ') great day': 56513,
#  'great day =': 191749,
#  'day = )': 145273,
#  'idea': 207573,
#  'love': 232862,
#  'much': 249742,
#  'weird': 366964,
#  'really': 288874,
#  'favorite': 168788,
#  'person': 273405,
#  'ever': 162156,
#  'idea love': 207619,
#  'love much': 233968,
#  'much .': 249793,
#  ". 's": 66049,
#  "'s weird": 54783,
#  'weird @': 366976,
#  'user really': 353813,
#  'really favorite': 288999,
#  'favorite person': 168846,
#  'person ever': 273488,
#  'idea love much': 207620,
#  'love much .': 233971,
#  "much . 's": 249795,
#  ". 's weird": 66149,
#  "'s weird @": 54784,
#  'weird @ user': 366977,
#  '@ user really': 89462,
#  'user really favorite': 353820,
#  'really favorite person': 289000,
#  'favorite person ever': 168847,
#  'ten': 327918,
#  'till': 333200,
#  'go': 186346,
#  'manchester': 239111,
#  'see': 301547,
#  '14': 75265,
#  'ten day': 327926,
#  'day till': 146314,
#  'till go': 333258,
#  'go manchester': 186794,
#  'manchester see': 239125,
#  'see @': 301664,
#  'user see': 354188,
#  'user 14': 348078,
#  '14 day': 75275,
#  'ten day till': 327928,
#  'day till go': 146324,
#  'till go manchester': 333261,
#  'go manchester see': 186795,
#  'manchester see @': 239126,
#  'see @ user': 301665,
#  '@ user see': 89586,
#  'user see @': 354193,
#  '@ user 14': 87631,
#  'user 14 day': 348079,
#  'year': 375736,
#  ',': 57090,
#  'misplacing': 245292,
#  'priority': 282067,
#  'others': 267680,
#  'showing': 307395,
#  'u': 342482,
#  'year ,': 375799,
#  ', misplacing': 60603,
#  'misplacing priority': 245293,
#  'priority ,': 282069,
#  ', others': 61004,
#  'others showing': 267765,
#  'showing u': 307418,
#  'u .': 342579,
#  'year , misplacing': 375807,
#  ', misplacing priority': 60604,
#  'misplacing priority ,': 245294,
#  'priority , others': 282070,
#  ', others showing': 61006,
#  'others showing u': 267766,
#  'showing u .': 307419,
#  'come': 134623,
#  'galleta': 181082,
#  '*': 56764,
#  '1aã±o': 75975,
#  'andrã©s': 100654,
#  'muecas': 250220,
#  'bocadepatoâ\x80¦': 118731,
#  'come come': 134755,
#  'come galleta': 134811,
#  'galleta :': 181083,
#  ': *': 81733,
#  '* #': 56765,
#  '# 1aã±o': 6553,
#  '1aã±o #': 75976,
#  '# andrã©s': 8295,
#  'andrã©s #': 100655,
#  '# muecas': 31265,
#  'muecas #': 250221,
#  '# bocadepatoâ\x80¦': 11216,
#  'come come galleta': 134756,
#  'come galleta :': 134812,
#  'galleta : *': 181084,
#  ': * #': 81734,
#  '* # 1aã±o': 56766,
#  '# 1aã±o #': 6554,
#  '1aã±o # andrã©s': 75977,
#  '# andrã©s #': 8296,
#  'andrã©s # muecas': 100656,
#  '# muecas #': 31266,
#  'muecas # bocadepatoâ\x80¦': 250222,
#  'top': 336967,
#  'cece..': 128103,
#  'lastday': 221957,
#  'farwellpay': 167568,
#  'bestfriends': 113611,
#  'bestpaner': 113722,
#  'seeyouontopâ\x80¦': 302695,
#  'see top': 302194,
#  'top cece..': 337008,
#  'cece.. .': 128104,
#  '. .': 66244,
#  '# lastday': 27266,
#  'lastday #': 221958,
#  '# farwellpay': 18698,
#  'farwellpay #': 167569,
#  '# bestfriends': 10317,
#  'bestfriends #': 113612,
#  '# bestpaner': 10353,
#  'bestpaner #': 113723,
#  '# seeyouontopâ\x80¦': 39013,
#  'see top cece..': 302195,
#  'top cece.. .': 337009,
#  'cece.. . .': 128105,
#  '. . .': 66250,
#  '. . #': 66245,
#  '. # lastday': 65128,
#  '# lastday #': 27267,
#  'lastday # farwellpay': 221959,
#  '# farwellpay #': 18699,
#  'farwellpay # bestfriends': 167570,
#  '# bestfriends #': 10318,
#  'bestfriends # bestpaner': 113614,
#  '# bestpaner #': 10354,
#  'bestpaner # seeyouontopâ\x80¦': 113724,
#  'root': 295718,
#  'thing': 330649,
#  '?': 85257,
#  'â\x9d¤ï¸\x8fð\x9f\x8c±': 381776,
#  'forest': 175908,
#  'life': 225674,
#  'inlove': 210387,
#  'givelove': 185686,
#  'exploring': 164738,
#  'freedomâ\x80¦': 177465,
#  'root thing': 295738,
#  'thing ?': 330719,
#  '? â\x9d¤ï¸\x8fð\x9f\x8c±': 86697,
#  'â\x9d¤ï¸\x8fð\x9f\x8c± #': 381777,
#  '# root': 38095,
#  'root #': 295719,
#  '# forest': 19957,
#  'forest #': 175909,
#  '# life': 27812,
#  'life #': 225691,
#  '# love': 28572,
#  'love #': 232884,
#  '# inlove': 25010,
#  'inlove #': 210388,
#  '# givelove': 21399,
#  'givelove #': 185687,
#  '# exploring': 18324,
#  'exploring #': 164741,
#  '# freedomâ\x80¦': 20150,
#  'root thing ?': 295739,
#  'thing ? â\x9d¤ï¸\x8fð\x9f\x8c±': 330722,
#  '? â\x9d¤ï¸\x8fð\x9f\x8c± #': 86698,
#  'â\x9d¤ï¸\x8fð\x9f\x8c± # root': 381778,
#  '# root #': 38096,
#  'root # forest': 295720,
#  '# forest #': 19958,
#  'forest # life': 175911,
#  '# life #': 27814,
#  'life # love': 225784,
#  '# love #': 28574,
#  'love # inlove': 233122,
#  '# inlove #': 25011,
#  'inlove # givelove': 210392,
#  '# givelove #': 21400,
#  'givelove # exploring': 185688,
#  '# exploring #': 18325,
#  'exploring # freedomâ\x80¦': 164743,
#  'bihday': 114981,
#  'countdown': 139015,
#  '1': 74022,
#  'almost14': 97446,
#  '1day': 75988,
#  'ð\x9f\x8e\x89ð\x9f\x8e\x89': 383879,
#  'bihday countdown': 115317,
#  'countdown :': 139033,
#  ': 1': 81778,
#  '1 day': 74099,
#  'day !': 144674,
#  '! #': 492,
#  '# 14': 6495,
#  '14 #': 75266,
#  '# almost14': 7959,
#  'almost14 #': 97447,
#  '# 1day': 6560,
#  '1day ð\x9f\x8e\x89ð\x9f\x8e\x89': 75992,
#  'bihday countdown :': 115318,
#  'countdown : 1': 139034,
#  ': 1 day': 81779,
#  '1 day !': 74100,
#  'day ! !': 144675,
#  '! ! !': 2,
#  '! ! #': 3,
#  '! # 14': 500,
#  '# 14 #': 6496,
#  '14 # almost14': 75267,
#  '# almost14 #': 7960,
#  'almost14 # 1day': 97448,
#  '# 1day ð\x9f\x8e\x89ð\x9f\x8e\x89': 6562,
#  'hear': 200522,
#  'story': 319176,
#  'user want': 355742,
#  'want hear': 362945,
#  'hear story': 200629,
#  'story .': 319208,
#  '@ user want': 90029,
#  'user want hear': 355751,
#  'want hear story': 362946,
#  'hear story .': 200630,
#  'dear': 147278,
#  'democrat': 148726,
#  'djt': 152085,
#  'allowing': 97213,
#  'islamicradicals': 212988,
#  '2': 76191,
#  'use': 346008,
#  'america': 99119,
#  'freedom': 177406,
#  'destroy': 149717,
#  'r': 285683,
#  'islamophoâ\x80¦': 213048,
#  'user dear': 349842,
#  'dear #': 147281,
#  '# democrat': 15829,
#  'democrat ,': 148730,
#  ', djt': 58908,
#  'djt allowing': 152086,
#  'allowing #': 97214,
#  '# islamicradicals': 25599,
#  'islamicradicals 2': 212989,
#  '2 use': 76678,
#  'use america': 346026,
#  "america 's": 99144,
#  "'s freedom": 53160,
#  'freedom 2': 177423,
#  '2 destroy': 76367,
#  'destroy r': 149731,
#  'r freedom': 285738,
#  'freedom #': 177409,
#  '# islamophoâ\x80¦': 25619,
#  '@ user dear': 88232,
#  'user dear #': 349843,
#  'dear # democrat': 147283,
#  '# democrat ,': 15831,
#  'democrat , djt': 148731,
#  ', djt allowing': 58909,
#  'djt allowing #': 152087,
#  'allowing # islamicradicals': 97215,
#  '# islamicradicals 2': 25600,
#  'islamicradicals 2 use': 212990,
#  '2 use america': 76679,
#  "use america 's": 346027,
#  "america 's freedom": 99146,
#  "'s freedom 2": 53161,
#  'freedom 2 destroy': 177424,
#  '2 destroy r': 76369,
#  'destroy r freedom': 149732,
#  'r freedom #': 285739,
#  'freedom # islamophoâ\x80¦': 177411,
#  'stop': 318736,
#  'ating': 104916,
#  'father': 167971,
#  'son': 313269,
#  'stop ating': 318789,
#  'ating father': 104917,
#  'father son': 168242,
#  'stop ating father': 318790,
#  'ating father son': 104918,
#  "'m": 50220,
#  'â\x9b\x84': 381107,
#  'cold': 133938,
#  'inverno': 212224,
#  'winter': 369883,
#  'coat': 133599,
#  'gmorning': 186314,
#  'mirror': 245142,
#  'pooalegreâ\x80¦': 278497,
#  "'m back": 50357,
#  'back ...': 107591,
#  '... â\x9b\x84': 73100,
#  'â\x9b\x84 #': 381108,
#  '# cold': 13933,
#  'cold #': 133939,
#  '# inverno': 25412,
#  'inverno #': 212225,
#  '# winter': 47103,
#  'winter #': 369884,
#  '# coat': 13852,
#  'coat #': 133600,
#  '# gmorning': 21521,
#  'gmorning #': 186315,
#  '# mirror': 30483,
#  'mirror #': 245145,
#  'selfie #': 302954,
#  '# pooalegreâ\x80¦': 35591,
#  "'m back ...": 50358,
#  'back ... â\x9b\x84': 107598,
#  '... â\x9b\x84 #': 73101,
#  'â\x9b\x84 # cold': 381109,
#  '# cold #': 13934,
#  'cold # inverno': 133943,
#  '# inverno #': 25413,
#  'inverno # winter': 212226,
#  '# winter #': 47104,
#  'winter # coat': 369888,
#  '# coat #': 13853,
#  'coat # gmorning': 133601,
#  '# gmorning #': 21522,
#  'gmorning # mirror': 186316,
#  '# mirror #': 30484,
#  'mirror # selfie': 245147,
#  '# selfie #': 39079,
#  'selfie # #': 302955,
#  '# # pooalegreâ\x80¦': 6255,
#  '&': 49147,
#  'lt': 235581,
#  ';': 83049,
#  'listen': 228803,
#  'best': 113072,
#  'singing': 308758,
#  'amazing': 98679,
#  'voice': 359452,
#  'user &': 347511,
#  '& lt': 49152,
#  'lt ;': 235584,
#  '; 3': 83368,
#  '3 listen': 78331,
#  'listen beautiful': 228832,
#  'beautiful best': 110976,
#  'best friend': 113245,
#  'friend @': 178415,
#  'user singing': 354415,
#  'singing amazing': 308771,
#  'amazing voice': 98946,
#  'voice &': 359458,
#  '3 &': 78196,
#  '3 3': 78220,
#  '@ user &': 87557,
#  'user & lt': 347514,
#  '& lt ;': 49153,
#  'lt ; 3': 235590,
#  '; 3 listen': 83388,
#  '3 listen beautiful': 78332,
#  'listen beautiful best': 228833,
#  'beautiful best friend': 110977,
#  'best friend @': 113253,
#  'friend @ user': 178421,
#  '@ user singing': 89662,
#  'user singing amazing': 354416,
#  'singing amazing voice': 308772,
#  'amazing voice &': 98947,
#  'voice & lt': 359460,
#  '; 3 &': 83370,
#  '3 & lt': 78197,
#  '; 3 3': 83378,
#  'proud': 283313,
#  'present': 281074,
#  'smuggler': 311514,
#  'spring': 315763,
#  'collection': 134146,
#  '2016': 77009,
#  'releasethebeast': 291181,
#  'jager': 213886,
#  'proud present': 283439,
#  'present :': 281093,
#  ': happy': 82252,
#  'happy smuggler': 197792,
#  'smuggler spring': 311515,
#  'spring collection': 315787,
#  'collection 2016': 134159,
#  '2016 !': 77010,
#  '# releasethebeast': 37395,
#  'releasethebeast #': 291182,
#  '# jager': 25833,
#  'jager ...': 213887,
#  'proud present :': 283441,
#  'present : happy': 281094,
#  ': happy smuggler': 82260,
#  'happy smuggler spring': 197793,
#  'smuggler spring collection': 311516,
#  'spring collection 2016': 315788,
#  'collection 2016 !': 134160,
#  '2016 ! #': 77012,
#  '! # releasethebeast': 1742,
#  '# releasethebeast #': 37396,
#  'releasethebeast # jager': 291183,
#  '# jager ...': 25834,
#  'look': 231241,
#  'arrived': 103990,
#  "look 's": 231269,
#  "'s arrived": 52361,
#  'arrived @': 104015,
#  "look 's arrived": 231270,
#  "'s arrived @": 52363,
#  'arrived @ user': 104016,
#  'amp': 99607,
#  'grateful': 191432,
#  'money': 247044,
#  'increasing': 209536,
#  'quantity': 285062,
#  'multiple': 250319,
#  'source': 314250,
#  'continuous': 137666,
#  'basis': 109675,
#  '& amp': 49148,
#  'amp ;': 99608,
#  '; #': 83053,
#  '# grateful': 22116,
#  'grateful #': 191437,
#  '# money': 30828,
#  'money come': 247100,
#  'come #': 134632,
#  '# increasing': 24849,
#  'increasing quantity': 209541,
#  'quantity #': 285063,
#  '# multiple': 31293,
#  'multiple source': 250326,
#  'source #': 314251,
#  '# continuous': 14395,
#  'continuous basis': 137669,
#  '& amp ;': 49149,
#  'amp ; #': 99610,
#  '; # grateful': 83127,
#  '# grateful #': 22118,
#  'grateful # money': 191458,
#  '# money come': 30836,
#  'money come #': 247101,
#  'come # increasing': 134640,
#  '# increasing quantity': 24850,
#  'increasing quantity #': 209542,
#  'quantity # multiple': 285064,
#  ...}

# %%
from sklearn import decomposition

# %%
svd = decomposition.TruncatedSVD(n_components=2)

# %%
svd.fit(X_train_v)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=2, n_iter=5,
#        random_state=None, tol=0.0)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, classification_report

# %%
y_pred = mlp_clf.predict(X_test_v)

# %%
#confusion_matrix(y_test, y_pred)

# %%
print("roc_auc score: {}".format(roc_auc_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# roc_auc score: 0.7628268427850535
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5945
#           1       0.92      0.53      0.67       448
#
# avg / total       0.96      0.96      0.96      6393

# %%
X_all = vectorizer.transform(X)
y_all = y

# %%
mlp_clf.fit(X_all, y_all)
# Out:
# Iteration 1, loss = 0.45076652
# Iteration 2, loss = 0.24601258
# Iteration 3, loss = 0.14190490
# Iteration 4, loss = 0.08174407
# Iteration 5, loss = 0.04972015
# Iteration 6, loss = 0.03319932
# Iteration 7, loss = 0.02385617
# Iteration 8, loss = 0.01817407
# Iteration 9, loss = 0.01446235
# Iteration 10, loss = 0.01191282
# Iteration 11, loss = 0.01009742
# Iteration 12, loss = 0.00875664
# Iteration 13, loss = 0.00774495
# Iteration 14, loss = 0.00696281
# Iteration 15, loss = 0.00633324
# Iteration 16, loss = 0.00582839
# Iteration 17, loss = 0.00540767
# Iteration 18, loss = 0.00504763
# Iteration 19, loss = 0.00473986
# Iteration 20, loss = 0.00446822
# Iteration 21, loss = 0.00422901
# Iteration 22, loss = 0.00401109
# Iteration 23, loss = 0.00381435
# Iteration 24, loss = 0.00363354
# Iteration 25, loss = 0.00346945
# Iteration 26, loss = 0.00331397
# Iteration 27, loss = 0.00316922
# Iteration 28, loss = 0.00303260
# Iteration 29, loss = 0.00290545
# Iteration 30, loss = 0.00278692
# Iteration 31, loss = 0.00267435
# Iteration 32, loss = 0.00256730
# Iteration 33, loss = 0.00246583
# Iteration 34, loss = 0.00236869
# Iteration 35, loss = 0.00227923
# Iteration 36, loss = 0.00219202
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=True, warm_start=False)

# %%
df_test = pd.read_csv("dataset/test.csv")

# %%
df_test.sample(5)
# Out:
#           id                                              tweet
# 12936  44899  could we see a #deadrising4 at #e32016? only t...
# 14019  45982  @user seriously considered but too poor after ...
# 9000   40963   @user if only i had a boyfriend to bring me i...
# 5097   37060  boattrip with all the girls! @user #moderosa #...
# 233    32196  ð   #socialmedia may 2016 was hottest may o...

# %%
df_test['tweet'] = df_test['tweet'].apply(lambda x : tweets_lemm(x))

# %%
df_test.sample(5)
# Out:
#           id                                              tweet
# 12338  44301  not long now & amp ; @ user & amp ; i are off ...
# 3180   35143  @ user fundafield @ user cup team check in sta...
# 3052   35015  absolutely buzzing for friday ðð©ðð°...
# 3541   35504  @ user @ user thank you sooo much , i ca n't w...
# 1849   33812  @ user emma stone on hollywood : `` they 've g...

# %%
dtest = vectorizer.transform(df_test['tweet'])
test_pred = mlp_clf.predict(dtest)

# %%
df_test['label'] = test_pred

# %%
submission = df_test[['id','label']]

# %%
submission.to_csv('sub_rodixxi_mlpc_lemmatizer_2-1.csv', index=False)
