# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv", index_col=0)

# %%
df.sample(5)
# Out:
#        label                                              tweet
# id
# 19449      0  so looking forward to my spa day tomorrow!!! @...
# 9685       0  a very   #bihday to the #gorgeous, sonam kapoo...
# 2694       0  tomorrow it's been 30 years you died... i miss...
# 23624      0  the waiting is almost over...#pratice 1 #europ...
# 30347      0  _animaladvocate: the "#dairy industry" destroy...

# %%
df["label"].unique()
# Out:
# array([0, 1])

# %%
df["tweet"].nunique()
# Out:
# 29530

# %%
df.size
# Out:
# 63924

# %%
df["tweet"].value_counts()
# Out:
# #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦                                                        319
# i finally found a way how to delete old tweets! you might find it useful as well:    #deletetweets                                           82
# aww yeah it's all good bing bong bing bong                                                                                                   75
# i'm so   and #grateful now that - #affirmations                                                                                              56
# @user you might be a libtard if... #libtard  #sjw #liberal #politics                                                                         40
# you might be a libtard if... #libtard  #sjw #liberal #politics                                                                               32
# ð #love #instagood #photooftheday top.tags #tbt #cute #me #beautiful #followme   #followâ¦                                               29
# have my lover stop being angry at me visit us..&gt;&gt;&gt;  #lover   #friend #astrologer #love                                              26
# #flagday2016   #flag #day #2016 #(30 #photos) buy things about "flag day 2016": â¦                                                          22
# get #up get   get  #enjoy #music #today #free #apps #free #music                                                                             21
# @user #feminismiscancer #feminismisterrorism #feminismmuktbharat why  #malevote is ignored  @user                                            20
# #sikh #temple vandalised in in #calgary, #wso condemns  act                                                                                  20
# save $$ no logins x brokers   #me #change #memes #love   #education #university                                                              17
# can #lighttherapy help with   or #depression?    #altwaystoheal  #healthy is #happy !!                                                       16
# #music as #therapy as a tool for #healing!   #altwaystoheal #healthy is  !!                                                                  14
# does #magnettherapy really work?   #altwaystoheal #healing #healthy   !!                                                                     14
# best essential oils for #healing!!    #altwaystoheal #healthy  !!                                                                            14
# what is a #detoxdiet?  #altwaystoheal! #healthy  !                                                                                           14
# can #lighttherapy help with   or #depression?   #altwaystoheal #healthy is #happy !!                                                         14
# safe ways to heal your #acne!!    #altwaystoheal #healthy   #healing!!                                                                       14
# best #essentialoils for #anxiety !!     #healthy   #peace !!  #altwaystoheal !!                                                              14
# best #lawofattraction #resources for #healing!    #altwaystoheal #healthy is  ! #idwp !                                                      13
# looking to feel more #joy? join me and 20 speakers on the free summit #unleashyourjoy                                                        13
# herbal sleep remedies that work!!  #altwaystoheal #healthy #healing   !!                                                                     13
# can #lighttherapy help with #sad or #depression?    #altwaystoheal  #healthy is   !!                                                         12
# #raw food diet benefits! -    #altwaystoheal #healthy   #healing #peace #joy #love !!                                                        12
# #lawofattraction for #healing!!    #altwaystoheal #healthy is  !!                                                                            12
# can #atherapy and #musictherapy heal your life?   #altwaystoheal #healthy   #healing!                                                        11
# stuck in the rat race? find your freedom.   #masterkeyexperience                                                                             11
# #saysomething   bull up: you will dominate your bull and you will direct it whatever you want it to do. when                                 11
#                                                                                                                                            ...
# doing my first exterior job on a home tomorrow.   #cuttingtuition                                                                             1
# i guess some girls need to use a creepy man to pay for things they can't afford bc they aren't independent enough to get it themselves        1
# no one but you can make you   #quote                                                                                                          1
# #shineythings make me   #yellowstatuspresenter #younique next stop #pinkstatus                                                                1
# via @user hi there :) we just want to say have a relaxing and   #weekend! #                                                                   1
# #my_qoute_of_the_day.        being   with the #right people is better than being #happy with the #wrong ones.. #philippos                     1
# @user   ð to have a payslip of the lovely shop where i work #label for realâ¦                                                             1
# when you make an offer on the house of your dreams, only to find out someone else made an offer 15 minutes earlier.   #alanismorissette       1
# love saves the day!  eastville park, bristol, may bank holiday 2016.  #lovesavestheday #lstd #bristol   #payâ¦                               1
#  @user @user @user @user @user @user #americans have a right to be   over this #massacre!                                                     1
# just reading trumps tweets makes my hea hu, if this man becomes president many lives will become turmoil &amp; some don't even know it        1
# @user @user unfounately death toll might go up.                                                                                               1
# this #makes me so    |                                                                                                                        1
# so #american to want #intelligent #cars !!  !                                                                                                 1
# now playing #pharrellwilliams -   on classic rock attic                                                                                       1
# heading to new smyrna beach ~ they have never seen the ocean before  !                                                                        1
# bubbles!  #bubbles #pink                                                                                                                      1
# just got tickets to see @user sept 29 irvine. first time live can't wait.   #blink182                                                         1
# #saturday   #weekend ð»âï¸ð great way to sta the weekend ðð¾ð· stay activeð #walk #hike #runâ¦                             1
# 7 steps to #healthy and   #aging                                                                                                              1
# soulmate ððð #mommy #daughter   #together #soulmate #rubygrace #medan                                                                1
# hiding behind a phone/tweet. shows the kind of person you are   #pathetic #look@user ðð                                                 1
# i'm going back to school  tomorrow........ aishhhhh,,,nervous&lt;3    #backtoschool                                                           1
# ð installation day-makes me   @user #outdoors #furniture clientsalwayâ¦                                                                   1
# #quote of the day:âallow #children to be   in their own way, for what better way will they find?â â samuel...                           1
# omg i loosed my homework                                                                                                                      1
# #fish   bull up: you will dominate your bull and you will direct it whatever you want it to do. when you sta                                  1
#  @user june 17th : officially repo-free and... orange is the new black new season is coming out                                               1
# at any given time that fouh emoji is on point ð©ð.                                                                                       1
# thoughts before turning 21ð­: i don't want to get older... time needs to stop ðð° #beforebihday   #youngforever #iwish                 1
# Name: tweet, Length: 29530, dtype: int64

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def tweets_lemm(tweet):
    lemmatizer = WordNetLemmatizer()
    word_list = nltk.word_tokenize(tweet)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output

# %%
df['tweet'] = df['tweet'].apply(lambda x : tweets_lemm(x))

# %%
from sklearn.model_selection import train_test_split

# %%
X = df["tweet"]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /home/rcrespillo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vectorizer = TfidfVectorizer(analyzer='word', 
                             tokenizer=nltk.word_tokenize, 
                             stop_words=stops, 
                             ngram_range=(1,3))

X_train_v = vectorizer.fit_transform(X_train)
X_test_v = vectorizer.transform(X_test)

# %%
X_train_v.shape
# Out:
# (25569, 391320)

# %%
vectorizer.vocabulary_
# Out:
# {'@': 86913,
#  'user': 347344,
#  "'ll": 49806,
#  "'treading": 54880,
#  'board': 118912,
#  "'": 49029,
#  'famous': 167625,
#  'theatre': 330962,
#  'le': 223879,
#  'month': 248110,
#  '!': 0,
#  'ticket': 333899,
#  ':': 81455,
#  'httâ\x80¦': 207038,
#  '@ user': 87675,
#  "user 'll": 348587,
#  "'ll 'treading": 49817,
#  "'treading board": 54881,
#  "board '": 118919,
#  "' famous": 49205,
#  'famous theatre': 167653,
#  'theatre le': 330986,
#  'le month': 223949,
#  'month !': 248111,
#  '! ticket': 4614,
#  'ticket :': 333930,
#  ': httâ\x80¦': 82340,
#  "@ user 'll": 87687,
#  "user 'll 'treading": 348588,
#  "'ll 'treading board": 49818,
#  "'treading board '": 54882,
#  "board ' famous": 118920,
#  "' famous theatre": 49206,
#  'famous theatre le': 167654,
#  'theatre le month': 330987,
#  'le month !': 223950,
#  'month ! ticket': 248116,
#  '! ticket :': 4616,
#  'ticket : httâ\x80¦': 333931,
#  '#': 5994,
#  'sadieschoice': 298509,
#  'bedoubleyouproductions': 111957,
#  'wish': 371115,
#  'u': 343606,
#  'fathersday': 168971,
#  'today': 335807,
#  'music': 251437,
#  '4u': 79644,
#  'enjoy': 160088,
#  '# sadieschoice': 38468,
#  'sadieschoice #': 298510,
#  '# bedoubleyouproductions': 10043,
#  'bedoubleyouproductions wish': 111958,
#  'wish u': 371286,
#  'u fathersday': 343981,
#  'fathersday #': 168981,
#  '# fathersday': 18879,
#  'fathersday today': 169157,
#  'today #': 335858,
#  '# music': 31488,
#  'music 4u': 251563,
#  '4u !': 79645,
#  '! #': 506,
#  '# enjoy': 17852,
#  '# sadieschoice #': 38469,
#  'sadieschoice # bedoubleyouproductions': 298511,
#  '# bedoubleyouproductions wish': 10044,
#  'bedoubleyouproductions wish u': 111959,
#  'wish u fathersday': 371289,
#  'u fathersday #': 343982,
#  'fathersday # fathersday': 169007,
#  '# fathersday today': 18918,
#  'fathersday today #': 169158,
#  'today # music': 335908,
#  '# music 4u': 31494,
#  'music 4u !': 251564,
#  '4u ! #': 79646,
#  '! # enjoy': 986,
#  'â\x86\x9d': 381403,
#  'italy': 214096,
#  'industrial': 210818,
#  'output': 269041,
#  'w.d.a': 361062,
#  '(': 55306,
#  'yoy': 378741,
#  ')': 56061,
#  'increased': 210373,
#  '1.8': 74388,
#  '%': 48859,
#  'april': 103477,
#  'previous': 282496,
#  '0.5': 73829,
#  'blog': 118289,
#  'silver': 309266,
#  'gold': 188973,
#  'fâ\x80¦': 181562,
#  'â\x86\x9d #': 381404,
#  '# italy': 25762,
#  'italy industrial': 214116,
#  'industrial output': 210819,
#  'output w.d.a': 269046,
#  'w.d.a (': 361063,
#  '( yoy': 56043,
#  'yoy )': 378742,
#  ') increased': 56508,
#  'increased 1.8': 210378,
#  '1.8 %': 74389,
#  '% april': 48925,
#  'april previous': 103484,
#  'previous 0.5': 282509,
#  '0.5 %': 73830,
#  '% #': 48860,
#  '# blog': 11101,
#  'blog #': 118294,
#  '# silver': 39883,
#  'silver #': 309267,
#  '# gold': 21783,
#  'gold #': 188977,
#  '# fâ\x80¦': 20773,
#  'â\x86\x9d # italy': 381459,
#  '# italy industrial': 25766,
#  'italy industrial output': 214117,
#  'industrial output w.d.a': 210821,
#  'output w.d.a (': 269047,
#  'w.d.a ( yoy': 361064,
#  '( yoy )': 56044,
#  'yoy ) increased': 378745,
#  ') increased 1.8': 56510,
#  'increased 1.8 %': 210379,
#  '1.8 % april': 74390,
#  '% april previous': 48927,
#  'april previous 0.5': 103485,
#  'previous 0.5 %': 282510,
#  '0.5 % #': 73831,
#  '% # blog': 48864,
#  '# blog #': 11103,
#  'blog # silver': 118308,
#  '# silver #': 39884,
#  'silver # gold': 309269,
#  '# gold #': 21785,
#  'gold # fâ\x80¦': 188981,
#  'awful': 106836,
#  ',': 57040,
#  'mean': 242391,
#  'world': 374011,
#  'live': 230356,
#  'scaredfohefuture': 300979,
#  'awful ,': 106837,
#  ', mean': 60545,
#  'mean world': 242545,
#  'world live': 374277,
#  'live !': 230357,
#  '# scaredfohefuture': 38848,
#  'awful , mean': 106838,
#  ', mean world': 60555,
#  'mean world live': 242547,
#  'world live !': 374278,
#  'live ! #': 230359,
#  '! # scaredfohefuture': 1786,
#  'give': 186195,
#  'chance': 129269,
#  'â\x9d¤': 382492,
#  'user give': 351937,
#  'give #': 186196,
#  '# chance': 13125,
#  'chance â\x9d¤': 129328,
#  'â\x9d¤ @': 382520,
#  'user @': 349369,
#  '@ user give': 88714,
#  'user give #': 351938,
#  'give # chance': 186197,
#  '# chance â\x9d¤': 13127,
#  'chance â\x9d¤ @': 129329,
#  'â\x9d¤ @ user': 382523,
#  '@ user @': 87821,
#  'user @ user': 349375,
#  'model': 246894,
#  'love': 233730,
#  'take': 326265,
#  'time': 334342,
#  'urð\x9f\x93±': 346904,
#  'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 389580,
#  'ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 386954,
#  '# model': 30797,
#  'model love': 246934,
#  'love u': 235079,
#  'u take': 344457,
#  'take u': 326585,
#  'u time': 344478,
#  'time urð\x9f\x93±': 335112,
#  'urð\x9f\x93± !': 346905,
#  '! !': 1,
#  '! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 5807,
#  'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91 ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 389581,
#  '# model love': 30800,
#  'model love u': 246935,
#  'love u take': 235089,
#  'u take u': 344460,
#  'take u time': 326588,
#  'u time urð\x9f\x93±': 344481,
#  'time urð\x9f\x93± !': 335113,
#  'urð\x9f\x93± ! !': 346906,
#  '! ! !': 2,
#  '! ! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 470,
#  '! ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91 ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 5808,
#  '1': 74021,
#  'day': 145138,
#  '21': 77342,
#  'sunday': 323148,
#  'burday': 123942,
#  'happines': 197421,
#  'edda': 157616,
#  '1 day': 74089,
#  'day 21': 145670,
#  '21 #': 77343,
#  '# sunday': 41929,
#  'sunday #': 323161,
#  '# burday': 12189,
#  'burday #': 123943,
#  '# happines': 22856,
#  'happines edda': 197426,
#  '1 day 21': 74092,
#  'day 21 #': 145671,
#  '21 # sunday': 77344,
#  '# sunday #': 41930,
#  'sunday # burday': 323171,
#  '# burday #': 12190,
#  'burday # happines': 123944,
#  '# happines edda': 22858,
#  'trainhard': 339209,
#  'polar': 278864,
#  'bear': 110849,
#  'climb': 133202,
#  'racing': 286937,
#  'angry': 101063,
#  'living': 230816,
#  'cold': 134416,
#  'place': 276700,
#  'lo': 231041,
#  '# trainhard': 44202,
#  'trainhard polar': 339214,
#  'polar bear': 278865,
#  'bear climb': 110869,
#  'climb racing': 133207,
#  'racing :': 286943,
#  ': angry': 81954,
#  'angry polar': 101156,
#  'racing ,': 286941,
#  ', polar': 61191,
#  'bear living': 110875,
#  'living cold': 230853,
#  'cold place': 134454,
#  'place lo': 276824,
#  '# trainhard polar': 44205,
#  'trainhard polar bear': 339215,
#  'polar bear climb': 278867,
#  'bear climb racing': 110870,
#  'climb racing :': 133209,
#  'racing : angry': 286944,
#  ': angry polar': 81956,
#  'angry polar bear': 101157,
#  'climb racing ,': 133208,
#  'racing , polar': 286942,
#  ', polar bear': 61192,
#  'polar bear living': 278868,
#  'bear living cold': 110876,
#  'living cold place': 230857,
#  'cold place lo': 134456,
#  'oh': 264730,
#  'thank': 329797,
#  '4': 78982,
#  '.': 64432,
#  'country': 139629,
#  'die': 150751,
#  'child': 130736,
#  'safe': 298582,
#  'america': 99336,
#  'oh love': 264839,
#  'love thank': 235046,
#  'thank 4': 329840,
#  '4 .': 79017,
#  '. love': 68693,
#  'love country': 234482,
#  'country die': 139692,
#  'die child': 150769,
#  'child safe': 130910,
#  'safe day': 298612,
#  'day america': 145784,
#  'oh love thank': 264840,
#  'love thank 4': 235047,
#  'thank 4 .': 329841,
#  '4 . love': 79019,
#  '. love country': 68700,
#  'love country die': 234483,
#  'country die child': 139693,
#  'die child safe': 150770,
#  'child safe day': 130911,
#  'safe day america': 298613,
#  'greek': 193219,
#  'girl': 185508,
#  'ana': 100655,
#  'sex': 305556,
#  'black': 117070,
#  'porn': 279762,
#  'greek girl': 193222,
#  'girl ana': 185696,
#  'ana sex': 100666,
#  'sex black': 305587,
#  'black girl': 117176,
#  'girl porn': 185894,
#  'greek girl ana': 193223,
#  'girl ana sex': 185697,
#  'ana sex black': 100667,
#  'sex black girl': 305588,
#  'black girl porn': 117177,
#  'successful': 321995,
#  'tweet': 342656,
#  'wa': 361250,
#  "n't": 252758,
#  'even': 162097,
#  'good': 189377,
#  'joke': 216297,
#  '...': 71389,
#  'successful tweet': 322037,
#  'tweet wa': 342794,
#  "wa n't": 361909,
#  "n't even": 253274,
#  'even good': 162275,
#  'good joke': 189698,
#  'joke ...': 216324,
#  'successful tweet wa': 322038,
#  "tweet wa n't": 342795,
#  "wa n't even": 361921,
#  "n't even good": 253297,
#  'even good joke': 162276,
#  'good joke ...': 189699,
#  'drinkin': 155371,
#  'coffee': 134243,
#  '&': 49022,
#  'amp': 99819,
#  ';': 83124,
#  'listening': 229752,
#  'story': 320196,
#  'bout': 120602,
#  'hilary': 203409,
#  'clinton': 133238,
#  'defended': 148488,
#  'set': 305286,
#  'free': 177846,
#  'brutal': 123184,
#  'rapist': 288213,
#  'knowing': 220965,
#  'guilty.ð\x9f\x98¤': 194384,
#  'drinkin coffee': 155372,
#  'coffee &': 134280,
#  '& amp': 49023,
#  'amp ;': 99820,
#  '; listening': 84401,
#  'listening story': 229798,
#  'story bout': 320252,
#  'bout hilary': 120621,
#  'hilary clinton': 203410,
#  'clinton defended': 133252,
#  'defended &': 148489,
#  '; set': 84837,
#  'set free': 305345,
#  'free brutal': 177915,
#  'brutal child': 123191,
#  'child rapist': 130906,
#  'rapist .': 288218,
#  '. knowing': 68456,
#  'knowing wa': 221005,
#  'wa guilty.ð\x9f\x98¤': 361744,
#  'drinkin coffee &': 155373,
#  'coffee & amp': 134281,
#  '& amp ;': 49024,
#  'amp ; listening': 100215,
#  '; listening story': 84403,
#  'listening story bout': 229799,
#  'story bout hilary': 320253,
#  'bout hilary clinton': 120622,
#  'hilary clinton defended': 203411,
#  'clinton defended &': 133253,
#  'defended & amp': 148490,
#  'amp ; set': 100401,
#  '; set free': 84838,
#  'set free brutal': 305346,
#  'free brutal child': 177916,
#  'brutal child rapist': 123192,
#  'child rapist .': 130907,
#  'rapist . knowing': 288219,
#  '. knowing wa': 68457,
#  'knowing wa guilty.ð\x9f\x98¤': 221006,
#  "'re": 51278,
#  'missing': 246301,
#  'amazing': 98892,
#  'icelollie': 208446,
#  'weather': 366273,
#  'rest': 293558,
#  'assured': 104995,
#  'asâ\x80¦': 105065,
#  "'re missing": 51656,
#  'missing #': 246302,
#  '# amazing': 8110,
#  'amazing #': 98904,
#  '# icelollie': 24472,
#  'icelollie weather': 208447,
#  'weather ,': 366285,
#  ', rest': 61526,
#  'rest assured': 293579,
#  "assured 're": 104996,
#  "'re asâ\x80¦": 51374,
#  "'re missing #": 51657,
#  'missing # amazing': 246303,
#  '# amazing #': 8112,
#  'amazing # icelollie': 98928,
#  '# icelollie weather': 24473,
#  'icelollie weather ,': 208448,
#  'weather , rest': 366286,
#  ', rest assured': 61527,
#  "rest assured 're": 293580,
#  "assured 're asâ\x80¦": 104997,
#  'wait': 362444,
#  'let': 225540,
#  'way': 365539,
#  'someone': 313581,
#  'ha': 195284,
#  'suggestion': 322272,
#  'need': 256300,
#  'playlist': 277754,
#  'next': 259669,
#  'stream': 320594,
#  'wait let': 362651,
#  'let way': 225843,
#  'way someone': 365877,
#  'someone ha': 313719,
#  'ha suggestion': 195870,
#  'suggestion need': 322273,
#  'need playlist': 256591,
#  'playlist next': 277770,
#  'next stream': 259870,
#  'wait let way': 362652,
#  'let way someone': 225844,
#  'way someone ha': 365878,
#  'someone ha suggestion': 313723,
#  'ha suggestion need': 195871,
#  'suggestion need playlist': 322274,
#  'need playlist next': 256592,
#  'playlist next stream': 277771,
#  'anyone': 102529,
#  'suppos': 324370,
#  'feminist': 171072,
#  'basis': 109920,
#  'care': 127078,
#  'white': 369477,
#  'centered': 128916,
#  'feminism': 171046,
#  "'s": 51903,
#  'disturbing': 152312,
#  'disgustinâ\x80¦': 151948,
#  'user anyone': 349710,
#  'anyone suppos': 102604,
#  'suppos clinton': 324375,
#  'clinton feminist': 133254,
#  'feminist basis': 171076,
#  'basis care': 109925,
#  'care white': 127191,
#  'white centered': 369551,
#  'centered feminism': 128917,
#  "feminism 's": 171055,
#  "'s disturbing": 52878,
#  'disturbing disgustinâ\x80¦': 152315,
#  '@ user anyone': 87928,
#  'user anyone suppos': 349716,
#  'anyone suppos clinton': 102605,
#  'suppos clinton feminist': 324377,
#  'clinton feminist basis': 133255,
#  'feminist basis care': 171077,
#  'basis care white': 109926,
#  'care white centered': 127192,
#  'white centered feminism': 369552,
#  "centered feminism 's": 128918,
#  "feminism 's disturbing": 171056,
#  "'s disturbing disgustinâ\x80¦": 52879,
#  'medical': 242732,
#  'humor': 207587,
#  'people': 272930,
#  'truth': 341454,
#  'feel': 169932,
#  'better': 114145,
#  'sad': 298053,
#  'true': 340663,
#  'husband': 207865,
#  'highlight': 203274,
#  '# medical': 30066,
#  'medical #': 242733,
#  '# humor': 24255,
#  'humor #': 207590,
#  '# people': 34803,
#  'people #': 272936,
#  '# truth': 44604,
#  'truth #': 341458,
#  '# feel': 19055,
#  'feel better': 170021,
#  'better #': 114151,
#  '# sad': 38456,
#  'sad #': 298062,
#  '# true': 44468,
#  'true love': 340770,
#  'love #': 233753,
#  '# husband': 24313,
#  'husband #': 207868,
#  '# highlight': 23624,
#  '# medical #': 30067,
#  'medical # humor': 242734,
#  '# humor #': 24256,
#  'humor # people': 207600,
#  '# people #': 34804,
#  'people # truth': 272993,
#  '# truth #': 44605,
#  'truth # feel': 341463,
#  '# feel better': 19057,
#  'feel better #': 170022,
#  'better # sad': 114160,
#  '# sad #': 38457,
#  'sad # true': 298092,
#  '# true love': 44475,
#  'true love #': 340771,
#  'love # husband': 233985,
#  '# husband #': 24314,
#  'husband # highlight': 207870,
#  'taking': 326688,
#  'gun': 194451,
#  'away': 106432,
#  'giving': 186500,
#  'honestly': 205176,
#  'doe': 152828,
#  'matter': 241578,
#  'gon': 189132,
#  'na': 254635,
#  'still': 319079,
#  'hateful': 199964,
#  'want': 363730,
#  'taking gun': 326720,
#  'gun away': 194496,
#  'away giving': 106520,
#  'giving people': 186547,
#  'people gun': 273346,
#  'gun ...': 194488,
#  '... honestly': 72530,
#  'honestly doe': 205181,
#  "doe n't": 152946,
#  "n't matter": 253830,
#  'matter people': 241664,
#  'people gon': 273336,
#  'gon na': 189137,
#  'na still': 254874,
#  'still hateful': 319248,
#  'hateful want': 199980,
#  'taking gun away': 326721,
#  'gun away giving': 194498,
#  'away giving people': 106521,
#  'giving people gun': 186548,
#  'people gun ...': 273347,
#  'gun ... honestly': 194489,
#  '... honestly doe': 72531,
#  "honestly doe n't": 205182,
#  "doe n't matter": 152979,
#  "n't matter people": 253836,
#  'matter people gon': 241665,
#  'people gon na': 273337,
#  'gon na still': 189205,
#  'na still hateful': 254875,
#  'still hateful want': 319249,
#  'always': 98391,
#  'tear': 328285,
#  'anime': 101363,
#  'always tear': 98727,
#  'tear #': 328288,
#  '# anime': 8430,
#  'always tear #': 98728,
#  'tear # anime': 328289,
#  'stuakenyon81': 321172,
#  'cover': 140145,
#  'reveal': 294169,
#  'swiftly': 325461,
#  'sharpens': 306502,
#  'fang': 167865,
#  'radicalisation': 287246,
#  'revenge': 294208,
#  'eevalancaster': 157940,
#  'stuakenyon81 #': 321173,
#  '# cover': 14706,
#  'cover #': 140147,
#  '# reveal': 37738,
#  'reveal !': 294170,
#  '! swiftly': 4526,
#  'swiftly sharpens': 325462,
#  'sharpens fang': 306503,
#  'fang ,': 167870,
#  ', #': 57050,
#  '# radicalisation': 36880,
#  'radicalisation &': 287249,
#  '; #': 83129,
#  '# revenge': 37740,
#  'revenge eevalancaster': 294215,
#  'stuakenyon81 # cover': 321174,
#  '# cover #': 14707,
#  'cover # reveal': 140156,
#  '# reveal !': 37739,
#  'reveal ! swiftly': 294171,
#  '! swiftly sharpens': 4527,
#  'swiftly sharpens fang': 325463,
#  'sharpens fang ,': 306505,
#  'fang , #': 167871,
#  ', # radicalisation': 57299,
#  '# radicalisation &': 36882,
#  'radicalisation & amp': 287250,
#  'amp ; #': 99822,
#  '; # revenge': 83278,
#  '# revenge eevalancaster': 37742,
#  'rip': 295334,
#  'french': 178239,
#  'police': 278916,
#  'man': 239507,
#  'wife': 370141,
#  'paris': 271057,
#  'rip french': 295402,
#  'french police': 178249,
#  'police man': 278952,
#  'man &': 239536,
#  '; wife': 85184,
#  'wife .': 370158,
#  '. time': 70232,
#  'time #': 334355,
#  '# paris': 34457,
#  'rip french police': 295403,
#  'french police man': 178250,
#  'police man &': 278953,
#  'man & amp': 239537,
#  'amp ; wife': 100551,
#  '; wife .': 85185,
#  'wife . time': 370162,
#  '. time #': 70233,
#  'time # paris': 334406,
#  'tonight': 337534,
#  'mystery': 252511,
#  'endeavor': 159564,
#  'witch': 371460,
#  'finale': 171972,
#  'goodtv': 190480,
#  'tonight @': 337655,
#  'user ha': 352242,
#  'ha @': 195322,
#  'user mystery': 353785,
#  'mystery endeavor': 252516,
#  'endeavor .': 159565,
#  '. @': 66554,
#  'ha good': 195589,
#  'good witch': 190054,
#  'witch finale': 371466,
#  'finale #': 171973,
#  '# goodtv': 21984,
#  'tonight @ user': 337656,
#  '@ user ha': 88785,
#  'user ha @': 352245,
#  'ha @ user': 195324,
#  '@ user mystery': 89260,
#  'user mystery endeavor': 353786,
#  'mystery endeavor .': 252517,
#  'endeavor . @': 159566,
#  '. @ user': 66562,
#  'user ha good': 352262,
#  'ha good witch': 195594,
#  'good witch finale': 190055,
#  'witch finale #': 371467,
#  'finale # goodtv': 171974,
#  'standard': 317798,
#  'work': 373148,
#  'volunteer': 360629,
#  'itwasagoodday': 214235,
#  'roxborough': 297002,
#  'reservoir': 293247,
#  'standard day': 317807,
#  'day work': 146871,
#  'work ...': 373276,
#  '... #': 71401,
#  '# volunteer': 45867,
#  'volunteer #': 360630,
#  '# itwasagoodday': 25826,
#  'itwasagoodday @': 214236,
#  '@ roxborough': 87544,
#  'roxborough reservoir': 297003,
#  'standard day work': 317808,
#  'day work ...': 146874,
#  'work ... #': 373277,
#  '... # volunteer': 71672,
#  '# volunteer #': 45868,
#  'volunteer # itwasagoodday': 360631,
#  '# itwasagoodday @': 25827,
#  'itwasagoodday @ roxborough': 214237,
#  '@ roxborough reservoir': 87545,
#  "'ve": 54898,
#  'got': 190897,
#  'first': 173183,
#  'ever': 162775,
#  'gig': 185368,
#  'angel': 100950,
#  'comedy': 135528,
#  "tonight 've": 337597,
#  "'ve got": 55034,
#  'got first': 191140,
#  'first ever': 173339,
#  'ever gig': 162905,
#  'gig angel': 185381,
#  'angel comedy': 100966,
#  "tonight 've got": 337598,
#  "'ve got first": 55042,
#  'got first ever': 191143,
#  'first ever gig': 173343,
#  'ever gig angel': 162906,
#  'gig angel comedy': 185382,
#  'look': 232124,
#  'like': 227883,
#  'gave': 182624,
#  'sander': 299385,
#  'much': 250532,
#  'credit': 141134,
#  'last': 222540,
#  'night': 260657,
#  'user look': 353233,
#  'look like': 232346,
#  'like gave': 228360,
#  'gave sander': 182661,
#  'sander much': 299393,
#  'much credit': 250651,
#  'credit last': 141140,
#  'last night': 222679,
#  'night .': 260737,
#  '@ user look': 89101,
#  'user look like': 353247,
#  'look like gave': 232375,
#  'like gave sander': 228361,
#  'gave sander much': 182662,
#  'sander much credit': 299394,
#  'much credit last': 250652,
#  'credit last night': 141141,
#  'last night .': 222685,
#  'aww': 106914,
#  'yeah': 376630,
#  'bing': 116464,
#  'bong': 119489,
#  'aww yeah': 106928,
#  "yeah 's": 376643,
#  "'s good": 53225,
#  'good bing': 189503,
#  'bing bong': 116467,
#  'bong bing': 119490,
#  "aww yeah 's": 106929,
#  "yeah 's good": 376644,
#  "'s good bing": 53230,
#  'good bing bong': 189504,
#  'bing bong bing': 116468,
#  'bong bing bong': 119491,
#  "'m": 50138,
#  'done': 153687,
#  'ð\x9f¤\x92': 390877,
#  'thanks': 330477,
#  'god': 187973,
#  'everything': 163778,
#  'ð\x9f\x98\x8a': 388393,
#  'happy': 197743,
#  'keep': 218037,
#  'smiling': 312326,
#  'ð\x9f\x98\x8að\x9f\x98\x87ð\x9f\x98\x89': 388615,
#  'strong': 320983,
#  "'m done": 50423,
#  'done ð\x9f¤\x92': 153884,
#  'ð\x9f¤\x92 thanks': 390878,
#  'thanks god': 330598,
#  'god everything': 188106,
#  'everything ð\x9f\x98\x8a': 163954,
#  'ð\x9f\x98\x8a happy': 388464,
#  'happy everything': 198272,
#  'everything take': 163929,
#  'take care': 326371,
#  'care keep': 127145,
#  'keep smiling': 218271,
#  'smiling ð\x9f\x98\x8að\x9f\x98\x87ð\x9f\x98\x89': 312399,
#  'ð\x9f\x98\x8að\x9f\x98\x87ð\x9f\x98\x89 #': 388616,
#  '# thanks': 43066,
#  'thanks #': 330483,
#  '# #': 6001,
#  '# strong': 41578,
#  "'m done ð\x9f¤\x92": 50431,
#  'done ð\x9f¤\x92 thanks': 153885,
#  'ð\x9f¤\x92 thanks god': 390879,
#  'thanks god everything': 330602,
#  'god everything ð\x9f\x98\x8a': 188107,
#  'everything ð\x9f\x98\x8a happy': 163955,
#  'ð\x9f\x98\x8a happy everything': 388465,
#  'happy everything take': 198273,
#  'everything take care': 163930,
#  'take care keep': 326376,
#  'care keep smiling': 127146,
#  'keep smiling ð\x9f\x98\x8að\x9f\x98\x87ð\x9f\x98\x89': 218278,
#  'smiling ð\x9f\x98\x8að\x9f\x98\x87ð\x9f\x98\x89 #': 312400,
#  'ð\x9f\x98\x8að\x9f\x98\x87ð\x9f\x98\x89 # thanks': 388617,
#  '# thanks #': 43068,
#  'thanks # #': 330484,
#  '# # strong': 6314,
#  'play': 277265,
#  'head': 200685,
#  'whenever': 369251,
#  'talk': 326867,
#  'know': 220468,
#  'assholeswillbeassholes': 104930,
#  'fuckmylife': 180250,
#  'tired': 335475,
#  'play head': 277352,
#  'head whenever': 200776,
#  'whenever talk': 369267,
#  'talk .': 326879,
#  '. know': 68445,
#  'know .': 220543,
#  '. #': 64438,
#  '# assholeswillbeassholes': 8913,
#  'assholeswillbeassholes #': 104931,
#  '# fuckmylife': 20551,
#  'fuckmylife #': 180251,
#  '# tired': 43819,
#  'play head whenever': 277353,
#  'head whenever talk': 200777,
#  'whenever talk .': 369268,
#  'talk . know': 326881,
#  '. know .': 68448,
#  'know . #': 220544,
#  '. # assholeswillbeassholes': 64529,
#  '# assholeswillbeassholes #': 8914,
#  'assholeswillbeassholes # fuckmylife': 104932,
#  '# fuckmylife #': 20552,
#  'fuckmylife # tired': 180252,
#  'everyone': 163464,
#  'blamed': 117605,
#  'black/brown': 117328,
#  'community': 136229,
#  'crack': 140460,
#  'blame': 117558,
#  '?': 85367,
#  'doublestandard': 154394,
#  'drugsâ\x80¦': 155711,
#  'everyone blamed': 163564,
#  'blamed black/brown': 117612,
#  'black/brown community': 117329,
#  'community crack': 136260,
#  'crack ;': 140464,
#  "; 's": 83358,
#  "'s blame": 52436,
#  'blame ?': 117565,
#  '? #': 85416,
#  '# doublestandard': 16802,
#  'doublestandard #': 154395,
#  '# drugsâ\x80¦': 17010,
#  'everyone blamed black/brown': 163565,
#  'blamed black/brown community': 117613,
#  'black/brown community crack': 117330,
#  'community crack ;': 136261,
#  "crack ; 's": 140465,
#  "; 's blame": 83360,
#  "'s blame ?": 52437,
#  'blame ? #': 117566,
#  '? # doublestandard': 85483,
#  '# doublestandard #': 16803,
#  'doublestandard # drugsâ\x80¦': 154396,
#  '2nd': 77971,
#  'wedding': 366514,
#  'anniversary': 101502,
#  'lt': 236385,
#  '3': 78133,
#  'truelove': 340830,
#  'pougueseitalian': 280614,
#  'happy 2nd': 197952,
#  '2nd wedding': 78029,
#  'wedding anniversary': 366584,
#  'anniversary love': 101549,
#  'love @': 234337,
#  'user &': 348562,
#  '& lt': 49027,
#  'lt ;': 236388,
#  '; 3': 83450,
#  '3 #': 78137,
#  '# truelove': 44478,
#  'truelove #': 340831,
#  '# pougueseitalian': 35890,
#  'pougueseitalian &': 280615,
#  'happy 2nd wedding': 197953,
#  '2nd wedding anniversary': 78030,
#  'wedding anniversary love': 366589,
#  'anniversary love @': 101551,
#  'love @ user': 234345,
#  '@ user &': 87679,
#  'user & lt': 348565,
#  '& lt ;': 49028,
#  'lt ; 3': 236395,
#  '; 3 #': 83452,
#  '3 # truelove': 78167,
#  '# truelove #': 44479,
#  'truelove # pougueseitalian': 340834,
#  '# pougueseitalian &': 35891,
#  'pougueseitalian & lt': 280616,
#  'happyð\x9f\x92\x99': 199045,
#  'travel': 339505,
#  'instamood': 212134,
#  'moment': 247276,
#  'mylife': 252389,
#  'russian': 297716,
#  '4likeâ\x80¦': 79579,
#  'happyð\x9f\x92\x99 #': 199046,
#  '# travel': 44253,
#  'travel #': 339509,
#  '# time': 43732,
#  '# instamood': 25332,
#  'instamood #': 212135,
#  '# moment': 30866,
#  'moment #': 247281,
#  '# love': 28714,
#  '# mylife': 31714,
#  'mylife #': 252390,
#  '# russian': 38390,
#  'russian #': 297717,
#  '# girl': 21408,
#  'girl #': 185518,
#  'model #': 246896,
#  '# 4likeâ\x80¦': 6912,
#  'happyð\x9f\x92\x99 # travel': 199047,
#  '# travel #': 44254,
#  'travel # time': 339572,
#  '# time #': 43734,
#  'time # instamood': 334394,
#  '# instamood #': 25333,
#  'instamood # moment': 212154,
#  '# moment #': 30867,
#  'moment # love': 247301,
#  '# love #': 28716,
#  'love # mylife': 234084,
#  '# mylife #': 31715,
#  'mylife # russian': 252396,
#  '# russian #': 38391,
#  'russian # girl': 297718,
#  '# girl #': 21410,
#  'girl # model': 185597,
#  '# model #': 30798,
#  'model # 4likeâ\x80¦': 246898,
#  'notmypresident': 262789,
#  'misogynistic': 245977,
#  'traitor': 339308,
#  'theresistance': 331497,
#  'putinsbitch': 285645,
#  'user #': 347375,
#  '# notmypresident': 33136,
#  'notmypresident ever': 262799,
#  'ever #': 162791,
#  '# misogynistic': 30611,
#  'misogynistic #': 245978,
#  '# traitor': 44217,
#  'traitor #': 339309,
#  '# theresistance': 43424,
#  'theresistance #': 331498,
#  '# putinsbitch': 36674,
#  '@ user #': 87677,
#  'user # notmypresident': 348135,
#  '# notmypresident ever': 33140,
#  'notmypresident ever #': 262800,
#  'ever # misogynistic': 162803,
#  '# misogynistic #': 30612,
#  'misogynistic # traitor': 245979,
#  '# traitor #': 44218,
#  'traitor # theresistance': 339313,
#  '# theresistance #': 43425,
#  'theresistance # putinsbitch': 331500,
#  'miraclesfromheaven': 245847,
#  'make': 238172,
#  'cry': 141769,
#  'sosad': 315015,
#  'ending': 159602,
#  '# miraclesfromheaven': 30581,
#  'miraclesfromheaven make': 245848,
#  'make #': 238187,
#  '# cry': 14983,
#  'cry #': 141772,
#  '# sosad': 40746,
#  'sosad ending': 315019,
#  '# miraclesfromheaven make': 30582,
#  'miraclesfromheaven make #': 245849,
#  'make # cry': 238197,
#  '# cry #': 14985,
#  'cry # sosad': 141789,
#  '# sosad ending': 40748,
#  'meet': 242943,
#  'sebastian': 302361,
#  ...}

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(10,), verbose=True)

# %%
mlp_clf.fit(X_train_v, y_train)
# Out:
# Iteration 1, loss = 0.52021059
# Iteration 2, loss = 0.24496322
# Iteration 3, loss = 0.15434266
# Iteration 4, loss = 0.10696322
# Iteration 5, loss = 0.07111473
# Iteration 6, loss = 0.04700912
# Iteration 7, loss = 0.03245416
# Iteration 8, loss = 0.02365456
# Iteration 9, loss = 0.01813999
# Iteration 10, loss = 0.01450783
# Iteration 11, loss = 0.01203759
# Iteration 12, loss = 0.01026813
# Iteration 13, loss = 0.00897823
# Iteration 14, loss = 0.00800424
# Iteration 15, loss = 0.00725013
# Iteration 16, loss = 0.00665283
# Iteration 17, loss = 0.00616745
# Iteration 18, loss = 0.00576659
# Iteration 19, loss = 0.00542748
# Iteration 20, loss = 0.00513688
# Iteration 21, loss = 0.00488417
# Iteration 22, loss = 0.00465950
# Iteration 23, loss = 0.00445890
# Iteration 24, loss = 0.00427568
# Iteration 25, loss = 0.00410852
# Iteration 26, loss = 0.00395351
# Iteration 27, loss = 0.00380937
# Iteration 28, loss = 0.00367403
# Iteration 29, loss = 0.00354682
# Iteration 30, loss = 0.00342633
# Iteration 31, loss = 0.00331167
# Iteration 32, loss = 0.00320208
# Iteration 33, loss = 0.00309773
# Iteration 34, loss = 0.00299793
# Iteration 35, loss = 0.00290236
# Iteration 36, loss = 0.00281075
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=True, warm_start=False)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, classification_report

# %%
y_pred = mlp_clf.predict(X_test_v)

# %%
#confusion_matrix(y_test, y_pred)

# %%
print("roc_auc score: {}".format(roc_auc_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# roc_auc score: 0.7628268427850535
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5945
#           1       0.92      0.53      0.67       448
#
# avg / total       0.96      0.96      0.96      6393

# %%
X_all = vectorizer.transform(X)
y_all = y

# %%
mlp_clf.fit(X_all, y_all)
# Out:
# Iteration 1, loss = 0.45076652
# Iteration 2, loss = 0.24601258
# Iteration 3, loss = 0.14190490
# Iteration 4, loss = 0.08174407
# Iteration 5, loss = 0.04972015
# Iteration 6, loss = 0.03319932
# Iteration 7, loss = 0.02385617
# Iteration 8, loss = 0.01817407
# Iteration 9, loss = 0.01446235
# Iteration 10, loss = 0.01191282
# Iteration 11, loss = 0.01009742
# Iteration 12, loss = 0.00875664
# Iteration 13, loss = 0.00774495
# Iteration 14, loss = 0.00696281
# Iteration 15, loss = 0.00633324
# Iteration 16, loss = 0.00582839
# Iteration 17, loss = 0.00540767
# Iteration 18, loss = 0.00504763
# Iteration 19, loss = 0.00473986
# Iteration 20, loss = 0.00446822
# Iteration 21, loss = 0.00422901
# Iteration 22, loss = 0.00401109
# Iteration 23, loss = 0.00381435
# Iteration 24, loss = 0.00363354
# Iteration 25, loss = 0.00346945
# Iteration 26, loss = 0.00331397
# Iteration 27, loss = 0.00316922
# Iteration 28, loss = 0.00303260
# Iteration 29, loss = 0.00290545
# Iteration 30, loss = 0.00278692
# Iteration 31, loss = 0.00267435
# Iteration 32, loss = 0.00256730
# Iteration 33, loss = 0.00246583
# Iteration 34, loss = 0.00236869
# Iteration 35, loss = 0.00227923
# Iteration 36, loss = 0.00219202
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=True, warm_start=False)

# %%
df_test = pd.read_csv("dataset/test.csv")

# %%
df_test.sample(5)
# Out:
#           id                                              tweet
# 12936  44899  could we see a #deadrising4 at #e32016? only t...
# 14019  45982  @user seriously considered but too poor after ...
# 9000   40963   @user if only i had a boyfriend to bring me i...
# 5097   37060  boattrip with all the girls! @user #moderosa #...
# 233    32196  ð   #socialmedia may 2016 was hottest may o...

# %%
df_test['tweet'] = df_test['tweet'].apply(lambda x : tweets_lemm(x))

# %%
df_test.sample(5)
# Out:
#           id                                              tweet
# 12338  44301  not long now & amp ; @ user & amp ; i are off ...
# 3180   35143  @ user fundafield @ user cup team check in sta...
# 3052   35015  absolutely buzzing for friday ðð©ðð°...
# 3541   35504  @ user @ user thank you sooo much , i ca n't w...
# 1849   33812  @ user emma stone on hollywood : `` they 've g...

# %%
dtest = vectorizer.transform(df_test['tweet'])
test_pred = mlp_clf.predict(dtest)

# %%
df_test['label'] = test_pred

# %%
submission = df_test[['id','label']]

# %%
submission.to_csv('sub_rodixxi_mlpc_lemmatizer_2-1.csv', index=False)
