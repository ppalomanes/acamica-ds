# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv", index_col=0)
df_bk = df
df.sample(5)
# Out:
#        label                                              tweet
# id
# 8179       0  "flcrashcorrectors: "kscrashcorrectors: "kscra...
# 15427      0  this is where it happened ð #pray #disney  ...
# 888        0  #decors   buffalo simulation: buffalo for you ...
# 16002      1  #sikh #temple vandalised in in #calgary, #wso ...
# 7315       0   @user just waiting for john mccain to announc...

# %% [markdown]
# Twits should have less than 140ch

# %%
df[df['tweet'].str.len() > 140].head()
# Out:
#      label                                              tweet
# id
# 8        0  the next school year is the year for exams.ð...
# 336      0  watching the @user leadership embrace &amp; ki...
# 434      0   @user * sweets ð°ð©ð¬ð­ð«â¨!!!!!! ...
# 475      0  this is a shockingly   and increasingly #viole...
# 566      0  thank youðsoo muchð pretty @user i feel ...

# %%
df[df['tweet'].str.len() > 140].shape
# Out:
# (222, 2)

# %% [markdown]
# There must be some f*k simbols encoded in here

# %%
df.tweet[336]
# Out:
# "watching the @user leadership embrace &amp; kiss donald's ass is #pathetic &amp;  . this is now the @user pay. a pay of racism &amp; hate. #ripgop"

# %%
from bs4 import BeautifulSoup
BeautifulSoup(df.tweet[336], 'lxml').get_text()
# Out:
# "watching the @user leadership embrace & kiss donald's ass is #pathetic &  . this is now the @user pay. a pay of racism & hate. #ripgop"

# %%
df['tweet'] = df['tweet'].apply(lambda x : BeautifulSoup(x, 'lxml').get_text())

# %%
df[df['tweet'].str.len() > 140].shape
# Out:
# (149, 2)

# %%
df.tweet[434]
# Out:
# '@user * sweets ð\x9f\x8d°ð\x9f\x8d©ð\x9f\x8d¬ð\x9f\x8d\xadð\x9f\x8d«â\x9c¨!!!!!! * #instagood #ì\x95\x84ì\x9d´ë\x8f\x8c #å\x81¶å\x83\x8f #idola #idol #à¹\x84à¸\xadà¸\x94à¸\xadà¸¥ #followme #selfie   #ã\x81©ã\x82\x8bã\x81\x88ã\x82\x8câ\x80¦ '

# %%
import re
df['tweet'] = df['tweet'].apply(lambda x : re.sub(r'@[A-Za-z0-9]+','',x))

# %%
df.tweet[434]
# Out:
# ' * sweets ð\x9f\x8d°ð\x9f\x8d©ð\x9f\x8d¬ð\x9f\x8d\xadð\x9f\x8d«â\x9c¨!!!!!! * #instagood #ì\x95\x84ì\x9d´ë\x8f\x8c #å\x81¶å\x83\x8f #idola #idol #à¹\x84à¸\xadà¸\x94à¸\xadà¸¥ #followme #selfie   #ã\x81©ã\x82\x8bã\x81\x88ã\x82\x8câ\x80¦ '

# %%
df.shape
# Out:
# (31962, 2)

# %%
df.tweet.str.contains('https|http', na=False).count()
# Out:
# 31962

# %% [markdown]
# Cleaning special simbols and numbers like # and @ -> better f-1 without this

# %%
df.tweet[1]
# Out:
# ' when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run'

# %%
#df['tweet'] = df['tweet'].apply(lambda x : re.sub("[^a-zA-Z]", " ", x))

# %%
df.tweet[1]
# Out:
# ' when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run'

# %% [markdown]
# Lemmatization

# %%
import nltk

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def tweets_lemm(tweet):
    lemmatizer = WordNetLemmatizer()
    word_list = nltk.word_tokenize(tweet)
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
    return lemmatized_output

# %%
print(tweets_lemm(df.tweet[1]))
# Out:
# when a father is dysfunctional and is so selfish he drag his kid into his dysfunction . # run

# %%
df['tweet'] = df['tweet'].apply(lambda x : tweets_lemm(x))

# %%
from sklearn.model_selection import train_test_split

# %%
X = df["tweet"]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /home/rcrespillo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rcrespillo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vectorizer = TfidfVectorizer(analyzer='word', 
                             tokenizer=nltk.word_tokenize, 
                             stop_words=stops, 
                             ngram_range=(1,3))

X_train_v = vectorizer.fit_transform(X_train)
X_test_v = vectorizer.transform(X_test)

# %%
X_train_v.shape
# Out:
# (25569, 377046)

# %%
vectorizer.vocabulary_
# Out:
# {'going': 184480,
#  'seeing': 299149,
#  'everyday': 159618,
#  'look': 228180,
#  'phone': 270972,
#  'ð\x9f\x98\x94': 375011,
#  '#': 6111,
#  'verysad': 344591,
#  'going seeing': 184936,
#  'seeing everyday': 299195,
#  'everyday look': 159661,
#  'look phone': 228491,
#  'phone ð\x9f\x98\x94': 271051,
#  'ð\x9f\x98\x94 #': 375012,
#  '# verysad': 45393,
#  'going seeing everyday': 184937,
#  'seeing everyday look': 299196,
#  'everyday look phone': 159662,
#  'look phone ð\x9f\x98\x94': 228492,
#  'phone ð\x9f\x98\x94 #': 271052,
#  'ð\x9f\x98\x94 # verysad': 375028,
#  "n't": 248553,
#  'need': 252150,
#  'blame': 113979,
#  'atrocity': 101748,
#  'isi': 209917,
#  'islamicterorrist': 210057,
#  '-': 64583,
#  'nut': 259265,
#  'everywhere': 160212,
#  'commit': 132482,
#  'terrorism': 325207,
#  '.': 66124,
#  'lgbtresilience': 222273,
#  "n't need": 249655,
#  'need blame': 252242,
#  'blame atrocity': 113990,
#  'atrocity #': 101749,
#  '# isi': 25622,
#  'isi #': 209918,
#  '# islamicterorrist': 25651,
#  'islamicterorrist -': 210058,
#  '- nut': 65404,
#  'nut everywhere': 259276,
#  'everywhere commit': 160228,
#  'commit #': 132483,
#  '# terrorism': 42764,
#  'terrorism .': 325216,
#  '. #': 66129,
#  '# lgbtresilience': 27798,
#  "n't need blame": 249658,
#  'need blame atrocity': 252243,
#  'blame atrocity #': 113991,
#  'atrocity # isi': 101750,
#  '# isi #': 25623,
#  'isi # islamicterorrist': 209923,
#  '# islamicterorrist -': 25652,
#  'islamicterorrist - nut': 210059,
#  '- nut everywhere': 65405,
#  'nut everywhere commit': 259277,
#  'everywhere commit #': 160229,
#  'commit # terrorism': 132484,
#  '# terrorism .': 42767,
#  'terrorism . #': 325217,
#  '. # lgbtresilience': 66920,
#  'ugh': 340789,
#  'true': 336616,
#  'ifschweinsteigerproposediwouldntsayno': 205037,
#  'ugh true': 340811,
#  'true #': 336628,
#  '# ifschweinsteigerproposediwouldntsayno': 24481,
#  'ugh true #': 340812,
#  'true # ifschweinsteigerproposediwouldntsayno': 336633,
#  'coffee': 130617,
#  'anyone': 99003,
#  '?': 85367,
#  'humpday': 203831,
#  'lady': 218010,
#  'wednesdayisgeorgeday': 352491,
#  'georgeclooney': 179684,
#  'handsome': 193051,
#  'love': 229765,
#  'â\x9d¤ï¸\x8f': 368386,
#  '# coffee': 14004,
#  'coffee anyone': 130672,
#  'anyone ?': 99010,
#  '? #': 85407,
#  '# humpday': 24185,
#  'humpday #': 203836,
#  '# lady': 27185,
#  'lady #': 218016,
#  '# wednesdayisgeorgeday': 46189,
#  'wednesdayisgeorgeday #': 352492,
#  '# georgeclooney': 21085,
#  'georgeclooney #': 179685,
#  '# handsome': 22741,
#  'handsome #': 193054,
#  '# love': 28617,
#  'love â\x9d¤ï¸\x8f': 231271,
#  '# coffee anyone': 14008,
#  'coffee anyone ?': 130673,
#  'anyone ? #': 99011,
#  '? # humpday': 85550,
#  '# humpday #': 24187,
#  'humpday # lady': 203842,
#  '# lady #': 27186,
#  'lady # wednesdayisgeorgeday': 218025,
#  '# wednesdayisgeorgeday #': 46190,
#  'wednesdayisgeorgeday # georgeclooney': 352493,
#  '# georgeclooney #': 21086,
#  'georgeclooney # handsome': 179686,
#  '# handsome #': 22742,
#  'handsome # love': 193061,
#  '# love â\x9d¤ï¸\x8f': 28677,
#  'hanging': 193128,
#  'upside': 342563,
#  'ð\x9f¤\x94ð\x9f\x99\x83': 376642,
#  'upsidedown': 342578,
#  'smile': 307658,
#  'couple': 136187,
#  'boyfriend': 117461,
#  'girlfriend': 182176,
#  'playingâ\x80¦': 273657,
#  'hanging upside': 193153,
#  'upside ð\x9f¤\x94ð\x9f\x99\x83': 342573,
#  'ð\x9f¤\x94ð\x9f\x99\x83 #': 376643,
#  '# upsidedown': 45042,
#  'upsidedown #': 342579,
#  '# smile': 40084,
#  'smile #': 307665,
#  '# couple': 14727,
#  'couple #': 136190,
#  '# boyfriend': 11623,
#  'boyfriend #': 117464,
#  '# girlfriend': 21327,
#  'girlfriend #': 182177,
#  '# playingâ\x80¦': 35277,
#  'hanging upside ð\x9f¤\x94ð\x9f\x99\x83': 193154,
#  'upside ð\x9f¤\x94ð\x9f\x99\x83 #': 342574,
#  'ð\x9f¤\x94ð\x9f\x99\x83 # upsidedown': 376644,
#  '# upsidedown #': 45043,
#  'upsidedown # smile': 342580,
#  '# smile #': 40085,
#  'smile # couple': 307714,
#  '# couple #': 14728,
#  'couple # boyfriend': 136196,
#  '# boyfriend #': 11624,
#  'boyfriend # girlfriend': 117475,
#  '# girlfriend #': 21328,
#  'girlfriend # playingâ\x80¦': 182183,
#  'correct': 135294,
#  'correcting': 135314,
#  'ð\x9f\x98\x82': 373413,
#  'grow': 190007,
#  ',': 58625,
#  'get': 179792,
#  'life': 222617,
#  'stop': 315668,
#  'trolling': 336461,
#  'woman': 357772,
#  'correct .': 135295,
#  ". n't": 70744,
#  'need correcting': 252281,
#  'correcting ð\x9f\x98\x82': 135315,
#  'ð\x9f\x98\x82 need': 373461,
#  'need grow': 252350,
#  'grow ,': 190015,
#  ', get': 61082,
#  'get life': 180352,
#  'life ,': 222846,
#  ', stop': 63700,
#  'stop trolling': 315885,
#  'trolling woman': 336470,
#  'woman .': 357833,
#  "correct . n't": 135297,
#  ". n't need": 70767,
#  "n't need correcting": 249660,
#  'need correcting ð\x9f\x98\x82': 252282,
#  'correcting ð\x9f\x98\x82 need': 135316,
#  'ð\x9f\x98\x82 need grow': 373462,
#  'need grow ,': 252351,
#  'grow , get': 190016,
#  ', get life': 61095,
#  'get life ,': 180354,
#  'life , stop': 222860,
#  ', stop trolling': 63706,
#  'stop trolling woman': 315886,
#  'trolling woman .': 336471,
#  'highlight': 199426,
#  'ha': 191447,
#  'listening': 225837,
#  '21': 79164,
#  'pilot': 272139,
#  'preparation': 277717,
#  'conce': 133214,
#  'sunday': 319077,
#  ':': 83136,
#  ')': 57652,
#  '21pilots': 79222,
#  'highlight life': 199441,
#  'life ha': 223143,
#  'ha listening': 191848,
#  'listening 21': 225849,
#  '21 pilot': 79190,
#  'pilot preparation': 272148,
#  'preparation conce': 277718,
#  'conce sunday': 133269,
#  'sunday :': 319214,
#  ': )': 83413,
#  ') #': 57660,
#  '# 21pilots': 6821,
#  'highlight life ha': 199442,
#  'life ha listening': 223146,
#  'ha listening 21': 191849,
#  'listening 21 pilot': 225850,
#  '21 pilot preparation': 79191,
#  'pilot preparation conce': 272149,
#  'preparation conce sunday': 277719,
#  'conce sunday :': 133270,
#  'sunday : )': 319215,
#  ': ) #': 83415,
#  ') # 21pilots': 57662,
#  'morrisey': 245220,
#  'morning': 244686,
#  'good': 185512,
#  'worldð\x9f\x98\x8e': 360239,
#  'friday': 174632,
#  'ð\x9f\x91\x8d': 371397,
#  'listening morrisey': 225864,
#  'morrisey morning': 245221,
#  'morning good': 244928,
#  'good worldð\x9f\x98\x8e': 186171,
#  'worldð\x9f\x98\x8e friday': 360240,
#  'friday ð\x9f\x91\x8d': 174992,
#  'listening morrisey morning': 225865,
#  'morrisey morning good': 245222,
#  'morning good worldð\x9f\x98\x8e': 244929,
#  'good worldð\x9f\x98\x8e friday': 186172,
#  'worldð\x9f\x98\x8e friday ð\x9f\x91\x8d': 360241,
#  'people': 268849,
#  'protesting': 279999,
#  'trump': 336890,
#  'republican': 288928,
#  'won-they': 358162,
#  'fuhered': 176546,
#  '&': 48792,
#  'â\x80¦': 367090,
#  '# people': 34662,
#  "people n't": 269395,
#  "n't protesting": 249759,
#  'protesting #': 280000,
#  '# trump': 44260,
#  'trump #': 336895,
#  '# republican': 37419,
#  'republican won-they': 288964,
#  'won-they trump': 358163,
#  'trump ha': 337039,
#  'ha fuhered': 191725,
#  'fuhered &': 176547,
#  '& â\x80¦': 50629,
#  "# people n't": 34668,
#  "people n't protesting": 269405,
#  "n't protesting #": 249760,
#  'protesting # trump': 280001,
#  '# trump #': 44262,
#  'trump # republican': 336924,
#  '# republican won-they': 37427,
#  'republican won-they trump': 288965,
#  'won-they trump ha': 358164,
#  'trump ha fuhered': 337041,
#  'ha fuhered &': 191726,
#  'fuhered & â\x80¦': 176548,
#  'beach': 107118,
#  'make': 234146,
#  'hea': 196537,
#  '# beach': 9924,
#  'beach make': 107210,
#  'make #': 234159,
#  '# hea': 23101,
#  'hea .': 196568,
#  '# beach make': 9929,
#  'beach make #': 107211,
#  'make # hea': 234180,
#  '# hea .': 23104,
#  'little': 226033,
#  'polski': 275239,
#  'sklep': 306581,
#  '!': 0,
#  'agingdisgracefully': 92841,
#  'travel': 335520,
#  'london': 227631,
#  'little polski': 226305,
#  'polski sklep': 275240,
#  'sklep good': 306582,
#  'good !': 185513,
#  '! #': 498,
#  '# agingdisgracefully': 7672,
#  'agingdisgracefully #': 92842,
#  '# travel': 44034,
#  'travel #': 335524,
#  '# london': 28410,
#  'little polski sklep': 226306,
#  'polski sklep good': 275241,
#  'sklep good !': 306583,
#  'good ! #': 185515,
#  '! # agingdisgracefully': 549,
#  '# agingdisgracefully #': 7673,
#  'agingdisgracefully # travel': 92843,
#  '# travel #': 44035,
#  'travel # london': 335557,
#  'see': 298275,
#  'bear': 107334,
#  'total': 334292,
#  'deprivation': 145981,
#  'terrible': 325113,
#  'psychological': 280472,
#  'condition': 133418,
#  'prison': 278785,
#  'feel': 166085,
#  'acceptable': 90446,
#  'see #': 298283,
#  '# bear': 9970,
#  'bear total': 107370,
#  'total #': 334293,
#  '# deprivation': 15998,
#  'deprivation terrible': 145982,
#  'terrible psychological': 325132,
#  'psychological condition': 280473,
#  'condition #': 133419,
#  '# prison': 36088,
#  'prison people': 278799,
#  'people feel': 269190,
#  'feel acceptable': 166157,
#  'acceptable !': 90447,
#  'see # bear': 298288,
#  '# bear total': 9973,
#  'bear total #': 107371,
#  'total # deprivation': 334294,
#  '# deprivation terrible': 15999,
#  'deprivation terrible psychological': 145983,
#  'terrible psychological condition': 325133,
#  'psychological condition #': 280474,
#  'condition # prison': 133422,
#  '# prison people': 36090,
#  'prison people feel': 278800,
#  'people feel acceptable': 269192,
#  'feel acceptable !': 166158,
#  'laugh': 219439,
#  "'re": 52894,
#  'happy': 193926,
#  '...': 73176,
#  'william': 356086,
#  'james': 211040,
#  'xtra': 361916,
#  "n't #": 248558,
#  '# laugh': 27405,
#  "laugh 're": 219463,
#  "'re happy": 53151,
#  'happy ...': 194099,
#  "... 're": 73504,
#  "'re laugh": 53204,
#  'laugh .': 219468,
#  '. -': 67974,
#  '- william': 65713,
#  'william james': 356087,
#  'james .': 211043,
#  '# xtra': 47474,
#  "n't # laugh": 248575,
#  "# laugh 're": 27407,
#  "laugh 're happy": 219464,
#  "'re happy ...": 53155,
#  "happy ... 're": 194101,
#  "... 're laugh": 73505,
#  "'re laugh .": 53205,
#  'laugh . -': 219470,
#  '. - william': 67992,
#  '- william james': 65714,
#  'william james .': 356088,
#  'james . #': 211044,
#  '. # xtra': 67689,
#  'first': 169373,
#  'â\x98\x95ï¸\x8f': 367570,
#  'long': 227844,
#  'weekend': 353109,
#  'ó¾¬\x98': 376999,
#  'first #': 169378,
#  'coffee â\x98\x95ï¸\x8f': 130709,
#  'â\x98\x95ï¸\x8f long': 367574,
#  'long weekend': 228010,
#  'weekend ó¾¬\x98': 353544,
#  'first # coffee': 169382,
#  '# coffee â\x98\x95ï¸\x8f': 14016,
#  'coffee â\x98\x95ï¸\x8f long': 130710,
#  'â\x98\x95ï¸\x8f long weekend': 367575,
#  'long weekend ó¾¬\x98': 228015,
#  'imwithher': 206372,
#  'hillary': 199569,
#  'clinton': 129625,
#  'took': 333939,
#  'money': 243800,
#  'islamic': 210021,
#  'country': 135994,
#  'remains': 288084,
#  'silent': 305027,
#  'treatment': 335923,
#  'muslim': 247634,
#  '# imwithher': 24843,
#  'imwithher ?': 206373,
#  '? hillary': 86286,
#  'hillary clinton': 199598,
#  'clinton took': 129659,
#  'took money': 333975,
#  'money islamic': 243886,
#  'islamic country': 210026,
#  'country remains': 136115,
#  'remains silent': 288103,
#  'silent treatment': 305042,
#  'treatment muslim': 335930,
#  'muslim woman': 247709,
#  'woman !': 357773,
#  '# imwithher ?': 24844,
#  'imwithher ? hillary': 206374,
#  '? hillary clinton': 86287,
#  'hillary clinton took': 199606,
#  'clinton took money': 129660,
#  'took money islamic': 333976,
#  'money islamic country': 243887,
#  'islamic country remains': 210027,
#  'country remains silent': 136116,
#  'remains silent treatment': 288104,
#  'silent treatment muslim': 305043,
#  'treatment muslim woman': 335931,
#  'muslim woman !': 247710,
#  'movieshit': 246007,
#  'bull': 120142,
#  'dominate': 149890,
#  'direct': 147753,
#  'whatever': 354736,
#  'want': 349429,
#  'yo': 363736,
#  '# movieshit': 31104,
#  'movieshit bull': 246008,
#  'bull :': 120143,
#  ': dominate': 83866,
#  'dominate bull': 149891,
#  'bull direct': 120147,
#  'direct whatever': 147758,
#  'whatever want': 354789,
#  'want .': 349467,
#  '. yo': 72514,
#  '# movieshit bull': 31105,
#  'movieshit bull :': 246009,
#  'bull : dominate': 120144,
#  ': dominate bull': 83867,
#  'dominate bull direct': 149892,
#  'bull direct whatever': 120148,
#  'direct whatever want': 147759,
#  'whatever want .': 354791,
#  'want . yo': 349480,
#  'yeah': 362423,
#  'wa': 346944,
#  'thought': 329027,
#  'yeah wa': 362494,
#  'wa thought': 347899,
#  'thought .': 329058,
#  'yeah wa thought': 362495,
#  'wa thought .': 347900,
#  'womenwhofarm': 358153,
#  'farmbitch': 164296,
#  'harvest': 195749,
#  '# womenwhofarm': 47044,
#  'womenwhofarm #': 358154,
#  '# farmbitch': 18727,
#  'farmbitch harvest': 164297,
#  '# womenwhofarm #': 47045,
#  'womenwhofarm # farmbitch': 358155,
#  '# farmbitch harvest': 18728,
#  'dish': 148349,
#  'hehe': 198064,
#  'silly': 305062,
#  'clean': 129194,
#  'housework': 203027,
#  'gay': 178834,
#  'gaylife': 178990,
#  'blessed': 114235,
#  'gayboy': 178966,
#  'winnipeg': 356625,
#  'waterfront': 351076,
#  '# dish': 16348,
#  'dish hehe': 148356,
#  'hehe #': 198067,
#  '# silly': 39653,
#  'silly #': 305063,
#  '# clean': 13765,
#  'clean #': 129195,
#  '# housework': 24030,
#  'housework #': 203028,
#  '# gay': 20896,
#  'gay #': 178836,
#  '# gaylife': 20923,
#  'gaylife #': 178991,
#  '# blessed': 11059,
#  'blessed #': 114240,
#  '# gayboy': 20909,
#  'gayboy #': 178967,
#  '# winnipeg': 46840,
#  'winnipeg #': 356626,
#  '# waterfront': 45976,
#  '# dish hehe': 16350,
#  'dish hehe #': 148357,
#  'hehe # silly': 198068,
#  '# silly #': 39654,
#  'silly # clean': 305067,
#  '# clean #': 13766,
#  'clean # housework': 129197,
#  '# housework #': 24031,
#  'housework # gay': 203029,
#  '# gay #': 20897,
#  'gay # gaylife': 178845,
#  '# gaylife #': 20924,
#  'gaylife # blessed': 178992,
#  '# blessed #': 11061,
#  'blessed # gayboy': 114261,
#  '# gayboy #': 20910,
#  'gayboy # winnipeg': 178971,
#  '# winnipeg #': 46841,
#  'winnipeg # waterfront': 356627,
#  'comment': 132317,
#  'reflection': 287085,
#  'ignorance': 205144,
#  'absolute': 90163,
#  'comment reflection': 132384,
#  'reflection total': 287101,
#  'total ignorance': 334306,
#  'ignorance absolute': 205160,
#  'comment reflection total': 132386,
#  'reflection total ignorance': 287102,
#  'total ignorance absolute': 334307,
#  'nothing': 258313,
#  'say': 295976,
#  'like': 223923,
#  'cute': 138967,
#  'mug': 246904,
#  'meet': 238877,
#  '3yr': 80756,
#  'old': 261123,
#  'camden': 122147,
#  'firecracker': 169278,
#  'forâ\x80¦': 173345,
#  'nothing say': 258485,
#  'say like': 296214,
#  'like cute': 224310,
#  'cute little': 139129,
#  'little mug': 226272,
#  'mug !': 246905,
#  '! meet': 3903,
#  'meet 3yr': 238898,
#  '3yr old': 80757,
#  'old camden': 261175,
#  'camden !': 122148,
#  '! ...': 2444,
#  '... firecracker': 74185,
#  'firecracker forâ\x80¦': 169279,
#  'nothing say like': 258490,
#  'say like cute': 296215,
#  'like cute little': 224311,
#  'cute little mug': 139132,
#  'little mug !': 226273,
#  'mug ! meet': 246907,
#  '! meet 3yr': 3904,
#  'meet 3yr old': 238899,
#  '3yr old camden': 80758,
#  'old camden !': 261176,
#  'camden ! ...': 122149,
#  '! ... firecracker': 2450,
#  '... firecracker forâ\x80¦': 74186,
#  'ok.': 261036,
#  'i_am': 204384,
#  'positive': 275855,
#  'affirmation': 92300,
#  'ok. #': 261037,
#  '# i_am': 24304,
#  'i_am #': 204385,
#  '# positive': 35659,
#  'positive #': 275858,
#  '# affirmation': 7566,
#  'ok. # i_am': 261038,
#  '# i_am #': 24305,
#  'i_am # positive': 204386,
#  '# positive #': 35661,
#  'positive # affirmation': 275859,
#  'whole': 355576,
#  'speech': 311858,
#  'attempt': 101876,
#  'appreciating': 99829,
#  "'s": 53552,
#  'v': 343578,
#  '(': 56873,
#  'enough': 156698,
#  'attacking': 101866,
#  'ð\x9f\x91\x8eð\x9f\x8f¼ð\x9f\x91\x8eð\x9f\x8f¼': 371479,
#  'whole speech': 355642,
#  'speech wa': 311898,
#  'wa attempt': 347111,
#  'attempt appreciating': 101880,
#  "appreciating 's": 99832,
#  "'s v": 56201,
#  'v isi': 343642,
#  'isi (': 209927,
#  '( enough': 57222,
#  'enough )': 156712,
#  ') attacking': 57998,
#  'attacking ð\x9f\x91\x8eð\x9f\x8f¼ð\x9f\x91\x8eð\x9f\x8f¼': 101875,
#  'whole speech wa': 355643,
#  'speech wa attempt': 311899,
#  'wa attempt appreciating': 347112,
#  "attempt appreciating 's": 101881,
#  "appreciating 's v": 99833,
#  "'s v isi": 56202,
#  'v isi (': 343643,
#  'isi ( enough': 209928,
#  '( enough )': 57223,
#  'enough ) attacking': 156713,
#  ') attacking ð\x9f\x91\x8eð\x9f\x8f¼ð\x9f\x91\x8eð\x9f\x8f¼': 57999,
#  'relied': 287956,
#  'bankruptcy': 105941,
#  'protection': 279941,
#  'keep': 214217,
#  'ego': 154336,
#  'billionaire': 112826,
#  'used': 343167,
#  'xenopbobiaâ\x80¦': 361802,
#  'relied #': 287957,
#  '# bankruptcy': 9703,
#  'bankruptcy protection': 105947,
#  'protection keep': 279953,
#  'keep ego': 214306,
#  'ego #': 154339,
#  '# billionaire': 10843,
#  'billionaire .': 112827,
#  '. used': 72186,
#  'used ,': 343173,
#  ', #': 58634,
#  '# xenopbobiaâ\x80¦': 47445,
#  'relied # bankruptcy': 287958,
#  '# bankruptcy protection': 9705,
#  'bankruptcy protection keep': 105948,
#  'protection keep ego': 279954,
#  'keep ego #': 214307,
#  'ego # billionaire': 154340,
#  '# billionaire .': 10844,
#  'billionaire . used': 112828,
#  '. used ,': 72187,
#  'used , #': 343174,
#  ', # xenopbobiaâ\x80¦': 58967,
#  'day': 141465,
#  '26': 79499,
#  'year': 362520,
#  'ð\x9f\x98\x80': 373078,
#  'june4': 213438,
#  'thankful': 326045,
#  'itsmybihdayallweek': 210509,
#  '26candles': 79510,
#  'ð\x9f\x8e\x82': 370422,
#  'first day': 169479,
#  'day 26': 142022,
#  '26 year': 79502,
#  'year old': 362843,
#  'old .': 261147,
#  '. ð\x9f\x98\x80': 72802,
#  'ð\x9f\x98\x80 #': 373079,
#  '# june4': 26428,
#  'june4 #': 213439,
#  '# thankful': 42860,
#  'thankful #': 326046,
#  '# itsmybihdayallweek': 25783,
#  'itsmybihdayallweek #': 210510,
#  '# 26candles': 6862,
#  '26candles ð\x9f\x8e\x82': 79511,
#  'first day 26': 169483,
#  'day 26 year': 142023,
#  '26 year old': 79503,
#  'year old .': 362847,
#  'old . ð\x9f\x98\x80': 261154,
#  '. ð\x9f\x98\x80 #': 72803,
#  'ð\x9f\x98\x80 # june4': 373092,
#  '# june4 #': 26429,
#  'june4 # thankful': 213440,
#  '# thankful #': 42861,
#  'thankful # itsmybihdayallweek': 326054,
#  '# itsmybihdayallweek #': 25784,
#  'itsmybihdayallweek # 26candles': 210511,
#  '# 26candles ð\x9f\x8e\x82': 6863,
#  'finally': 168219,
#  'found': 173426,
#  'way': 351179,
#  'delete': 145196,
#  'tweet': 338610,
#  'might': 240735,
#  'find': 168545,
#  'useful': 343266,
#  'well': 353907,
#  'deletetweets': 145220,
#  'finally found': 168329,
#  'found way': 173561,
#  'way delete': 351319,
#  'delete old': 145203,
#  'old tweet': 261313,
#  'tweet !': 338611,
#  '! might': 3931,
#  'might find': 240768,
#  'find useful': 168791,
#  'useful well': 343273,
#  'well :': 353971,
#  ': #': 83141,
#  '# deletetweets': 15846,
#  'finally found way': 168331,
#  'found way delete': 173562,
#  'way delete old': 351320,
#  'delete old tweet': 145204,
#  'old tweet !': 261314,
#  'tweet ! might': 338615,
#  '! might find': 3932,
#  'might find useful': 240769,
#  'find useful well': 168792,
#  'useful well :': 343274,
#  'well : #': 353972,
#  ': # deletetweets': 83178,
#  'bff': 110991,
#  'jehna': 211493,
#  'broke': 119072,
#  '``': 87969,
#  'kiss/date': 216237,
#  'ð\x9f\x98\xad': 375746,
#  'bff jehna': 111015,
#  'jehna broke': 211494,
#  'broke ``': 119089,
#  '`` boyfriend': 88439,
#  'boyfriend ``': 117493,
#  '`` kiss/date': 88917,
#  'kiss/date ð\x9f\x98\xad': 216238,
#  'bff jehna broke': 111016,
#  'jehna broke ``': 211495,
#  'broke `` boyfriend': 119090,
#  '`` boyfriend ``': 88440,
#  'boyfriend `` kiss/date': 117494,
#  '`` kiss/date ð\x9f\x98\xad': 88918,
#  'challenge': 125539,
#  'aap': 89814,
#  'claim': 128861,
#  '70': 82403,
#  '%': 48622,
#  'punjabi': 280965,
#  'drugaddicts': 152050,
#  'dare': 140859,
#  'prove': 280236,
#  'challenge #': 125541,
#  '# aap': 7228,
#  "aap 's": 89818,
#  "'s claim": 54187,
#  'claim 70': 128865,
#  '70 %': 82406,
#  '% #': 48623,
#  '# punjabi': 36422,
#  'punjabi #': 280966,
#  '# drugaddicts': 16996,
#  'drugaddicts ,': 152051,
#  ', dare': 60363,
#  'dare prove': 140878,
#  'challenge # aap': 125543,
#  "# aap 's": 7231,
#  "aap 's claim": 89819,
#  "'s claim 70": 54188,
#  'claim 70 %': 128866,
#  '70 % #': 82407,
#  '% # punjabi': 48632,
#  '# punjabi #': 36423,
#  'punjabi # drugaddicts': 280967,
#  '# drugaddicts ,': 16997,
#  'drugaddicts , dare': 152052,
#  ', dare prove': 60364,
#  'tyler': 339429,
#  'perry': 270242,
#  'â\x80\x98reverse': 366788,
#  'racismâ\x80\x99': 282901,
#  'critic': 137724,
#  'tlc': 331719,
#  'series': 300738,
#  'reverse': 290068,
#  'criticsâ\x80¦â\x80¦': 137764,
#  'tyler perry': 339435,
#  'perry claim': 270245,
#  'claim â\x80\x98reverse': 128896,
#  'â\x80\x98reverse racismâ\x80\x99': 366789,
#  'racismâ\x80\x99 critic': 282902,
#  'critic tlc': 137729,
#  'tlc series': 331726,
#  'series #': 300741,
#  '# tyler': 44609,
#  'tyler #': 339430,
#  '# perry': 34755,
#  'perry #': 270243,
#  '# claim': 13705,
#  'claim #': 128862,
#  '# reverse': 37563,
#  'reverse #': 290069,
#  '# criticsâ\x80¦â\x80¦': 14953,
#  'tyler perry claim': 339436,
#  'perry claim â\x80\x98reverse': 270246,
#  'claim â\x80\x98reverse racismâ\x80\x99': 128897,
#  'â\x80\x98reverse racismâ\x80\x99 critic': 366790,
#  'racismâ\x80\x99 critic tlc': 282903,
#  'critic tlc series': 137730,
#  'tlc series #': 331727,
#  'series # tyler': 300744,
#  '# tyler #': 44610,
#  'tyler # perry': 339431,
#  '# perry #': 34756,
#  'perry # claim': 270244,
#  '# claim #': 13706,
#  'claim # reverse': 128864,
#  '# reverse #': 37564,
#  'reverse # criticsâ\x80¦â\x80¦': 290070,
#  'loving': 232215,
#  'conference': 133511,
#  'call': 121722,
#  'one': 261685,
#  'teammates.big': 324170,
#  'thing': 327693,
#  'happening': 193373,
#  'within': 357176,
#  'team': 323888,
#  'loving conference': 232247,
#  'conference call': 133541,
#  'call one': 121838,
#  'one teammates.big': 262408,
#  'teammates.big thing': 324171,
#  'thing happening': 327909,
#  'happening within': 193436,
#  'within team': 357210,
#  'team !': 323889,
#  'loving conference call': 232248,
#  'conference call one': 133542,
#  'call one teammates.big': 121839,
#  'one teammates.big thing': 262409,
#  'teammates.big thing happening': 324172,
#  'thing happening within': 327914,
#  'happening within team': 193437,
#  'within team !': 357211,
#  'happy make': 194658,
#  'make happy': 234477,
#  'happy .': 194066,
#  'happy make happy': 194659,
#  'make happy .': 234481,
#  'happy . #': 194067,
#  'simple': 305190,
#  'becoming': 108284,
#  'capable': 123115,
#  'burnsurvivor': 120447,
#  'dolbf': 149809,
#  'motivation': 245447,
#  'motivate': 245409,
#  'simple ,': 305196,
#  ', true': 64028,
#  'true .': 336656,
#  '. becoming': 68584,
#  'becoming capable': 108287,
#  'capable !': 123116,
#  '# burnsurvivor': 12233,
#  'burnsurvivor #': 120448,
#  '# dolbf': 16638,
#  'dolbf #': 149810,
#  '# motivation': 31019,
#  'motivation #': 245448,
#  '# motivate': 31007,
#  'simple , true': 305200,
#  ', true .': 64030,
#  'true . becoming': 336659,
#  '. becoming capable': 68585,
#  'becoming capable !': 108288,
#  'capable ! #': 123117,
#  '! # burnsurvivor': 735,
#  '# burnsurvivor #': 12234,
#  'burnsurvivor # dolbf': 120449,
#  '# dolbf #': 16639,
#  'dolbf # motivation': 149811,
#  '# motivation #': 31020,
#  'motivation # motivate': 245472,
#  '20': 78610,
#  'time': 330365,
#  'potus': 276525,
#  'address': 91615,
#  'nation': 251313,
#  'mass': 237130,
#  'shooting': 303284,
#  'happened': 193284,
#  'usâ\x80¦': 343491,
#  'yet': 363492,
#  'changeâ\x80¦': 126010,
#  'frustrating': 176074,
#  'stophate': 315941,
#  'usa': 342888,
#  '20 time': 78652,
#  'time #': 330376,
#  '# potus': 35738,
#  'potus ha': 276545,
#  'ha address': 191497,
#  'address nation': 91628,
#  'nation mass': 251342,
#  'mass shooting': 237146,
#  'shooting happened': 303380,
#  'happened usâ\x80¦': 193358,
#  'usâ\x80¦ yet': 343492,
#  'yet nothing': 363607,
#  'nothing changeâ\x80¦': 258368,
#  'changeâ\x80¦ #': 126011,
#  '# frustrating': 20449,
#  'frustrating #': 176075,
#  '# stophate': 41202,
#  'stophate #': 315942,
#  '# usa': 45074,
#  '20 time #': 78653,
#  'time # potus': 330432,
#  '# potus ha': 35740,
#  'potus ha address': 276546,
#  'ha address nation': 191498,
#  'address nation mass': 91629,
#  'nation mass shooting': 251343,
#  'mass shooting happened': 237155,
#  'shooting happened usâ\x80¦': 303381,
#  'happened usâ\x80¦ yet': 193359,
#  'usâ\x80¦ yet nothing': 343493,
#  'yet nothing changeâ\x80¦': 363608,
#  'nothing changeâ\x80¦ #': 258369,
#  'changeâ\x80¦ # frustrating': 126012,
#  '# frustrating #': 20450,
#  'frustrating # stophate': 176076,
#  '# stophate #': 41203,
#  'stophate # usa': 315943,
#  'kiss': 216201,
#  'dive': 148747,
#  'scuba': 297565,
#  'diving': 148818,
#  'kotakinabalu': 217413,
#  'sabah': 293727,
#  'vacation': 343717,
#  'holiday': 200418,
#  'kiss dive': 216221,
#  'dive #': 148749,
#  '# scuba': 38761,
#  'scuba #': 297566,
#  '# diving': 16433,
#  'diving #': 148819,
#  '# kotakinabalu': 27056,
#  'kotakinabalu #': 217414,
#  '# sabah': 38227,
#  'sabah #': 293728,
#  '# vacation': 45188,
#  'vacation #': 343721,
#  '# holiday': 23682,
#  'holiday #': 200424,
#  'kiss dive #': 216222,
#  'dive # scuba': 148752,
#  '# scuba #': 38762,
#  'scuba # diving': 297568,
#  '# diving #': 16434,
#  'diving # kotakinabalu': 148820,
#  '# kotakinabalu #': 27057,
#  'kotakinabalu # sabah': 217415,
#  '# sabah #': 38228,
#  'sabah # travel': 293729,
#  'travel # vacation': 335588,
#  '# vacation #': 45189,
#  'vacation # holiday': 343733,
#  '# holiday #': 23684,
#  'holiday # love': 200469,
#  'save': 295743,
#  '$': 48418,
#  'logins': 227370,
#  'x': 361630,
#  'broker': 119200,
#  'change': 125751,
#  'meme': 239349,
#  'education': 154104,
#  'university': 341899,
#  'save $': 295757,
#  '$ $': 48423,
#  '$ logins': 48599,
#  'logins x': 227371,
#  'x broker': 361657,
#  'broker #': 119201,
#  '# #': 6120,
#  '# change': 13161,
#  'change #': 125756,
#  '# meme': 30016,
#  'meme #': 239352,
#  'love #': 229787,
#  '# education': 17420,
#  'education #': 154105,
#  '# university': 44926,
#  ...}

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_clf = MLPClassifier(activation='tanh',  
                     hidden_layer_sizes=(10,), 
                     verbose=True)

# %%
mlp_clf.fit(X_train_v, y_train)
# Out:
# Iteration 1, loss = 0.38205469
# Iteration 2, loss = 0.19653906
# Iteration 3, loss = 0.13642463
# Iteration 4, loss = 0.09583283
# Iteration 5, loss = 0.06509543
# Iteration 6, loss = 0.04443694
# Iteration 7, loss = 0.03149561
# Iteration 8, loss = 0.02335673
# Iteration 9, loss = 0.01811265
# Iteration 10, loss = 0.01459987
# Iteration 11, loss = 0.01216037
# Iteration 12, loss = 0.01040312
# Iteration 13, loss = 0.00910236
# Iteration 14, loss = 0.00810776
# Iteration 15, loss = 0.00732779
# Iteration 16, loss = 0.00670485
# Iteration 17, loss = 0.00619337
# Iteration 18, loss = 0.00576763
# Iteration 19, loss = 0.00540630
# Iteration 20, loss = 0.00509656
# Iteration 21, loss = 0.00482422
# Iteration 22, loss = 0.00458320
# Iteration 23, loss = 0.00436866
# Iteration 24, loss = 0.00417446
# Iteration 25, loss = 0.00399749
# Iteration 26, loss = 0.00383628
# Iteration 27, loss = 0.00368654
# Iteration 28, loss = 0.00354670
# Iteration 29, loss = 0.00341733
# Iteration 30, loss = 0.00329543
# Iteration 31, loss = 0.00317684
# Iteration 32, loss = 0.00307026
# Iteration 33, loss = 0.00296792
# Iteration 34, loss = 0.00287158
# Iteration 35, loss = 0.00277934
# Iteration 36, loss = 0.00269267
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=True, warm_start=False)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, classification_report

# %%
y_pred = mlp_clf.predict(X_test_v)

# %%
#confusion_matrix(y_test, y_pred)

# %%
print("roc_auc score: {}".format(roc_auc_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# roc_auc score: 0.7993207827706356
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      5945
#           1       0.92      0.60      0.73       448
#
# avg / total       0.97      0.97      0.97      6393

# %%
X_all = vectorizer.transform(X)
y_all = y

# %%
mlp_clf.fit(X_all, y_all)
# Out:
# Iteration 1, loss = 0.39734188
# Iteration 2, loss = 0.19497688
# Iteration 3, loss = 0.13580592
# Iteration 4, loss = 0.09539689
# Iteration 5, loss = 0.06516864
# Iteration 6, loss = 0.04535579
# Iteration 7, loss = 0.03296804
# Iteration 8, loss = 0.02508637
# Iteration 9, loss = 0.01986712
# Iteration 10, loss = 0.01625697
# Iteration 11, loss = 0.01367538
# Iteration 12, loss = 0.01175884
# Iteration 13, loss = 0.01030564
# Iteration 14, loss = 0.00917269
# Iteration 15, loss = 0.00827120
# Iteration 16, loss = 0.00753405
# Iteration 17, loss = 0.00692051
# Iteration 18, loss = 0.00640447
# Iteration 19, loss = 0.00596429
# Iteration 20, loss = 0.00558073
# Iteration 21, loss = 0.00524437
# Iteration 22, loss = 0.00494511
# Iteration 23, loss = 0.00467603
# Iteration 24, loss = 0.00443348
# Iteration 25, loss = 0.00421292
# Iteration 26, loss = 0.00400989
# Iteration 27, loss = 0.00382425
# Iteration 28, loss = 0.00365250
# Iteration 29, loss = 0.00349274
# Iteration 30, loss = 0.00334365
# Iteration 31, loss = 0.00320370
# Iteration 32, loss = 0.00307417
# Iteration 33, loss = 0.00295212
# Iteration 34, loss = 0.00283799
# Iteration 35, loss = 0.00272901
# Iteration 36, loss = 0.00262893
# Iteration 37, loss = 0.00253147
# Iteration 38, loss = 0.00243893
# Iteration 39, loss = 0.00235865
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=True, warm_start=False)

# %%
df_test = pd.read_csv("dataset/test.csv")

# %%
df_test.sample(5)
# Out:
#           id                                              tweet
# 13662  45625  @user @user &amp; will i am...   ð¤ðð¼ð...
# 1149   33112   @user ð¦ðwhen haagen-dazs comes to brigh...
# 8939   40902  @user didn't know there was one, just looked i...
# 1349   33312  what america owes #blacks    #africanamerican ...
# 15048  47011    to see my fellow #ham radio operators #cantw...

# %%
dtest = vectorizer.transform(df_test['tweet'])
test_pred = mlp_clf.predict(dtest)

# %%
df_test['label'] = test_pred

# %%
submission = df_test[['id','label']]

# %%
submission.to_csv('sub_rodixxi_mlpc_lemmatizer.csv', index=False)
